# %% [markdown]
# # Deducing Struct Layout with Symbolic Execution
# The goal of this tutorial is to determine the input format
# accepted by the test program `dns.{arch}.elf`
# without reading the source or resorting to manual RE.
#
# We'll use memory labelling to lay out a hypothetical message structure
# in our machine state, and then use `FieldDetectionAnalysis` to
# detect inconsistencies between our hypothesis and how the code accesses the data.
# By iterating this process, we will refine our hypothesis until it matches
# what the code accepts.

# %% [markdown]
# ## Setup & Installation
# Install the required packages as described in the install directions.
#
# You can build the example programs by running `make all` from this directory.
# This requires the cross-compiler toolchains installed as part of the apt dependencies;
# this analysis will work on any architecture supported by angr.
#
# Let's test this program against the example input `examples/answer.dat`:
#
# ```
# $> hexdump -C examples/answer.dat
# 00000000  ce 70 81 80 00 01 00 01  00 00 00 01 06 67 6f 6f  |.p...........goo|
# 00000010  67 6c 65 03 63 6f 6d 00  00 01 00 01 c0 0c 00 01  |gle.com.........|
# 00000020  00 01 00 00 00 d2 00 04  8e fa 41 ce 00 00 29 04  |..........A...).|
# 00000030  c4 00 00 00 00 00 1c 00  0a 00 18 cb 6e 4b 21 27  |............nK!'|
# 00000040  ca a2 eb 8f fc 9f 64 67  85 5f 7f cf 3e 38 e4 56  |......dg._..>8.V|
# 00000050  80 72 f9                                          |.r.|
# 00000053
#
# $> ./bin/dns.amd64.elf examples/answer.dat
# DNS Message:
#         TID:          ce70
#         FLAGS:        0120
#         # Questions:  1
#         # Answers:    0
#         # Auth. Rs:   0
#         # Extra Rs:   1
# Question:
#         Name:         google.com
#         Type:         1
#         Class:        1
# Record:
#         Name:
#         Type:         41
#         Class:        1232
# ```
#
# If it's not apparent yet, this program parses basic DNS messages.
# However, the exact structure accepted by the parser isn't obvious.
# We could decompile the binary and try to elicit the structure but
# we are going to use SmallWord analysis capabilites to figure it out.
#
# ## Harnessing the Parser
#
# For sanity's sake, let's assume we know that the parser is implemented in `parse_dns_msg()`,
# and that we roughly know its arguments from `main()`:
#
# - **Arg 1:** `uint8_t *` pointing to an input buffer
# - **Arg 2:** `size_t` holding its size
# - **Arg 3:** `size_t *` pointing to a value starting at zero
# - **Arg 4:** `struct *` pointing to an unknown struct
#
# Our goal for this exercise is to figure out the structure of argument 1,
# which we'll call `buf`, and argument 4, which we'll call `msg`.
#
# First, we set up some smallworld boilerplate.
# This configures logging, as well as the hinter
# that will let us see the output from our analysis.

# %%
import warnings

warnings.filterwarnings(
    "ignore", 
    message="Protobuf gencode version .* is exactly one major version older.*"
)

# %%
import logging
import pathlib

import smallworld
import smallworld.analyses.field_detection
import smallworld.analyses.unstable.angr.visitor
from smallworld.analyses.field_detection import FieldDetectionAnalysis

# Set up logging and hinting                                                                                                                                                                                                         
smallworld.logging.setup_logging(level=logging.INFO)
smallworld.hinting.setup_hinting(stream=True, verbose=True)

log = logging.getLogger("smallworld")
# Out:
# /home/na28046/.local/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.2 is exactly one major version older than the runtime version 6.30.2 at angr/protos/primitives.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/na28046/.local/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.2 is exactly one major version older than the runtime version 6.30.2 at angr/protos/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/na28046/.local/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.2 is exactly one major version older than the runtime version 6.30.2 at angr/protos/cfg.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/na28046/.local/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.2 is exactly one major version older than the runtime version 6.30.2 at angr/protos/xrefs.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/na28046/.local/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.2 is exactly one major version older than the runtime version 6.30.2 at angr/protos/variables.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %% [markdown]
# Next, we create the basic machine state, load our ELF file into a smallworld state object, and add the code to the machine.
#
# Since we don't expect a specific platform, we can use the platform definition parsed out of the ELF headers.
#
# Also, since this is the only ELF we're loading, we can use its notion of program bounds to define which memory the analysis can execute.

# %%
# Create a machine
machine = smallworld.state.Machine()

# Load the code
filepath = "bin/dns.amd64.elf"
with open(filepath, "rb") as f:
    code = smallworld.state.memory.code.Executable.from_elf(f, 0x40000)
    machine.add(code)

# Apply the code's bounds to the machine
for bound in code.bounds:
    machine.add_bound(bound[0], bound[1])

# Use the ELF's notion of the platform
platform = code.platform

 # Create the analysis; we'll need it later.
analysis = FieldDetectionAnalysis(platform)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-07-08 09:59:44,191", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 09:59:44,192", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 09:59:44,192", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 09:59:44,193", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}

# %%
# Create a CPU
cpu = smallworld.state.cpus.CPU.for_platform(platform)
machine.add(cpu)

# Use lief to find the address of parse_dns_message
sym = code.get_symbol_value("parse_dns_message")
cpu.rip.set(sym)

# Add a blank stack
stack = smallworld.state.memory.stack.Stack.for_platform(
    platform, 0x7FFFFFFFC000, 0x4000
)
machine.add(stack)

stack.push_integer(0x01010101, 8, None)

# Configure the stack pointer
sp = stack.get_pointer()
cpu.rsp.set(sp)

# %% [markdown]
# Now that we have the program set up, we can start to model the inputs to `parse_dns_message()`.
# We know we need a message struct, a memory buffer, and a `size_t`
# that are all passed by reference.
#
# For ease of modelling, let's just allocate them all as globals.
#
# To start, we'll allocate `buf` and `msg` as blank swaths of memory.
# As we learn more about their internal structure from the analysis,
# we will come back and refine this part of our harness.

# %%
# Configure somewhere for arguments to live                                                                                                                                                                                          
gdata = smallworld.state.memory.Memory(0x6000, 0x1000)
machine.add(gdata)
# DNS message struct                                                                                                                                                                                                                 
# Sort of cheating that I know how big it is.                                                                                                                                                                                        
gdata[0] = smallworld.state.SymbolicValue(48, None, None, "msg")
# Input buffer                                                                                                                                                                                                                       
gdata[48] = smallworld.state.SymbolicValue(512, None, None, "buf")
# Offset into buffer                                                                                                                                                                                                                 
gdata[560] = smallworld.state.IntegerValue(0, 8, "off", False)

# %% [markdown]
# Next, we use what we know about the function signature to assign values to registers.
# We know that the first arg points to `buf`, the second is the size of `buf`,
# the third points to `off`, and the fourth points to `msg`.

# %%
# Configure arguments                                                                                                                                                                                                                
# arg 0: pointer to buf                                                                                                                                                                                                              
cpu.rdi.set(gdata.address + 48)
cpu.rdi.set_label("PTR buf")
# arg 1: buffer capacity                                                                                                                                                                                                             
cpu.rsi.set(512)
cpu.rsi.set_label("cap")
# arg 2: pointer to off                                                                                                                                                                                                              
cpu.rdx.set(gdata.address + 560)
cpu.rdx.set_label("PTR off")
# arg 3: pointer to msg                                                                                                                                                                                                              
cpu.rcx.set(gdata.address)
cpu.rcx.set_label("PTR msg")

# %% [markdown]
# At long last, we're reading to actually run our analysis.

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg
# [+] {"time": "2025-07-08 09:59:44,249", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 48, "label": "msg", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2170> := buf
# [+] {"time": "2025-07-08 09:59:44,250", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 09:59:44,251", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a13093b6f80>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a13093b6f80>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] Self-modifying code is not always correctly optimized by PyVEX. To guarantee correctness, VEX optimizations have been disabled.
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg)
# [!]   <BV64 0x0>
# [+] {"time": "2025-07-08 09:59:44,640", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 24592, "size": 8, "pc": 269939, "guards": [], "access": "write", "label": "msg", "start": 16, "end": 24, "expr": "<BV64 0x0>", "class": "smallworld.analyses.field_detection.hints.PartialByteFieldWriteHint"}}
# [*] Partial write to known field
# [*]   address:    0x6010
# [*]   size:       8
# [*]   pc:         0x41e73
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg[16:24]
# [*]   expr:       <BV64 0x0>
# [!] <SimulationManager with 1 deadended>
# [!] []
# [!] State at <BV64 0x41e73>:
# [!]   Guards:
# [!]   Fields:
# [!]     0x6000 - 0x6030: msg = <BV384 msg>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>

# %% [markdown]
# # First Results
#
# (This code so far is collected in `dns_0.py`.)  The analysis produced by `FieldDetectionAnalysis` yields the following hint:
#
# ```
# [*] Partial write to known field
# [*]   address:    0x6010
# [*]   size:       8
# [*]   pc:         0x41e73
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg[16:24]
# [*]   expr:       <BV64 0x0>
# ```
# The code at `0x41e73` tried to write 8 bytes of zero starting 16 bytes into our `msg` buffer.
# But we defined `msg` as a 512 byte contiguous region and didn't expect to see a field.
#
# With this information in hand we can redefine `msg` as the following

# %%
gdata[0] = smallworld.state.SymbolicValue(16, None, None, "msg.unk-0x0")
gdata[16] = smallworld.state.SymbolicValue(8, None, None, "msg.a")
gdata[24] = smallworld.state.SymbolicValue(24, None, None, "msg.unk-0x18")

# %% [markdown]
# We're not sure what `msg.a` is, but we know it's very likely a field.
# We're on our way!
#
# Running our updated script gives a very similar hint to the first:

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.unk-0x0
# [+] {"time": "2025-07-08 09:59:44,666", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 16, "label": "msg.unk-0x0", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2170> := buf
# [+] {"time": "2025-07-08 09:59:44,668", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 09:59:44,669", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.a
# [+] {"time": "2025-07-08 09:59:44,670", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.unk-0x18
# [+] {"time": "2025-07-08 09:59:44,671", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 24, "label": "msg.unk-0x18", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a1309286f50>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a1309286f50>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.unk-0x18)
# [!]   <BV64 0x0>
# [+] {"time": "2025-07-08 09:59:45,044", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 24600, "size": 8, "pc": 269951, "guards": [], "access": "write", "label": "msg.unk-0x18", "start": 0, "end": 8, "expr": "<BV64 0x0>", "class": "smallworld.analyses.field_detection.hints.PartialByteFieldWriteHint"}}
# [*] Partial write to known field
# [*]   address:    0x6018
# [*]   size:       8
# [*]   pc:         0x41e7f
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg.unk-0x18[0:8]
# [*]   expr:       <BV64 0x0>
# [!] <SimulationManager with 1 deadended>
# [!] []
# [!] State at <BV64 0x41e7f>:
# [!]   Guards:
# [!]   Fields:
# [!]     0x6000 - 0x6010: msg.unk-0x0 = <BV128 msg.unk-0x0>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_8_64 = <BV64 0x0>
# [!]     0x6018 - 0x6030: msg.unk-0x18 = <BV192 msg.unk-0x18>

# %% [markdown]
# Running our updated script gives a very similar hint to the first:
#
# ```
# [*] Partial write to known field
# [*]   address:    0x6018
# [*]   size:       8
# [*]   pc:         0x41e7f
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg.unk.0x18[0:8]
# [*]   expr:       <BV64 0x0>
# ```
#
# In fact, four iterations tell us the same thing;
# the program writes zero to four 8-byte fields right next to each other:

# %%
gdata[0] = smallworld.state.SymbolicValue(16, None, None, "msg.unk-0x0")
gdata[16] = smallworld.state.SymbolicValue(8, None, None, "msg.a")
gdata[24] = smallworld.state.SymbolicValue(8, None, None, "msg.b")
gdata[32] = smallworld.state.SymbolicValue(8, None, None, "msg.c")
gdata[40] = smallworld.state.SymbolicValue(8, None, None, "msg.d")

# %% [markdown]
# Some more iterations, and we start decoding `msg.unk-0x0`.

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a13078dbf40> := msg.unk-0x0
# [+] {"time": "2025-07-08 09:59:45,087", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 16, "label": "msg.unk-0x0", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2170> := buf
# [+] {"time": "2025-07-08 09:59:45,091", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 09:59:45,094", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a1309287400> := msg.a
# [+] {"time": "2025-07-08 09:59:45,095", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.b
# [+] {"time": "2025-07-08 09:59:45,097", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.c
# [+] {"time": "2025-07-08 09:59:45,098", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.d
# [+] {"time": "2025-07-08 09:59:45,099", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a13078eb310>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a13078eb310>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf)
# [!]   <BV16 Reverse(buf[4095:4080])>
# [+] {"time": "2025-07-08 09:59:45,906", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24624, "size": 2, "pc": 268304, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x6030
# [*]   size:       2
# [*]   pc:         0x41810
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] <SimulationManager with 1 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41810>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6010: msg.unk-0x0 = <BV128 msg.unk-0x0>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_16_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_17_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_18_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_19_64 = <BV64 0x0>

# %% [markdown]
# Iterating on this process we find that we have multiple 2 byte regions which we identify as parts of `msg.hdr`, since we suspect it's the part of the struct representing the DNS header.  The information in the final 4 bytes of this region are never referenced.  We leave them as a final 4 byte region we call `msg.hdr.unused`:

# %%
gdata[0] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.a")
gdata[2] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.b")
gdata[4] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.c")
gdata[6] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.d")
gdata[8] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.e")
gdata[10] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.f")
gdata[12] = smallworld.state.SymbolicValue(4, None, None, "msg.hdr.unused")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7a130797f280> := msg.hdr.a
# [+] {"time": "2025-07-08 09:59:45,945", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2170> := buf
# [+] {"time": "2025-07-08 09:59:45,946", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 09:59:45,948", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a1309287400> := msg.a
# [+] {"time": "2025-07-08 09:59:45,950", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.b
# [+] {"time": "2025-07-08 09:59:45,951", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.c
# [+] {"time": "2025-07-08 09:59:45,953", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.d
# [+] {"time": "2025-07-08 09:59:45,954", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7a130797f2e0> := msg.hdr.b
# [+] {"time": "2025-07-08 09:59:45,956", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7a130797e920> := msg.hdr.c
# [+] {"time": "2025-07-08 09:59:45,959", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7a130797e980> := msg.hdr.d
# [+] {"time": "2025-07-08 09:59:45,960", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7a130797e9e0> := msg.hdr.e
# [+] {"time": "2025-07-08 09:59:45,962", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7a130797ea40> := msg.hdr.f
# [+] {"time": "2025-07-08 09:59:45,963", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a130797eaa0> := msg.hdr.unused
# [+] {"time": "2025-07-08 09:59:45,964", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a130794a380>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a130794a380>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf)
# [!]   <BV16 Reverse(buf[4095:4080])>
# [+] {"time": "2025-07-08 09:59:46,911", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24624, "size": 2, "pc": 268304, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x6030
# [*]   size:       2
# [*]   pc:         0x41810
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] <SimulationManager with 1 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41810>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a = <BV16 msg.hdr.a>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_34_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_35_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_36_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_37_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b = <BV16 msg.hdr.b>
# [!]     0x6004 - 0x6006: msg.hdr.c = <BV16 msg.hdr.c>
# [!]     0x6006 - 0x6008: msg.hdr.d = <BV16 msg.hdr.d>
# [!]     0x6008 - 0x600a: msg.hdr.e = <BV16 msg.hdr.e>
# [!]     0x600a - 0x600c: msg.hdr.f = <BV16 msg.hdr.f>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>

# %% [markdown]
# Repeating this process for `buf` we can further identify regions which we summarize as:

# %%
gdata[48] = smallworld.state.SymbolicValue(2, None, None, "buf.a")
gdata[50] = smallworld.state.SymbolicValue(2, None, None, "buf.b")
gdata[52] = smallworld.state.SymbolicValue(2, None, None, "buf.c")
gdata[54] = smallworld.state.SymbolicValue(2, None, None, "buf.d")
gdata[56] = smallworld.state.SymbolicValue(2, None, None, "buf.e")
gdata[58] = smallworld.state.SymbolicValue(2, None, None, "buf.f")
gdata[60] = smallworld.state.SymbolicValue(500, None, None, "buf")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7a130797f280> := msg.hdr.a
# [+] {"time": "2025-07-08 09:59:46,954", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7a130784b4c0> := buf.a
# [+] {"time": "2025-07-08 09:59:46,955", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 09:59:46,958", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a1309287400> := msg.a
# [+] {"time": "2025-07-08 09:59:46,959", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.b
# [+] {"time": "2025-07-08 09:59:46,960", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.c
# [+] {"time": "2025-07-08 09:59:46,961", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.d
# [+] {"time": "2025-07-08 09:59:46,962", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7a130797f2e0> := msg.hdr.b
# [+] {"time": "2025-07-08 09:59:46,963", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7a130797e920> := msg.hdr.c
# [+] {"time": "2025-07-08 09:59:46,964", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7a130797e980> := msg.hdr.d
# [+] {"time": "2025-07-08 09:59:46,966", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7a130797e9e0> := msg.hdr.e
# [+] {"time": "2025-07-08 09:59:46,967", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7a130797ea40> := msg.hdr.f
# [+] {"time": "2025-07-08 09:59:46,968", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a130797eaa0> := msg.hdr.unused
# [+] {"time": "2025-07-08 09:59:46,968", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7a130784ae90> := buf.b
# [+] {"time": "2025-07-08 09:59:46,970", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2170> := buf.c
# [+] {"time": "2025-07-08 09:59:46,971", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x7a13093b7ca0> := buf.d
# [+] {"time": "2025-07-08 09:59:46,972", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7a1307848a00> := buf.e
# [+] {"time": "2025-07-08 09:59:46,973", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7a130784bac0> := buf.f
# [+] {"time": "2025-07-08 09:59:46,974", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a130784bb20> := buf
# [+] {"time": "2025-07-08 09:59:46,975", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a130797ef80>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a130797ef80>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_67_16>
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x1076>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_63_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_74_64 = <BV64 off_72_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_58_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_59_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_60_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_61_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_65_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_67_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_69_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_71_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_73_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# The work above is summarized in `dns_1.py`.

# %% [markdown]
# # Adding malloc
#
# Notice that the `FieldDetectionAnalysis` routine no longer provides information about a partial access to a known field, so execution continues.  The last successful read is reported to be at instruction `0x41ed2`, and that the analysis ends there with the last known good state being reported as:
#
# ```
# [!] State at <BV64 0x1076>:
# ```
#
# We loaded our ELF at 0x40000 so something's way off.
# If we disassemble the code and look around 0x1ed2 (which is 0x41ed2 minus the loading address 0x40000) we find:
#
# ```
# $> objdump -d -R ./bin/dns.amd64.elf
# ...
#     1ed2:       0f b7 40 04             movzwl 0x4(%rax),%eax
#     1ed6:       48 69 f8 08 01 00 00    imul   $0x108,%rax,%rdi
#     1edd:       e8 8e f1 ff ff          call   1070 <malloc@plt>
# ...
# ```
#
# This is an external call to `malloc()` which we have not loaded.
#
# We have not yet discussed how to handle an external call like this.  One strategey would be to stub out `malloc()` and carry on.  Howerver, we would
# like to know what is happening inside the heap-allocated buffers as well.
# Luckily, `FieldDetectionAnalysis` comes with a malloc model.
# Let's update our harness:

# %% [markdown]
# Note: At this point we recreate our machine so any changes we made along the way are reset.

# %%
def reinitialize_demo():
    # reinitializing outside of this routine
    global machine
    global platform
    global analysis
    global cpu
    global sym
    global stack
    global sp
    global code


    # Create a machine
    machine = smallworld.state.Machine()

    # Load the code
    filepath = "bin/dns.amd64.elf"
    with open(filepath, "rb") as f:
        code = smallworld.state.memory.code.Executable.from_elf(f, 0x40000)
        machine.add(code)

    # Apply the code's bounds to the machine
    for bound in code.bounds:
       machine.add_bound(bound[0], bound[1])

    # Use the ELF's notion of the platform
    platform = code.platform

    # Create the analysis; we'll need it later.
    analysis = FieldDetectionAnalysis(platform)

    # Create a CPU
    cpu = smallworld.state.cpus.CPU.for_platform(platform)
    machine.add(cpu)

    # Use lief to find the address of parse_dns_message
    sym = code.get_symbol_value("parse_dns_message")
    cpu.rip.set(sym)

    # Add a blank stack
    stack = smallworld.state.memory.stack.Stack.for_platform(
        platform, 0x7FFFFFFFC000, 0x4000
    )
    machine.add(stack)
    machine.add(gdata)

    stack.push_integer(0x01010101, 8, None)

    # Configure the stack pointer
    sp = stack.get_pointer()
    cpu.rsp.set(sp)

    # Configure arguments
    # arg 0: pointer to buf
    cpu.rdi.set(gdata.address + 48)
    cpu.rdi.set_label("PTR buf")
    # arg 1: buffer capacity
    cpu.rsi.set(512)
    cpu.rsi.set_label("cap")
    # arg 2: pointer to off
    cpu.rdx.set(gdata.address + 560)
    cpu.rdx.set_label("PTR off")
    # arg 3: pointer to msg
    cpu.rcx.set(gdata.address)
    cpu.rcx.set_label("PTR msg")
reinitialize_demo()
# Out:
# [+] Address: 40000
# [+] {"time": "2025-07-31 16:04:41,139", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-31 16:04:41,141", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-31 16:04:41,141", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-31 16:04:41,142", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 66
#      64     cpu.rcx.set(gdata.address)
#      65     cpu.rcx.set_label("PTR msg")
# ---> 66 reinitialize_demo()
#
# Cell In[2], line 45, in reinitialize_demo()
#      41 stack = smallworld.state.memory.stack.Stack.for_platform(
#      42     platform, 0x7FFFFFFFC000, 0x4000
#      43 )
#      44 machine.add(stack)
# ---> 45 machine.add(gdata)
#      47 stack.push_integer(0x01010101, 8, None)
#      49 # Configure the stack pointer
#
# NameError: name 'gdata' is not defined

# %%
from smallworld.analyses.field_detection import MallocModel, FreeModel
# Add a blank heap 
heap = smallworld.state.memory.heap.BumpAllocator(0x20000, 0x10000)
machine.add(heap)

# Configure malloc and free models
malloc = MallocModel(
    0x10000, heap, platform, analysis.mem_read_hook, analysis.mem_write_hook
)
machine.add(malloc)
machine.add_bound(malloc._address, malloc._address + 16)

free = FreeModel(0x1036)
machine.add(free)
machine.add_bound(free._address, free._address + 16)

# %% [markdown]
# This will invoke a function hook mimicking `malloc()` if we call address 0x10000.
# If we were in a raw binary, we'd have to do some manual patching
# to tell it where we put `malloc()`, but this is an ELF.
# Let's use the relocation entries to our advantage:

# %%
# Apply relocations to malloc
code.update_symbol_value("malloc", malloc._address)

# %% [markdown]
# So we can continue our analysis here or if you want to run outside this notebook the worke we have done up to this point is fully contained in `dns_2.py`:

# %%
machine.analyze(analysis)
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x20000 - 0x30000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7a130797f280> := msg.hdr.a
# [+] {"time": "2025-07-08 09:59:50,210", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7a130784b4c0> := buf.a
# [+] {"time": "2025-07-08 09:59:50,212", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 09:59:50,213", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a1309287400> := msg.a
# [+] {"time": "2025-07-08 09:59:50,215", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.b
# [+] {"time": "2025-07-08 09:59:50,216", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.c
# [+] {"time": "2025-07-08 09:59:50,218", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.d
# [+] {"time": "2025-07-08 09:59:50,220", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7a130797f2e0> := msg.hdr.b
# [+] {"time": "2025-07-08 09:59:50,224", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7a130797e920> := msg.hdr.c
# [+] {"time": "2025-07-08 09:59:50,225", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7a130797e980> := msg.hdr.d
# [+] {"time": "2025-07-08 09:59:50,226", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7a130797e9e0> := msg.hdr.e
# [+] {"time": "2025-07-08 09:59:50,226", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7a130797ea40> := msg.hdr.f
# [+] {"time": "2025-07-08 09:59:50,228", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a130797eaa0> := msg.hdr.unused
# [+] {"time": "2025-07-08 09:59:50,229", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7a130784ae90> := buf.b
# [+] {"time": "2025-07-08 09:59:50,230", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2170> := buf.c
# [+] {"time": "2025-07-08 09:59:50,230", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x7a13093b7ca0> := buf.d
# [+] {"time": "2025-07-08 09:59:50,232", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7a1307848a00> := buf.e
# [+] {"time": "2025-07-08 09:59:50,233", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7a130784bac0> := buf.f
# [+] {"time": "2025-07-08 09:59:50,234", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a130784bb20> := buf
# [+] {"time": "2025-07-08 09:59:50,235", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a1307652dd0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a1307652dd0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_103_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.c_103_16
# [*] Concretize them to continue analysis
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x10000>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_99_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_110_64 = <BV64 off_108_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_94_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_95_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_96_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_97_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_101_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_103_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_105_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_107_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_109_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# This ran for much longer, but eventually halted with an error similar to this:
#
# ```
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.c_27_16
# [*] Concretize them to continue analysis
# ```
#
# This output indicates that the analysis was able to deduce that the `msg.hdr.c` field
# gives the numbe of items allocated in our buffer.  In fact, if we scroll up to instruction
# 0x418d0 we see that `msg.hdr.c` gets filled in by the contents of `buf.c` so if we want to
# concretize `msg.hdr.c` we need to assign a concrete value to `buf.c` (and give it a new name):

# %%
gdata[52] = smallworld.state.BytesValue(b"\x00\x01", "buf.msg.hdr.c")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x20000 - 0x30000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7a130797f280> := msg.hdr.a
# [+] {"time": "2025-07-08 09:59:53,543", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7a130784b4c0> := buf.a
# [+] {"time": "2025-07-08 09:59:53,545", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 09:59:53,546", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a1309287400> := msg.a
# [+] {"time": "2025-07-08 09:59:53,548", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.b
# [+] {"time": "2025-07-08 09:59:53,549", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.c
# [+] {"time": "2025-07-08 09:59:53,550", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.d
# [+] {"time": "2025-07-08 09:59:53,551", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7a130797f2e0> := msg.hdr.b
# [+] {"time": "2025-07-08 09:59:53,552", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7a130797e920> := msg.hdr.c
# [+] {"time": "2025-07-08 09:59:53,553", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7a130797e980> := msg.hdr.d
# [+] {"time": "2025-07-08 09:59:53,554", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7a130797e9e0> := msg.hdr.e
# [+] {"time": "2025-07-08 09:59:53,555", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7a130797ea40> := msg.hdr.f
# [+] {"time": "2025-07-08 09:59:53,556", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a130797eaa0> := msg.hdr.unused
# [+] {"time": "2025-07-08 09:59:53,558", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7a130784ae90> := buf.b
# [+] {"time": "2025-07-08 09:59:53,558", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x7a1307651f00> := buf.msg.hdr.c
# [+] {"time": "2025-07-08 09:59:53,559", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x7a13093b7ca0> := buf.d
# [+] {"time": "2025-07-08 09:59:53,560", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7a1307848a00> := buf.e
# [+] {"time": "2025-07-08 09:59:53,561", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7a130784bac0> := buf.f
# [+] {"time": "2025-07-08 09:59:53,562", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a130784bb20> := buf
# [+] {"time": "2025-07-08 09:59:53,563", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a13073dc4f0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a13073dc4f0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_138_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_138_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_146_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_145_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_145_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf)
# [!]   <BV8 buf[3999:3992]>
# [+] {"time": "2025-07-08 09:59:57,561", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24636, "size": 1, "pc": 267639, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_138_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_145_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 1, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603c
# [*]   size:       1
# [*]   pc:         0x41577
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_138_16))> [[<BV16 msg.hdr.c_138_16>]]
# [*]     0x4155a: <Bool cap - off_145_64 >= 0x1> [[<BV64 off_145_64>, <BV64 cap>]]
# [*]   field:      buf[0:1]
# [!] <SimulationManager with 5 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41577>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_138_16))>
# [!]     0x4155a: <Bool cap - off_145_64 >= 0x1>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_134_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_145_64 = <BV64 off_143_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_146_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_130_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_131_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_132_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_136_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_138_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_140_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_142_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_144_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# ## Analyzing the behavior of malloc
#
# Scrolling up to the malloc call after the memory read at 0x41ed2 we see the following output from the malloc:
#
# ```
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [+] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [+]   <BV64 0x20010>
# ```
#
# Let's take this one line at a time:
#
# - `malloc: Alloc'd 264 bytes at 0x20010`:  Since we assigned 0x1 to the length in `buf.c`,
# this line is telling us that space for the struct is 264 bytes (the `malloc()` model would
# warn us if the length computation was more complex than "variable * magnitude".)
#
# - `Storing 8 bytes at 0x20008`: Malloc returns a pointer to the newly allocated memory so the address of the heap memory is stored there. #TODO - confirm this is true?
#
# - `  Length field msg.hdr.c not known`: We haven't told the `malloc()` model that it should track structs allocated using `msg.hdr.c`, or what they should look like. #TODO - review this comment, I don't fully understand it
#
# - `0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)`: The pointer to our new heap array is stored in `msg.a`, making `msg.hdr.c` the length of `msg.a`.
#
# We wrap up this section by noting that execution stopped on another read of a single byte from a larger buffer.  We'll finish this treatment of models with three final actions:
# - combine all the model work into a routine that can be called when we reinitialize our analysis
# - update our harness to take account of the single byte
# - run again

# %%
def add_malloc_free_models():
    global code
    global malloc
    global free
    global heap

    # Add a blank heap
    heap = smallworld.state.memory.heap.BumpAllocator(0x20000, 0x10000)
    machine.add(heap)

    # Configure malloc and free models
    malloc = MallocModel(
        0x10000, heap, platform, analysis.mem_read_hook, analysis.mem_write_hook
    )
    machine.add(malloc)
    machine.add_bound(malloc._address, malloc._address + 16)

    free = FreeModel(0x1036)
    machine.add(free)
    machine.add_bound(free._address, free._address + 16)

    # Apply relocations to malloc
    code.update_symbol_value("malloc", malloc._address)
  
reinitialize_demo()
add_malloc_free_models()
gdata[60] = smallworld.state.SymbolicValue(1, None, None, "buf.g")
gdata[61] = smallworld.state.SymbolicValue(499, None, None, "buf")
machine.analyze(analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-07-08 09:59:57,596", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 09:59:57,597", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 09:59:57,598", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 09:59:57,598", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x40000 - 0x46000
# [!] 0x20000 - 0x30000
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7a130797f280> := msg.hdr.a
# [+] {"time": "2025-07-08 09:59:57,605", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7a130784b4c0> := buf.a
# [+] {"time": "2025-07-08 09:59:57,606", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 09:59:57,608", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a1309287400> := msg.a
# [+] {"time": "2025-07-08 09:59:57,609", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.b
# [+] {"time": "2025-07-08 09:59:57,611", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.c
# [+] {"time": "2025-07-08 09:59:57,613", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.d
# [+] {"time": "2025-07-08 09:59:57,614", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7a130797f2e0> := msg.hdr.b
# [+] {"time": "2025-07-08 09:59:57,616", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7a130797e920> := msg.hdr.c
# [+] {"time": "2025-07-08 09:59:57,617", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7a130797e980> := msg.hdr.d
# [+] {"time": "2025-07-08 09:59:57,618", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7a130797e9e0> := msg.hdr.e
# [+] {"time": "2025-07-08 09:59:57,619", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7a130797ea40> := msg.hdr.f
# [+] {"time": "2025-07-08 09:59:57,620", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a130797eaa0> := msg.hdr.unused
# [+] {"time": "2025-07-08 09:59:57,622", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7a130784ae90> := buf.b
# [+] {"time": "2025-07-08 09:59:57,624", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x7a1307651f00> := buf.msg.hdr.c
# [+] {"time": "2025-07-08 09:59:57,625", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x7a13093b7ca0> := buf.d
# [+] {"time": "2025-07-08 09:59:57,627", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7a1307848a00> := buf.e
# [+] {"time": "2025-07-08 09:59:57,629", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7a130784bac0> := buf.f
# [+] {"time": "2025-07-08 09:59:57,630", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x7a130780d180> := buf.g
# [+] {"time": "2025-07-08 09:59:57,634", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.g", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a130784a620> := buf
# [+] {"time": "2025-07-08 09:59:57,636", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 499, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a13076232e0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a13076232e0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_172_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_172_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_172_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_172_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_174_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_174_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_174_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_174_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_176_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_176_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_176_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_176_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_178_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_178_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_178_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_178_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_180_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_180_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_180_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_180_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_175_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_175_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_183_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_182_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_182_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf.g)
# [!]   <BV8 buf.g>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_182_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_182_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x415c5: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_184_64>
# [!] 0x415c8: READING 0x603d - 0x603e (buf)
# [!]   <BV8 buf[3991:3984]>
# [+] {"time": "2025-07-08 10:00:02,094", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24637, "size": 1, "pc": 267720, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_175_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_182_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 1, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x415c8
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))> [[<BV16 msg.hdr.c_175_16>]]
# [*]     0x4155a: <Bool cap - off_182_64 >= 0x1> [[<BV64 off_182_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]   field:      buf[0:1]
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_184_64>
# [!] 0x41652: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_184_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_184_64>
# [!] 0x41a44: READING 0x603d - 0x603f (buf)
# [!]   <BV16 Reverse(buf[3991:3976])>
# [+] {"time": "2025-07-08 10:00:02,537", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24637, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_175_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_182_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268839, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_184_64", 64]}]}, {"op": "BVV", "args": [4, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))> [[<BV16 msg.hdr.c_175_16>]]
# [*]     0x4155a: <Bool cap - off_182_64 >= 0x1> [[<BV64 off_182_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g == 0> [[<BV8 buf.g>]]
# [*]     0x41a27: <Bool cap - off_184_64 >= 0x4> [[<BV64 off_184_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] 0x416b2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_184_64>
# [!] 0x416b9: READING 0x603d - 0x603e (buf)
# [!]   <BV8 buf[3991:3984]>
# [+] {"time": "2025-07-08 10:00:02,906", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24637, "size": 1, "pc": 267961, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_175_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_182_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_184_64", 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 1, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x416b9
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))> [[<BV16 msg.hdr.c_175_16>]]
# [*]     0x4155a: <Bool cap - off_182_64 >= 0x1> [[<BV64 off_182_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) != 192> [[<BV8 buf.g>]]
# [*]     0x4161c: <Bool (buf.g & 192) == 0> [[<BV8 buf.g>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.g)) < 0xff then 1 else 0) | (if buf.g == 255 then 1 else 0)) != 0> [[<BV8 buf.g>]]
# [*]     0x4165c: <Bool cap - off_184_64 >= (0#32 .. (0#24 .. buf.g))> [[<BV8 buf.g>, <BV64 off_184_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.g))> [[<BV8 buf.g>]]
# [*]   field:      buf[0:1]
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_183_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_183_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] <SimulationManager with 16 unsat, 4 deadended>
# [!] []
# [!] State at <BV64 0x415c8>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))>
# [!]     0x4155a: <Bool cap - off_182_64 >= 0x1>
# [!]     0x41592: <Bool buf.g != 0>
# [!]     0x415ab: <Bool (buf.g & 192) == 192>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_171_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_184_64 = <BV64 off_182_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_183_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_167_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_168_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_169_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_173_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_175_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_177_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_179_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_181_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [!] State at <BV64 0x41a44>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))>
# [!]     0x4155a: <Bool cap - off_182_64 >= 0x1>
# [!]     0x41592: <Bool buf.g == 0>
# [!]     0x41a27: <Bool cap - off_184_64 >= 0x4>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_171_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_184_64 = <BV64 off_182_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_183_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_167_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_168_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_169_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_173_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_175_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_177_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_179_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_181_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [!] State at <BV64 0x416b9>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))>
# [!]     0x4155a: <Bool cap - off_182_64 >= 0x1>
# [!]     0x41592: <Bool buf.g != 0>
# [!]     0x415ab: <Bool (buf.g & 192) != 192>
# [!]     0x4161c: <Bool (buf.g & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.g)) < 0xff then 1 else 0) | (if buf.g == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_184_64 >= (0#32 .. (0#24 .. buf.g))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.g))>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_171_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_184_64 = <BV64 off_182_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_183_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_167_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_168_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_169_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_173_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_175_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_177_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_179_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_181_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))>
# [!]     0x4155a: <Bool cap - off_182_64 >= 0x1>
# [!]     0x41592: <Bool buf.g != 0>
# [!]     0x415ab: <Bool (buf.g & 192) != 192>
# [!]     0x4161c: <Bool (buf.g & 192) != 0>
# [!]     0x421bd: <Bool msg.a_183_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_171_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_184_64 = <BV64 off_182_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_185_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_167_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_168_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_169_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_173_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_175_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_177_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_179_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_181_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [*] Multiple field defs starting at buf[0]:
# [*]     buf[0:1]
# [*]     buf[0:2]
# [*]   One or more of the following fields may control the format,
# [*]   either as a flag, type code or length:
# [*]     buf.g

# %% [markdown]
# # Stage 2 DNS exploration: Next control field
#
# The end of our last run produced new output.  In particular, it noted that `buf.g` seems to be
# influencing whether the first two bytes of `buf` are a single field or multiple fields.  What
# conditions are making this happen?  To address this question, we look at the various reports
# of `Partial access to known field` and look at the conditions that were required for that
# partial access to occurr.  This happens in three cases.  Extracting just the information
# relevent to `buf.g` we have:
#
# ### Case 1:
# ```
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x415c8
# [*]   access:     read
# [*]   guards:
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]   field:      buf[0:1]
# ```
# We get to this case exactly when the two high bits set on `buf.g`.  So since `buf.g` is a byte,
# `buf.g` is 64 and 255 inclusive.
#
# ### Case 2:
# ```
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x41592: <Bool buf.g == 0> [[<BV8 buf.g>]]
# [*]   field:      buf[0:2]
# ```
# We get to this case exactly when `buf.g == 0`.
#
# ### Case 3:
# ```
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x416b9
# [*]   access:     read
# [*]   guards:
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) != 192> [[<BV8 buf.g>]]
# [*]     0x4161c: <Bool (buf.g & 192) == 0> [[<BV8 buf.g>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.g)) < 0xff then 1 else 0) | (if buf.g == 255 then 1 else 0)) != 0> [[<BV8 buf.g>]]
# [*]     0x4165c: <Bool cap - off_184_64 >= (0#32 .. (0#24 .. buf.g))> [[<BV8 buf.g>, <BV64 off_184_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.g))> [[<BV8 buf.g>]]
# [*]   field:      buf[0:1]
# ```
# The conditions on `buf.g` look much more complicated here but with a little work
# it is not hard to see that this case arises exactly when the two high bits are
# unset on `buf.g` and `buf.g` non-zero.  So since `buf.g` is a byte, `buf.g` is
# between 1 and 63 inclusive.

# %% [markdown]
# ## Trying some concrete examples
#
# So can we try setting `buf.g` to some concrete values?  Of course, let's try a few:
#
# ### Case 1: `64 <= buf.g <= 255`
#
# Let's try setting the buffer to 64 and see what happens.  Having used symbolic execution
# in the past, we wrap our analysis with a timeout to catch in case it runs forever!

# %%
from smallworld.analyses.field_detection import MallocModel, FreeModel
import claripy
import timeout_decorator

@timeout_decorator.timeout(40)  # argument is in seconds
def analyze_with_timeout(machine, analysis):
    try:
        machine.analyze(analysis)
    except timeout_decorator.timeout_decorator.TimeoutError:
        print("Analysis timeout")


reinitialize_demo()
add_malloc_free_models()
gdata[61] = smallworld.state.SymbolicValue(1, None, None, "buf.one")
gdata[62] = smallworld.state.SymbolicValue(498, None, None, "buf")

# Add constraint to buf.g
machine.add_constraint(
    claripy.UGT(claripy.BVS("buf.g", 8, explicit_name=True), claripy.BVV(64, 8))
)

analyze_with_timeout(machine, analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-07-08 10:00:03,622", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:00:03,623", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:00:03,624", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:00:03,624", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x20000 - 0x30000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7a130797f280> := msg.hdr.a
# [+] {"time": "2025-07-08 10:00:03,630", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7a130784b4c0> := buf.a
# [+] {"time": "2025-07-08 10:00:03,632", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 10:00:03,633", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a1309287400> := msg.a
# [+] {"time": "2025-07-08 10:00:03,635", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.b
# [+] {"time": "2025-07-08 10:00:03,636", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.c
# [+] {"time": "2025-07-08 10:00:03,637", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.d
# [+] {"time": "2025-07-08 10:00:03,638", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7a130797f2e0> := msg.hdr.b
# [+] {"time": "2025-07-08 10:00:03,640", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7a130797e920> := msg.hdr.c
# [+] {"time": "2025-07-08 10:00:03,641", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7a130797e980> := msg.hdr.d
# [+] {"time": "2025-07-08 10:00:03,642", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7a130797e9e0> := msg.hdr.e
# [+] {"time": "2025-07-08 10:00:03,644", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7a130797ea40> := msg.hdr.f
# [+] {"time": "2025-07-08 10:00:03,645", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a130797eaa0> := msg.hdr.unused
# [+] {"time": "2025-07-08 10:00:03,646", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7a130784ae90> := buf.b
# [+] {"time": "2025-07-08 10:00:03,647", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x7a1307651f00> := buf.msg.hdr.c
# [+] {"time": "2025-07-08 10:00:03,649", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x7a13093b7ca0> := buf.d
# [+] {"time": "2025-07-08 10:00:03,650", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7a1307848a00> := buf.e
# [+] {"time": "2025-07-08 10:00:03,651", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7a130784bac0> := buf.f
# [+] {"time": "2025-07-08 10:00:03,653", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x7a130780d180> := buf.g
# [+] {"time": "2025-07-08 10:00:03,654", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.g", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x603e: <smallworld.state.state.SymbolicValue object at 0x7a130918b4f0> := buf.one
# [+] {"time": "2025-07-08 10:00:03,656", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 1, "label": "buf.one", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603e - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a1307992170> := buf
# [+] {"time": "2025-07-08 10:00:03,661", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24638, "size": 498, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x7fffffffc000 - 0x800000000000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a130784afb0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a130784afb0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [+] Storing 8 bytes at 0x7ffffffffff8
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_212_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_212_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_212_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_212_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_214_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_214_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_214_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_214_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_216_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_216_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_216_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_216_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_218_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_218_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_218_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_218_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_220_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_220_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_220_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_220_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_215_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_215_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_222_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_222_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf.g)
# [!]   <BV8 buf.g>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_222_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_222_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x415c5: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_224_64>
# [!] 0x415c8: READING 0x603d - 0x603e (buf.one)
# [!]   <BV8 buf.one>
# [!] 0x415d7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_224_64>
# [!] 0x415de: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_224_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_225_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_225_64>
# [!] 0x41a44: READING 0x603e - 0x6040 (buf)
# [!]   <BV16 Reverse(buf[3983:3968])>
# [+] {"time": "2025-07-08 10:00:11,061", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24638, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_215_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_222_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__eq__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268839, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_225_64", 64]}]}, {"op": "BVV", "args": [4, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603e
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_215_16))> [[<BV16 msg.hdr.c_215_16>]]
# [*]     0x4155a: <Bool cap - off_222_64 >= 0x1> [[<BV64 off_222_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool mem_a001_227_8 == 0> [[<BV8 mem_a001_227_8>]]
# [*]     0x41a27: <Bool cap - off_225_64 >= 0x4> [[<BV64 off_225_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_225_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_225_64>
# [!] 0x41a44: READING 0x603e - 0x6040 (buf)
# [!]   <BV16 Reverse(buf[3983:3968])>
# [+] {"time": "2025-07-08 10:00:19,851", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24638, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_215_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_222_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["mem_a001_227_8", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["mem_a002_228_8", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__eq__", "args": [{"op": "BVS", "args": ["mem_a025_230_8", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268839, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_225_64", 64]}]}, {"op": "BVV", "args": [4, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603e
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_215_16))> [[<BV16 msg.hdr.c_215_16>]]
# [*]     0x4155a: <Bool cap - off_222_64 >= 0x1> [[<BV64 off_222_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool mem_a001_227_8 != 0> [[<BV8 mem_a001_227_8>]]
# [*]     0x415ab: <Bool (mem_a001_227_8 & 192) == 192> [[<BV8 mem_a001_227_8>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. mem_a001_227_8)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. mem_a002_228_8))) >= 0x1> [[<BV8 mem_a002_228_8>, <BV8 mem_a001_227_8>, <BV64 cap>]]
# [*]     0x41592: <Bool mem_a025_230_8 == 0> [[<BV8 mem_a025_230_8>]]
# [*]     0x41a27: <Bool cap - off_225_64 >= 0x4> [[<BV64 off_225_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_225_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_225_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_225_64>
# [!] 0x41a44: READING 0x603e - 0x6040 (buf)
# [!]   <BV16 Reverse(buf[3983:3968])>
# [+] {"time": "2025-07-08 10:00:31,801", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24638, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_215_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_222_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["mem_a001_227_8", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__add__", "args": [{"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}, {"op": "BVV", "args": [1, 64]}]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["mem_a001_227_8", 8]}]}]}], "class": "smallworld.analyses.field ...
# [*] Partial access to known field
# [*]   address:    0x603e
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_215_16))> [[<BV16 msg.hdr.c_215_16>]]
# [*]     0x4155a: <Bool cap - off_222_64 >= 0x1> [[<BV64 off_222_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool mem_a001_227_8 != 0> [[<BV8 mem_a001_227_8>]]
# [*]     0x415ab: <Bool (mem_a001_227_8 & 192) != 192> [[<BV8 mem_a001_227_8>]]
# [*]     0x4161c: <Bool (mem_a001_227_8 & 192) == 0> [[<BV8 mem_a001_227_8>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. mem_a001_227_8)) < 0xff then 1 else 0) | (if mem_a001_227_8 == 255 then 1 else 0)) != 0> [[<BV8 mem_a001_227_8>]]
# [*]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. <...>)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. mem_a001_227_8))> [[<BV8 mem_a001_227_8>, <BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. mem_a001_227_8))> [[<BV8 mem_a001_227_8>]]
# [*]     0x416cb: <Bool (SignExt(24, mem_a002_228_8) - 0x61[31:31] ^ (SignExt(24, mem_a002_228_8)[31:31] ^ 0) & (SignExt(24, mem_a002_228_8)[31:31] ^ SignExt(24, mem_a002_228_8) - 0x61[31:31])) != 0> [[<BV8 mem_a002_228_8>]]
# [*]     0x416f5: <Bool (SignExt(24, mem_a002_228_8) - 0x30[31:31] ^ (SignExt(24, mem_a002_228_8)[31:31] ^ 0) & (SignExt(24, mem_a002_228_8)[31:31] ^ SignExt(24, mem_a002_228_8) - 0x30[31:31])) != 0> [[<BV8 mem_a002_228_8>]]
# [*]     0x4172b: <Bool ((0#7 .. (if SignExt(24, mem_a002_228_8) == 0x2d then 1 else 0)) & 1) != 0> [[<BV8 mem_a002_228_8>]]
# [*]     0x416a4: <Bool 0x1 >= (0#32 .. (0#24 .. mem_a001_227_8))> [[<BV8 mem_a001_227_8>]]
# [*]     0x4155a: <Bool cap - ((0#32 .. (0#24 .. mem_a001_227_8)) + (((0#32 .. (0#24 .. <...>)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV8 mem_a001_227_8>, <BV64 cap>]]
# [*]     0x41592: <Bool mem_a003_233_8 == 0> [[<BV8 mem_a003_233_8>]]
# [*]     0x41a27: <Bool cap - off_225_64 >= 0x4> [[<BV64 off_225_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_225_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_225_64>
# [!] 0x41a44: READING 0x603e - 0x6040 (buf)
# [!]   <BV16 Reverse(buf[3983:3968])>
# [+] {"time": "2025-07-08 10:00:33,876", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24638, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_215_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_222_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["mem_a001_227_8", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__add__", "args": [{"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}, {"op": "BVV", "args": [1, 64]}]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["mem_a001_227_8", 8]}]}]}], "class": "smallworld.analyses.field ...
# [*] Partial access to known field
# [*]   address:    0x603e
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_215_16))> [[<BV16 msg.hdr.c_215_16>]]
# [*]     0x4155a: <Bool cap - off_222_64 >= 0x1> [[<BV64 off_222_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool mem_a001_227_8 != 0> [[<BV8 mem_a001_227_8>]]
# [*]     0x415ab: <Bool (mem_a001_227_8 & 192) != 192> [[<BV8 mem_a001_227_8>]]
# [*]     0x4161c: <Bool (mem_a001_227_8 & 192) == 0> [[<BV8 mem_a001_227_8>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. mem_a001_227_8)) < 0xff then 1 else 0) | (if mem_a001_227_8 == 255 then 1 else 0)) != 0> [[<BV8 mem_a001_227_8>]]
# [*]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. <...>)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. mem_a001_227_8))> [[<BV8 mem_a001_227_8>, <BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. mem_a001_227_8))> [[<BV8 mem_a001_227_8>]]
# [*]     0x416cb: <Bool (SignExt(24, mem_a002_228_8) - 0x61[31:31] ^ (SignExt(24, mem_a002_228_8)[31:31] ^ 0) & (SignExt(24, mem_a002_228_8)[31:31] ^ SignExt(24, mem_a002_228_8) - 0x61[31:31])) != 0> [[<BV8 mem_a002_228_8>]]
# [*]     0x416f5: <Bool (SignExt(24, mem_a002_228_8) - 0x30[31:31] ^ (SignExt(24, mem_a002_228_8)[31:31] ^ 0) & (SignExt(24, mem_a002_228_8)[31:31] ^ SignExt(24, mem_a002_228_8) - 0x30[31:31])) == 0> [[<BV8 mem_a002_228_8>]]
# [*]     0x4172b: <Bool ((0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, <...>) == 0x2d then 1 else 0)) & 1)) != 0x0> [[<BV8 mem_a002_228_8>]]
# [*]     0x416a4: <Bool 0x1 >= (0#32 .. (0#24 .. mem_a001_227_8))> [[<BV8 mem_a001_227_8>]]
# [*]     0x4155a: <Bool cap - ((0#32 .. (0#24 .. mem_a001_227_8)) + (((0#32 .. (0#24 .. <...>)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV8 mem_a001_227_8>, <BV64 cap>]]
# [*]     0x41592: <Bool mem_a003_233_8 == 0> [[<BV8 mem_a003_233_8>]]
# [*]     0x41a27: <Bool cap - off_225_64 >= 0x4> [[<BV64 off_225_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_225_64>
# [!] 0x41a44: READING 0x603e - 0x6040 (buf)
# [!]   <BV16 Reverse(buf[3983:3968])>
# [+] {"time": "2025-07-08 10:00:36,329", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24638, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_215_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_222_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["mem_a001_227_8", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["mem_a001_227_8", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__add__", "args": [{"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}, {"op": "BVV", "args": [1, 64]}]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["mem_a001_227_8", 8]}]}]}], "class": "smallworld.analyses.field ...
# [*] Partial access to known field
# [*]   address:    0x603e
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_215_16))> [[<BV16 msg.hdr.c_215_16>]]
# [*]     0x4155a: <Bool cap - off_222_64 >= 0x1> [[<BV64 off_222_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool mem_a001_227_8 != 0> [[<BV8 mem_a001_227_8>]]
# [*]     0x415ab: <Bool (mem_a001_227_8 & 192) != 192> [[<BV8 mem_a001_227_8>]]
# [*]     0x4161c: <Bool (mem_a001_227_8 & 192) == 0> [[<BV8 mem_a001_227_8>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. mem_a001_227_8)) < 0xff then 1 else 0) | (if mem_a001_227_8 == 255 then 1 else 0)) != 0> [[<BV8 mem_a001_227_8>]]
# [*]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. <...>)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. mem_a001_227_8))> [[<BV8 mem_a001_227_8>, <BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. mem_a001_227_8))> [[<BV8 mem_a001_227_8>]]
# [*]     0x416cb: <Bool (SignExt(24, mem_a002_228_8) - 0x61[31:31] ^ (SignExt(24, mem_a002_228_8)[31:31] ^ 0) & (SignExt(24, mem_a002_228_8)[31:31] ^ SignExt(24, mem_a002_228_8) - 0x61[31:31])) == 0> [[<BV8 mem_a002_228_8>]]
# [*]     0x416f5: <Bool (SignExt(24, mem_a002_228_8) - 0x30[31:31] ^ (SignExt(24, mem_a002_228_8)[31:31] ^ 0) & (SignExt(24, mem_a002_228_8)[31:31] ^ SignExt(24, mem_a002_228_8) - 0x30[31:31])) == 0> [[<BV8 mem_a002_228_8>]]
# [*]     0x4172b: <Bool ((0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, <...>) == 0x2d then 1 else 0)) & 1)) != 0x0> [[<BV8 mem_a002_228_8>]]
# [*]     0x416a4: <Bool 0x1 >= (0#32 .. (0#24 .. mem_a001_227_8))> [[<BV8 mem_a001_227_8>]]
# [*]     0x4155a: <Bool cap - ((0#32 .. (0#24 .. mem_a001_227_8)) + (((0#32 .. (0#24 .. <...>)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV8 mem_a001_227_8>, <BV64 cap>]]
# [*]     0x41592: <Bool mem_a003_233_8 == 0> [[<BV8 mem_a003_233_8>]]
# [*]     0x41a27: <Bool cap - off_225_64 >= 0x4> [[<BV64 off_225_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_225_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_223_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# Analysis timeout

# %% [markdown]
# Notice that this has run to `0x1010101` which is the return value from this subroutine.  In other words, this exectuion has run to completeion.  Further subdividing `buf.a` into `buf.a1` and `buf.a2` we have:

# %%
reinitialize_demo()
add_malloc_free_models()
gdata[48] = smallworld.state.SymbolicValue(1, None, None, "buf.a1")
gdata[49] = smallworld.state.SymbolicValue(1, None, None, "buf.a2")

# Add constraint to buf.g
machine.add_constraint(
    claripy.UGT(claripy.BVS("buf.g", 8, explicit_name=True), claripy.BVV(64, 8))
)

analyze_with_timeout(machine, analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-07-08 10:00:43,656", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:00:43,657", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:00:43,658", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:00:43,660", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x40000 - 0x46000
# [!] 0x20000 - 0x30000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7a130797f280> := msg.hdr.a
# [+] {"time": "2025-07-08 10:00:43,667", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6031: <smallworld.state.state.SymbolicValue object at 0x7a1307991c30> := buf.a1
# [+] {"time": "2025-07-08 10:00:43,669", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 1, "label": "buf.a1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 10:00:43,670", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a1309287400> := msg.a
# [+] {"time": "2025-07-08 10:00:43,672", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.b
# [+] {"time": "2025-07-08 10:00:43,674", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.c
# [+] {"time": "2025-07-08 10:00:43,676", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.d
# [+] {"time": "2025-07-08 10:00:43,678", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7a130797f2e0> := msg.hdr.b
# [+] {"time": "2025-07-08 10:00:43,679", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7a130797e920> := msg.hdr.c
# [+] {"time": "2025-07-08 10:00:43,682", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7a130797e980> := msg.hdr.d
# [+] {"time": "2025-07-08 10:00:43,684", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7a130797e9e0> := msg.hdr.e
# [+] {"time": "2025-07-08 10:00:43,685", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7a130797ea40> := msg.hdr.f
# [+] {"time": "2025-07-08 10:00:43,688", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a130797eaa0> := msg.hdr.unused
# [+] {"time": "2025-07-08 10:00:43,690", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7a130784ae90> := buf.b
# [+] {"time": "2025-07-08 10:00:43,692", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x7a1307651f00> := buf.msg.hdr.c
# [+] {"time": "2025-07-08 10:00:43,693", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x7a13093b7ca0> := buf.d
# [+] {"time": "2025-07-08 10:00:43,695", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7a1307848a00> := buf.e
# [+] {"time": "2025-07-08 10:00:43,697", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7a130784bac0> := buf.f
# [+] {"time": "2025-07-08 10:00:43,698", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x7a130780d180> := buf.g
# [+] {"time": "2025-07-08 10:00:43,700", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.g", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x603e: <smallworld.state.state.SymbolicValue object at 0x7a130918b4f0> := buf.one
# [+] {"time": "2025-07-08 10:00:43,703", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 1, "label": "buf.one", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603e - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a1307992170> := buf
# [+] {"time": "2025-07-08 10:00:43,705", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24638, "size": 498, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6031 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7a1309191510> := buf.a2
# [+] {"time": "2025-07-08 10:00:43,706", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24625, "size": 1, "label": "buf.a2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x7fffffffc000 - 0x800000000000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a1309190c10>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a1309190c10>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [+] Storing 8 bytes at 0x7ffffffffff8
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_271_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_271_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_271_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_271_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_273_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_273_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_273_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_273_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_275_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_275_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_275_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_275_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_277_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_277_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_277_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_277_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_279_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_279_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_279_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_279_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_274_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_274_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_282_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_281_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_281_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf.g)
# [!]   <BV8 buf.g>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_281_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_281_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x415c5: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_283_64>
# [!] 0x415c8: READING 0x603d - 0x603e (buf.one)
# [!]   <BV8 buf.one>
# [!] 0x415d7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_283_64>
# [!] 0x415de: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_283_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_282_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_282_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41577: READING 0x6030 - 0x6031 (buf.a1)
# [!]   <BV8 buf.a1>
# [!] 0x415c8: READING 0x6031 - 0x6032 (buf.a2)
# [!]   <BV8 buf.a2>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_282_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_284_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_282_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_284_64>
# [!] 0x41a44: READING 0x603e - 0x6040 (buf)
# [!]   <BV16 Reverse(buf[3983:3968])>
# [+] {"time": "2025-07-08 10:00:52,368", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24638, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_274_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_281_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268839, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_284_64", 64]}]}, {"op": "BVV", "args": [4, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603e
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))> [[<BV16 msg.hdr.c_274_16>]]
# [*]     0x4155a: <Bool cap - off_281_64 >= 0x1> [[<BV64 off_281_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.a1 == 0> [[<BV8 buf.a1>]]
# [*]     0x41a27: <Bool cap - off_284_64 >= 0x4> [[<BV64 off_284_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [*] Partial access to known field
# [*]   address:    0x603e
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))> [[<BV16 msg.hdr.c_274_16>]]
# [*]     0x4155a: <Bool cap - off_281_64 >= 0x1> [[<BV64 off_281_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.a1 == 0> [[<BV8 buf.a1>]]
# [*]     0x41a27: <Bool cap - off_284_64 >= 0x4> [[<BV64 off_284_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x416b9: READING 0x6031 - 0x6032 (buf.a2)
# [!]   <BV8 buf.a2>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_282_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_282_64>
# [!] 0x41577: READING 0x6129 - 0x612a (buf)
# [!]   <BV8 buf[2103:2096]>
# [+] {"time": "2025-07-08 10:00:53,677", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24873, "size": 1, "pc": 267639, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_274_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_281_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.a1", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.a2", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 235, "end": 236, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x6129
# [*]   size:       1
# [*]   pc:         0x41577
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))> [[<BV16 msg.hdr.c_274_16>]]
# [*]     0x4155a: <Bool cap - off_281_64 >= 0x1> [[<BV64 off_281_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.a1 != 0> [[<BV8 buf.a1>]]
# [*]     0x415ab: <Bool (buf.a1 & 192) == 192> [[<BV8 buf.a1>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.a1)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.a2))) >= 0x1> [[<BV8 buf.a2>, <BV8 buf.a1>, <BV64 cap>]]
# [*]   field:      buf[235:236]
# [*] Partial access to known field
# [*]   address:    0x6129
# [*]   size:       1
# [*]   pc:         0x41577
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))> [[<BV16 msg.hdr.c_274_16>]]
# [*]     0x4155a: <Bool cap - off_281_64 >= 0x1> [[<BV64 off_281_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.a1 != 0> [[<BV8 buf.a1>]]
# [*]     0x415ab: <Bool (buf.a1 & 192) == 192> [[<BV8 buf.a1>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.a1)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.a2))) >= 0x1> [[<BV8 buf.a2>, <BV8 buf.a1>, <BV64 cap>]]
# [*]   field:      buf[235:236]
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x416b9: READING 0x6032 - 0x6033 (buf.b)
# [!]   <BV8 buf.b[15:8]>
# [+] {"time": "2025-07-08 10:00:55,336", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24626, "size": 1, "pc": 267961, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_274_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_281_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.a1", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__add__", "args": [{"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}, {"op": "BVV", "args": [1, 64]}]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.a1", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940 ...
# [*] Partial access to known field
# [*]   address:    0x6032
# [*]   size:       1
# [*]   pc:         0x416b9
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))> [[<BV16 msg.hdr.c_274_16>]]
# [*]     0x4155a: <Bool cap - off_281_64 >= 0x1> [[<BV64 off_281_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.a1 != 0> [[<BV8 buf.a1>]]
# [*]     0x415ab: <Bool (buf.a1 & 192) != 192> [[<BV8 buf.a1>]]
# [*]     0x4161c: <Bool (buf.a1 & 192) == 0> [[<BV8 buf.a1>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.a1)) < 0xff then 1 else 0) | (if buf.a1 == 255 then 1 else 0)) != 0> [[<BV8 buf.a1>]]
# [*]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. <...>)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>, <BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>]]
# [*]     0x416cb: <Bool (SignExt(24, buf.a2) - 0x61[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x61[31:31])) != 0> [[<BV8 buf.a2>]]
# [*]     0x416f5: <Bool (SignExt(24, buf.a2) - 0x30[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x30[31:31])) != 0> [[<BV8 buf.a2>]]
# [*]     0x4172b: <Bool ((0#7 .. (if SignExt(24, buf.a2) == 0x2d then 1 else 0)) & 1) != 0> [[<BV8 buf.a2>]]
# [*]     0x416a4: <Bool 0x1 < (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>]]
# [*]   field:      buf.b[0:1]
# [*] Partial access to known field
# [*]   address:    0x6032
# [*]   size:       1
# [*]   pc:         0x416b9
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))> [[<BV16 msg.hdr.c_274_16>]]
# [*]     0x4155a: <Bool cap - off_281_64 >= 0x1> [[<BV64 off_281_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.a1 != 0> [[<BV8 buf.a1>]]
# [*]     0x415ab: <Bool (buf.a1 & 192) != 192> [[<BV8 buf.a1>]]
# [*]     0x4161c: <Bool (buf.a1 & 192) == 0> [[<BV8 buf.a1>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.a1)) < 0xff then 1 else 0) | (if buf.a1 == 255 then 1 else 0)) != 0> [[<BV8 buf.a1>]]
# [*]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. <...>)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>, <BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>]]
# [*]     0x416cb: <Bool (SignExt(24, buf.a2) - 0x61[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x61[31:31])) != 0> [[<BV8 buf.a2>]]
# [*]     0x416f5: <Bool (SignExt(24, buf.a2) - 0x30[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x30[31:31])) != 0> [[<BV8 buf.a2>]]
# [*]     0x4172b: <Bool ((0#7 .. (if SignExt(24, buf.a2) == 0x2d then 1 else 0)) & 1) != 0> [[<BV8 buf.a2>]]
# [*]     0x416a4: <Bool 0x1 < (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>]]
# [*]   field:      buf.b[0:1]
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_282_64>
# [!] 0x416b9: READING 0x6032 - 0x6033 (buf.b)
# [!]   <BV8 buf.b[15:8]>
# [+] {"time": "2025-07-08 10:00:55,853", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24626, "size": 1, "pc": 267961, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_274_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_281_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.a1", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__add__", "args": [{"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}, {"op": "BVV", "args": [1, 64]}]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.a1", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940 ...
# [*] Partial access to known field
# [*]   address:    0x6032
# [*]   size:       1
# [*]   pc:         0x416b9
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))> [[<BV16 msg.hdr.c_274_16>]]
# [*]     0x4155a: <Bool cap - off_281_64 >= 0x1> [[<BV64 off_281_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.a1 != 0> [[<BV8 buf.a1>]]
# [*]     0x415ab: <Bool (buf.a1 & 192) != 192> [[<BV8 buf.a1>]]
# [*]     0x4161c: <Bool (buf.a1 & 192) == 0> [[<BV8 buf.a1>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.a1)) < 0xff then 1 else 0) | (if buf.a1 == 255 then 1 else 0)) != 0> [[<BV8 buf.a1>]]
# [*]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. <...>)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>, <BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>]]
# [*]     0x416cb: <Bool (SignExt(24, buf.a2) - 0x61[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x61[31:31])) != 0> [[<BV8 buf.a2>]]
# [*]     0x416f5: <Bool (SignExt(24, buf.a2) - 0x30[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x30[31:31])) == 0> [[<BV8 buf.a2>]]
# [*]     0x4172b: <Bool ((0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, <...>) == 0x2d then 1 else 0)) & 1)) != 0x0> [[<BV8 buf.a2>]]
# [*]     0x416a4: <Bool 0x1 < (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>]]
# [*]   field:      buf.b[0:1]
# [*] Partial access to known field
# [*]   address:    0x6032
# [*]   size:       1
# [*]   pc:         0x416b9
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))> [[<BV16 msg.hdr.c_274_16>]]
# [*]     0x4155a: <Bool cap - off_281_64 >= 0x1> [[<BV64 off_281_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.a1 != 0> [[<BV8 buf.a1>]]
# [*]     0x415ab: <Bool (buf.a1 & 192) != 192> [[<BV8 buf.a1>]]
# [*]     0x4161c: <Bool (buf.a1 & 192) == 0> [[<BV8 buf.a1>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.a1)) < 0xff then 1 else 0) | (if buf.a1 == 255 then 1 else 0)) != 0> [[<BV8 buf.a1>]]
# [*]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. <...>)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>, <BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>]]
# [*]     0x416cb: <Bool (SignExt(24, buf.a2) - 0x61[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x61[31:31])) != 0> [[<BV8 buf.a2>]]
# [*]     0x416f5: <Bool (SignExt(24, buf.a2) - 0x30[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x30[31:31])) == 0> [[<BV8 buf.a2>]]
# [*]     0x4172b: <Bool ((0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, <...>) == 0x2d then 1 else 0)) & 1)) != 0x0> [[<BV8 buf.a2>]]
# [*]     0x416a4: <Bool 0x1 < (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>]]
# [*]   field:      buf.b[0:1]
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_282_64>
# [!] 0x416b9: READING 0x6032 - 0x6033 (buf.b)
# [!]   <BV8 buf.b[15:8]>
# [+] {"time": "2025-07-08 10:00:56,165", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24626, "size": 1, "pc": 267961, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_274_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_281_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.a1", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.a1", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__add__", "args": [{"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.one", 8]}]}]}]}, {"op": "BVV", "args": [1, 64]}]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.a1", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940 ...
# [*] Partial access to known field
# [*]   address:    0x6032
# [*]   size:       1
# [*]   pc:         0x416b9
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))> [[<BV16 msg.hdr.c_274_16>]]
# [*]     0x4155a: <Bool cap - off_281_64 >= 0x1> [[<BV64 off_281_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1> [[<BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.a1 != 0> [[<BV8 buf.a1>]]
# [*]     0x415ab: <Bool (buf.a1 & 192) != 192> [[<BV8 buf.a1>]]
# [*]     0x4161c: <Bool (buf.a1 & 192) == 0> [[<BV8 buf.a1>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.a1)) < 0xff then 1 else 0) | (if buf.a1 == 255 then 1 else 0)) != 0> [[<BV8 buf.a1>]]
# [*]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. <...>)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>, <BV8 buf.one>, <BV8 buf.g>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>]]
# [*]     0x416cb: <Bool (SignExt(24, buf.a2) - 0x61[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x61[31:31])) == 0> [[<BV8 buf.a2>]]
# [*]     0x416f5: <Bool (SignExt(24, buf.a2) - 0x30[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x30[31:31])) == 0> [[<BV8 buf.a2>]]
# [*]     0x4172b: <Bool ((0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, <...>) == 0x2d then 1 else 0)) & 1)) != 0x0> [[<BV8 buf.a2>]]
# [*]     0x416a4: <Bool 0x1 < (0#32 .. (0#24 .. buf.a1))> [[<BV8 buf.a1>]]
# [*]   field:      buf.b[0:1]
# [*] Partial access to known field
# [*]   address:    0x6032
# [*]   size:       1
# ...
# [!]     0x416a4: <Bool 0x1 >= (0#32 .. (0#24 .. buf.a1))>
# [!]     0x4155a: <Bool cap - ((0#32 .. (0#24 .. buf.a1)) + (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= 0x1>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_270_16 = <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6031: buf.a1 = <BV8 buf.a1>
# [!]     0x6230 - 0x6238: off_284_64 = <BV64 off_283_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_282_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_266_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_267_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_268_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_272_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_274_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_276_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_278_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_280_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x603e: buf.one = <BV8 buf.one>
# [!]     0x603e - 0x6230: buf = <BV3984 buf>
# [!]     0x6031 - 0x6032: buf.a2 = <BV8 buf.a2>
# [!] State at <BV64 0x41577>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))>
# [!]     0x4155a: <Bool cap - off_281_64 >= 0x1>
# [!]     0x41592: <Bool buf.g != 0>
# [!]     0x415ab: <Bool (buf.g & 192) == 192>
# [!]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1>
# [!]     0x41592: <Bool buf.a1 != 0>
# [!]     0x415ab: <Bool (buf.a1 & 192) != 192>
# [!]     0x4161c: <Bool (buf.a1 & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.a1)) < 0xff then 1 else 0) | (if buf.a1 == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. buf.a1))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.a1))>
# [!]     0x416cb: <Bool (SignExt(24, buf.a2) - 0x61[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x61[31:31])) == 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.a2) - 0x30[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.a2) - 0x7a[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x7a[31:31]) | (if SignExt(24, buf.a2) == 0x7a then 1 else 0)) & 1) | (0#24 .. (0#7 .. SignExt(24, buf.a2) - 0x39[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x39[31:31]) | (if SignExt(24, buf.a2) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.a2) == 0x2d then 1 else 0)) & 1)) != 0x0>
# [!]     0x416a4: <Bool 0x1 >= (0#32 .. (0#24 .. buf.a1))>
# [!]     0x4155a: <Bool cap - ((0#32 .. (0#24 .. buf.a1)) + (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= 0x1>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_270_16 = <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6031: buf.a1 = <BV8 buf.a1>
# [!]     0x6230 - 0x6238: off_284_64 = <BV64 off_283_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_282_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_266_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_267_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_268_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_272_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_274_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_276_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_278_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_280_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x603e: buf.one = <BV8 buf.one>
# [!]     0x603e - 0x6230: buf = <BV3984 buf>
# [!]     0x6031 - 0x6032: buf.a2 = <BV8 buf.a2>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))>
# [!]     0x4155a: <Bool cap - off_281_64 >= 0x1>
# [!]     0x41592: <Bool buf.g != 0>
# [!]     0x415ab: <Bool (buf.g & 192) == 192>
# [!]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1>
# [!]     0x41592: <Bool buf.a1 != 0>
# [!]     0x415ab: <Bool (buf.a1 & 192) != 192>
# [!]     0x4161c: <Bool (buf.a1 & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.a1)) < 0xff then 1 else 0) | (if buf.a1 == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. buf.a1))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.a1))>
# [!]     0x416cb: <Bool (SignExt(24, buf.a2) - 0x61[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.a2) - 0x30[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x30[31:31])) != 0>
# [!]     0x4172b: <Bool ((0#7 .. (if SignExt(24, buf.a2) == 0x2d then 1 else 0)) & 1) == 0>
# [!]     0x421bd: <Bool msg.a_282_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_270_16 = <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6031: buf.a1 = <BV8 buf.a1>
# [!]     0x6230 - 0x6238: off_284_64 = <BV64 off_283_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_289_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_266_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_267_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_268_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_272_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_274_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_276_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_278_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_280_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x603e: buf.one = <BV8 buf.one>
# [!]     0x603e - 0x6230: buf = <BV3984 buf>
# [!]     0x6031 - 0x6032: buf.a2 = <BV8 buf.a2>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))>
# [!]     0x4155a: <Bool cap - off_281_64 >= 0x1>
# [!]     0x41592: <Bool buf.g != 0>
# [!]     0x415ab: <Bool (buf.g & 192) == 192>
# [!]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1>
# [!]     0x41592: <Bool buf.a1 != 0>
# [!]     0x415ab: <Bool (buf.a1 & 192) != 192>
# [!]     0x4161c: <Bool (buf.a1 & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.a1)) < 0xff then 1 else 0) | (if buf.a1 == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. buf.a1))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.a1))>
# [!]     0x416cb: <Bool (SignExt(24, buf.a2) - 0x61[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.a2) - 0x30[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.a2) - 0x39[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x39[31:31]) | (if SignExt(24, buf.a2) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.a2) == 0x2d then 1 else 0)) & 1)) == 0x0>
# [!]     0x421bd: <Bool msg.a_282_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_270_16 = <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6031: buf.a1 = <BV8 buf.a1>
# [!]     0x6230 - 0x6238: off_284_64 = <BV64 off_283_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_290_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_266_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_267_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_268_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_272_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_274_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_276_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_278_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_280_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x603e: buf.one = <BV8 buf.one>
# [!]     0x603e - 0x6230: buf = <BV3984 buf>
# [!]     0x6031 - 0x6032: buf.a2 = <BV8 buf.a2>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_274_16))>
# [!]     0x4155a: <Bool cap - off_281_64 >= 0x1>
# [!]     0x41592: <Bool buf.g != 0>
# [!]     0x415ab: <Bool (buf.g & 192) == 192>
# [!]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) >= 0x1>
# [!]     0x41592: <Bool buf.a1 != 0>
# [!]     0x415ab: <Bool (buf.a1 & 192) != 192>
# [!]     0x4161c: <Bool (buf.a1 & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.a1)) < 0xff then 1 else 0) | (if buf.a1 == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - ((((0#32 .. (0#24 .. buf.g)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.one))) + 0x1) >= (0#32 .. (0#24 .. buf.a1))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.a1))>
# [!]     0x416cb: <Bool (SignExt(24, buf.a2) - 0x61[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x61[31:31])) == 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.a2) - 0x30[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.a2) - 0x7a[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x7a[31:31]) | (if SignExt(24, buf.a2) == 0x7a then 1 else 0)) & 1) | (0#24 .. (0#7 .. SignExt(24, buf.a2) - 0x39[31:31] ^ (SignExt(24, buf.a2)[31:31] ^ 0) & (SignExt(24, buf.a2)[31:31] ^ SignExt(24, buf.a2) - 0x39[31:31]) | (if SignExt(24, buf.a2) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.a2) == 0x2d then 1 else 0)) & 1)) == 0x0>
# [!]     0x421bd: <Bool msg.a_282_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_270_16 = <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6031: buf.a1 = <BV8 buf.a1>
# [!]     0x6230 - 0x6238: off_284_64 = <BV64 off_283_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_291_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_266_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_267_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_268_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_272_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_274_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_276_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_278_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_280_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x603e: buf.one = <BV8 buf.one>
# [!]     0x603e - 0x6230: buf = <BV3984 buf>
# [!]     0x6031 - 0x6032: buf.a2 = <BV8 buf.a2>

# %% [markdown]
# And iterating a few times:

# %%
reinitialize_demo()
add_malloc_free_models()
gdata[4] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.c1")
gdata[5] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.c2")
gdata[50] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.b1")
gdata[51] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.b2")
gdata[56] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.e1")
gdata[57] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.e2")
gdata[61] = smallworld.state.SymbolicValue(1, None, None, "buf.1")
gdata[62] = smallworld.state.SymbolicValue(1, None, None, "buf.2")
gdata[63] = smallworld.state.SymbolicValue(1, None, None, "buf.3")
gdata[64] = smallworld.state.SymbolicValue(1, None, None, "buf.4")
gdata[65] = smallworld.state.SymbolicValue(495, None, None, "buf.rest")
# Add constraint to buf.g
machine.add_constraint(
    claripy.UGT(claripy.BVS("buf.g", 8, explicit_name=True), claripy.BVV(64, 8))
)

analyze_with_timeout(machine, analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-07-08 10:19:52,455", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:19:52,457", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:19:52,457", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:19:52,460", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x20000 - 0x30000
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7a130797f280> := msg.hdr.a
# [+] {"time": "2025-07-08 10:19:52,470", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6031: <smallworld.state.state.SymbolicValue object at 0x7a1307991c30> := buf.a1
# [+] {"time": "2025-07-08 10:19:52,471", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 1, "label": "buf.a1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 10:19:52,473", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a1309287400> := msg.a
# [+] {"time": "2025-07-08 10:19:52,477", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.b
# [+] {"time": "2025-07-08 10:19:52,478", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.c
# [+] {"time": "2025-07-08 10:19:52,479", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.d
# [+] {"time": "2025-07-08 10:19:52,480", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7a130797f2e0> := msg.hdr.b
# [+] {"time": "2025-07-08 10:19:52,481", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6005: <smallworld.state.state.SymbolicValue object at 0x7a1306e82080> := buf.msg.hdr.c1
# [+] {"time": "2025-07-08 10:19:52,482", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 1, "label": "buf.msg.hdr.c1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7a130797e980> := msg.hdr.d
# [+] {"time": "2025-07-08 10:19:52,483", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7a130797e9e0> := msg.hdr.e
# [+] {"time": "2025-07-08 10:19:52,484", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7a130797ea40> := msg.hdr.f
# [+] {"time": "2025-07-08 10:19:52,485", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a130797eaa0> := msg.hdr.unused
# [+] {"time": "2025-07-08 10:19:52,486", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6033: <smallworld.state.state.SymbolicValue object at 0x7a1306f6c070> := buf.msg.hdr.b1
# [+] {"time": "2025-07-08 10:19:52,487", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 1, "label": "buf.msg.hdr.b1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x7a1307651f00> := buf.msg.hdr.c
# [+] {"time": "2025-07-08 10:19:52,489", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x7a13093b7ca0> := buf.d
# [+] {"time": "2025-07-08 10:19:52,490", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x6039: <smallworld.state.state.SymbolicValue object at 0x7a1306e834f0> := buf.msg.hdr.e1
# [+] {"time": "2025-07-08 10:19:52,491", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 1, "label": "buf.msg.hdr.e1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7a130784bac0> := buf.f
# [+] {"time": "2025-07-08 10:19:52,492", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x7a130780d180> := buf.g
# [+] {"time": "2025-07-08 10:19:52,493", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.g", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x603e: <smallworld.state.state.SymbolicValue object at 0x7a1306e80c70> := buf.1
# [+] {"time": "2025-07-08 10:19:52,494", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 1, "label": "buf.1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603e - 0x603f: <smallworld.state.state.SymbolicValue object at 0x7a1306e80c10> := buf.2
# [+] {"time": "2025-07-08 10:19:52,495", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24638, "size": 1, "label": "buf.2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6031 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7a1309191510> := buf.a2
# [+] {"time": "2025-07-08 10:19:52,496", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24625, "size": 1, "label": "buf.a2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6005 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7a13093b77c0> := buf.msg.hdr.c2
# [+] {"time": "2025-07-08 10:19:52,497", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24581, "size": 1, "label": "buf.msg.hdr.c2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6039 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7a1306d96da0> := buf.msg.hdr.e2
# [+] {"time": "2025-07-08 10:19:52,498", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24633, "size": 1, "label": "buf.msg.hdr.e2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603f - 0x6040: <smallworld.state.state.SymbolicValue object at 0x7a1306e816c0> := buf.3
# [+] {"time": "2025-07-08 10:19:52,498", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24639, "size": 1, "label": "buf.3", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6040 - 0x6041: <smallworld.state.state.SymbolicValue object at 0x7a1306e82530> := buf.4
# [+] {"time": "2025-07-08 10:19:52,499", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24640, "size": 1, "label": "buf.4", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6041 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a1306e83130> := buf.rest
# [+] {"time": "2025-07-08 10:19:52,501", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24641, "size": 495, "label": "buf.rest", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6033 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7a1306e821d0> := buf.msg.hdr.b2
# [+] {"time": "2025-07-08 10:19:52,501", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24627, "size": 1, "label": "buf.msg.hdr.b2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a1306d96920>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a1306d96920>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_396_64>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_396_64>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_396_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_396_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_398_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_398_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_398_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_398_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_399_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_399_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_399_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_399_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_401_64>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_401_64>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_401_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_401_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_403_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_403_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_403_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_403_64 + 0x2>
# [!]   Write to entire field off
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field buf.msg.hdr.c not known
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_405_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_405_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf.g)
# [!]   <BV8 buf.g>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_405_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_405_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x415c5: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_407_64>
# [!] 0x415c8: READING 0x603d - 0x603e (buf.1)
# [!]   <BV8 buf.1>
# [!] 0x415d7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_407_64>
# [!] 0x415de: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_407_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_413_64>
# [!] 0x41577: READING 0x6030 - 0x6031 (buf.a1)
# [!]   <BV8 buf.a1>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_413_64>
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_413_64>
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_413_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x415c8: READING 0x6031 - 0x6032 (buf.a2)
# [!]   <BV8 buf.a2>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_400_16>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x416b9: READING 0x6031 - 0x6032 (buf.a2)
# [!]   <BV8 buf.a2>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_400_16
# [*] Concretize them to continue analysis
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_420_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_420_64>
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_420_64>
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_420_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x416b9: READING 0x6032 - 0x6033 (buf.msg.hdr.b1)
# [!]   <BV8 buf.msg.hdr.b1>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x416b9: READING 0x6032 - 0x6033 (buf.msg.hdr.b1)
# [!]   <BV8 buf.msg.hdr.b1>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x416b9: READING 0x6032 - 0x6033 (buf.msg.hdr.b1)
# [!]   <BV8 buf.msg.hdr.b1>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_400_16>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_406_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_427_64>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_400_16
# [*] Concretize them to continue analysis
# [!] 0x41577: READING 0x6032 - 0x6033 (buf.msg.hdr.b1)
# [!]   <BV8 buf.msg.hdr.b1>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64 + 0x2>
# [!]   Write to entire field off
# Analysis timeout

# %% [markdown]
# We are again asked to concretize a value, this time `msg.hdr.d`.

# %%
gdata[54] = smallworld.state.BytesValue(b"\x00\x01", "buf.msg.hdr.d")
reinitialize_demo()
add_malloc_free_models()
machine.add_constraint(
    claripy.UGT(claripy.BVS("buf.g", 8, explicit_name=True), claripy.BVV(64, 8))
)
analyze_with_timeout(machine, analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-07-08 10:25:11,566", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:25:11,567", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:25:11,568", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-07-08 10:25:11,568", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x40000 - 0x46000
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x20000 - 0x30000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7a130797f280> := msg.hdr.a
# [+] {"time": "2025-07-08 10:25:11,576", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6031: <smallworld.state.state.SymbolicValue object at 0x7a1307991c30> := buf.a1
# [+] {"time": "2025-07-08 10:25:11,577", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 1, "label": "buf.a1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 10:25:11,578", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a1309287400> := msg.a
# [+] {"time": "2025-07-08 10:25:11,579", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.b
# [+] {"time": "2025-07-08 10:25:11,580", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.c
# [+] {"time": "2025-07-08 10:25:11,581", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.d
# [+] {"time": "2025-07-08 10:25:11,582", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7a130797f2e0> := msg.hdr.b
# [+] {"time": "2025-07-08 10:25:11,583", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6005: <smallworld.state.state.SymbolicValue object at 0x7a1306e82080> := buf.msg.hdr.c1
# [+] {"time": "2025-07-08 10:25:11,584", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 1, "label": "buf.msg.hdr.c1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7a130797e980> := msg.hdr.d
# [+] {"time": "2025-07-08 10:25:11,585", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7a130797e9e0> := msg.hdr.e
# [+] {"time": "2025-07-08 10:25:11,586", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7a130797ea40> := msg.hdr.f
# [+] {"time": "2025-07-08 10:25:11,587", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a130797eaa0> := msg.hdr.unused
# [+] {"time": "2025-07-08 10:25:11,588", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6033: <smallworld.state.state.SymbolicValue object at 0x7a1306f6c070> := buf.msg.hdr.b1
# [+] {"time": "2025-07-08 10:25:11,589", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 1, "label": "buf.msg.hdr.b1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x7a1307651f00> := buf.msg.hdr.c
# [+] {"time": "2025-07-08 10:25:11,590", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.BytesValue object at 0x7a13068ed330> := buf.msg.hdr.d
# [+] {"time": "2025-07-08 10:25:11,592", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x6039: <smallworld.state.state.SymbolicValue object at 0x7a1306e834f0> := buf.msg.hdr.e1
# [+] {"time": "2025-07-08 10:25:11,592", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 1, "label": "buf.msg.hdr.e1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7a130784bac0> := buf.f
# [+] {"time": "2025-07-08 10:25:11,594", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x7a130780d180> := buf.g
# [+] {"time": "2025-07-08 10:25:11,595", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.g", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x603e: <smallworld.state.state.SymbolicValue object at 0x7a1306e80c70> := buf.1
# [+] {"time": "2025-07-08 10:25:11,596", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 1, "label": "buf.1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603e - 0x603f: <smallworld.state.state.SymbolicValue object at 0x7a1306e80c10> := buf.2
# [+] {"time": "2025-07-08 10:25:11,597", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24638, "size": 1, "label": "buf.2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6031 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7a1309191510> := buf.a2
# [+] {"time": "2025-07-08 10:25:11,599", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24625, "size": 1, "label": "buf.a2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6005 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7a13093b77c0> := buf.msg.hdr.c2
# [+] {"time": "2025-07-08 10:25:11,599", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24581, "size": 1, "label": "buf.msg.hdr.c2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6039 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7a1306d96da0> := buf.msg.hdr.e2
# [+] {"time": "2025-07-08 10:25:11,601", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24633, "size": 1, "label": "buf.msg.hdr.e2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603f - 0x6040: <smallworld.state.state.SymbolicValue object at 0x7a1306e816c0> := buf.3
# [+] {"time": "2025-07-08 10:25:11,602", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24639, "size": 1, "label": "buf.3", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6040 - 0x6041: <smallworld.state.state.SymbolicValue object at 0x7a1306e82530> := buf.4
# [+] {"time": "2025-07-08 10:25:11,603", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24640, "size": 1, "label": "buf.4", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6041 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a1306e83130> := buf.rest
# [+] {"time": "2025-07-08 10:25:11,604", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24641, "size": 495, "label": "buf.rest", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6033 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7a1306e821d0> := buf.msg.hdr.b2
# [+] {"time": "2025-07-08 10:25:11,605", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24627, "size": 1, "label": "buf.msg.hdr.b2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a1308b04ca0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a1308b04ca0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [+] Storing 2 bytes at 0x6036
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_463_64>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_463_64>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_463_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_463_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_465_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_465_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_465_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_465_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_466_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.msg.hdr.d)
# [!]   <BV16 Reverse(buf.msg.hdr.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_466_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.msg.hdr.d)
# [!]   <BV16 Reverse(buf.msg.hdr.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_466_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_466_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_468_64>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_468_64>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_468_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_468_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_470_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_470_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_470_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_470_64 + 0x2>
# [!]   Write to entire field off
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field buf.msg.hdr.c not known
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_472_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_472_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf.g)
# [!]   <BV8 buf.g>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_472_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_472_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x415c5: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_474_64>
# [!] 0x415c8: READING 0x603d - 0x603e (buf.1)
# [!]   <BV8 buf.1>
# [!] 0x415d7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_474_64>
# [!] 0x415de: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_474_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_480_64>
# [!] 0x41577: READING 0x6030 - 0x6031 (buf.a1)
# [!]   <BV8 buf.a1>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_480_64>
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_480_64>
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_480_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x415c8: READING 0x6031 - 0x6032 (buf.a2)
# [!]   <BV8 buf.a2>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_467_16>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x416b9: READING 0x6031 - 0x6032 (buf.a2)
# [!]   <BV8 buf.a2>
# [!] malloc: Alloc'd 280 bytes at 0x20118
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.d not known
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x41f94: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x20118>
# [!]   Write to entire field msg.b
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41fbe: READING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 msg.b_484_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41fc6: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_467_16>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_488_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_488_64>
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_488_64>
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_488_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x416b9: READING 0x6032 - 0x6033 (buf.msg.hdr.b1)
# [!]   <BV8 buf.msg.hdr.b1>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x416b9: READING 0x6032 - 0x6033 (buf.msg.hdr.b1)
# [!]   <BV8 buf.msg.hdr.b1>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x416b9: READING 0x6032 - 0x6033 (buf.msg.hdr.b1)
# [!]   <BV8 buf.msg.hdr.b1>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_467_16>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_473_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_495_64>
# [!] malloc: Alloc'd 280 bytes at 0x20118
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.d not known
# [!] 0x41577: READING 0x6032 - 0x6033 (buf.msg.hdr.b1)
# [!]   <BV8 buf.msg.hdr.b1>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_475_64>
# Analysis timeout
