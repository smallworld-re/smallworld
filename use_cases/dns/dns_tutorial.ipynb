# %% [markdown]
# # Deducing Struct Layout with Symbolic Execution
# The goal of this tutorial is to determine the input format
# accepted by the test program `dns.{arch}.elf`
# without reading the source or resorting to manual RE.
#
# We'll use memory labelling to lay out a hypothetical message structure
# in our machine state, and then use `FieldDetectionAnalysis` to
# detect inconsistencies between our hypothesis and how the code accesses the data.
# By iterating this process, we will refine our hypothesis until it matches
# what the code accepts.

# %% [markdown]
# ## Setup & Installation
# Install the required packages as described in the install directions.
#
# You can build the example programs by running `make all` from this directory.
# This requires the cross-compiler toolchains installed as part of the apt dependencies;
# this analysis will work on any architecture supported by angr.
#
# Let's test this program against the example input `examples/answer.dat`:
#
# ```
# $> hexdump -C examples/answer.dat
# 00000000  ce 70 81 80 00 01 00 01  00 00 00 01 06 67 6f 6f  |.p...........goo|
# 00000010  67 6c 65 03 63 6f 6d 00  00 01 00 01 c0 0c 00 01  |gle.com.........|
# 00000020  00 01 00 00 00 d2 00 04  8e fa 41 ce 00 00 29 04  |..........A...).|
# 00000030  c4 00 00 00 00 00 1c 00  0a 00 18 cb 6e 4b 21 27  |............nK!'|
# 00000040  ca a2 eb 8f fc 9f 64 67  85 5f 7f cf 3e 38 e4 56  |......dg._..>8.V|
# 00000050  80 72 f9                                          |.r.|
# 00000053
#
# $> ./bin/dns.amd64.elf examples/answer.dat
# DNS Message:
#         TID:          ce70
#         FLAGS:        0120
#         # Questions:  1
#         # Answers:    0
#         # Auth. Rs:   0
#         # Extra Rs:   1
# Question:
#         Name:         google.com
#         Type:         1
#         Class:        1
# Record:
#         Name:
#         Type:         41
#         Class:        1232
# ```
#
# If it's not apparent yet, this program parses basic DNS messages.
# However, the exact structure accepted by the parser isn't obvious.
# We could decompile the binary and try to elicit the structure but
# we are going to use SmallWord analysis capabilites to figure it out.
#
# ## Harnessing the Parser
#
# For sanity's sake, let's assume we know that the parser is implemented in `parse_dns_msg()`,
# and that we roughly know its arguments from `main()`:
#
# - **Arg 1:** `uint8_t *` pointing to an input buffer
# - **Arg 2:** `size_t` holding its size
# - **Arg 3:** `size_t *` pointing to a value starting at zero
# - **Arg 4:** `struct *` pointing to an unknown struct
#
# Our goal for this exercise is to figure out the structure of argument 1,
# which we'll call `buf`, and argument 4, which we'll call `msg`.
#
# First, we set up some smallworld boilerplate.
# This configures logging, as well as the hinter
# that will let us see the output from our analysis.

# %%
import warnings

warnings.filterwarnings(
    "ignore", 
    message="Protobuf gencode version .* is exactly one major version older.*"
)

# %%
import logging
import pathlib

import smallworld
import smallworld.analyses.field_detection
import smallworld.analyses.unstable.angr.visitor
from smallworld.analyses.field_detection import FieldDetectionAnalysis

# Set up logging and hinting                                                                                                                                                                                                         
smallworld.logging.setup_logging(level=logging.INFO)
smallworld.hinting.setup_hinting(stream=True, verbose=True)

log = logging.getLogger("smallworld")

# %% [markdown]
# Next, we create the basic machine state, load our ELF file into a smallworld state object, and add the code to the machine.
#
# Since we don't expect a specific platform, we can use the platform definition parsed out of the ELF headers.
#
# Also, since this is the only ELF we're loading, we can use its notion of program bounds to define which memory the analysis can execute.

# %%
# Create a machine
machine = smallworld.state.Machine()

# Load the code
filepath = "bin/dns.amd64.elf"
with open(filepath, "rb") as f:
    code = smallworld.state.memory.code.Executable.from_elf(f, 0x40000)
    machine.add(code)

# Apply the code's bounds to the machine
for bound in code.bounds:
    machine.add_bound(bound[0], bound[1])

# Use the ELF's notion of the platform
platform = code.platform

 # Create the analysis; we'll need it later.
analysis = FieldDetectionAnalysis(platform)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-08-07 14:50:25,323", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:50:25,324", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:50:25,325", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:50:25,327", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}

# %%
# Create a CPU
cpu = smallworld.state.cpus.CPU.for_platform(platform)
machine.add(cpu)

# Use lief to find the address of parse_dns_message
sym = code.get_symbol_value("parse_dns_message")
cpu.rip.set(sym)

# Add a blank stack
stack = smallworld.state.memory.stack.Stack.for_platform(
    platform, 0x7FFFFFFFC000, 0x4000
)
machine.add(stack)

stack.push_integer(0x01010101, 8, None)

# Configure the stack pointer
sp = stack.get_pointer()
cpu.rsp.set(sp)

# %% [markdown]
# Now that we have the program set up, we can start to model the inputs to `parse_dns_message()`.
# We know we need a message struct, a memory buffer, and a `size_t`
# that are all passed by reference.
#
# For ease of modelling, let's just allocate them all as globals.
#
# To start, we'll allocate `buf` and `msg` as blank swaths of memory.
# As we learn more about their internal structure from the analysis,
# we will come back and refine this part of our harness.

# %%
# Configure somewhere for arguments to live                                                                                                                                                                                          
gdata = smallworld.state.memory.Memory(0x6000, 0x1000)
machine.add(gdata)
# DNS message struct                                                                                                                                                                                                                 
# Sort of cheating that I know how big it is.                                                                                                                                                                                        
gdata[0] = smallworld.state.SymbolicValue(48, None, None, "msg")
# Input buffer                                                                                                                                                                                                                       
gdata[48] = smallworld.state.SymbolicValue(512, None, None, "buf")
# Offset into buffer                                                                                                                                                                                                                 
gdata[560] = smallworld.state.IntegerValue(0, 8, "off", False)

# %% [markdown]
# Next, we use what we know about the function signature to assign values to registers.
# We know that the first arg points to `buf`, the second is the size of `buf`,
# the third points to `off`, and the fourth points to `msg`.

# %%
# Configure arguments                                                                                                                                                                                                                
# arg 0: pointer to buf                                                                                                                                                                                                              
cpu.rdi.set(gdata.address + 48)
cpu.rdi.set_label("PTR buf")
# arg 1: buffer capacity                                                                                                                                                                                                             
cpu.rsi.set(512)
cpu.rsi.set_label("cap")
# arg 2: pointer to off                                                                                                                                                                                                              
cpu.rdx.set(gdata.address + 560)
cpu.rdx.set_label("PTR off")
# arg 3: pointer to msg                                                                                                                                                                                                              
cpu.rcx.set(gdata.address)
cpu.rcx.set_label("PTR msg")

# %% [markdown]
# At long last, we're reading to actually run our analysis.

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x782901109090> := msg
# [+] {"time": "2025-08-07 14:50:43,872", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 48, "label": "msg", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x78290110b310> := buf
# [+] {"time": "2025-08-07 14:50:43,874", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x782901109060> := off
# [+] {"time": "2025-08-07 14:50:43,875", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] 0x7fffffffc000 - 0x800000000000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7829012c7a00>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7829012c7a00>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [+] Storing 8 bytes at 0x7ffffffffff8
# [!] Self-modifying code is not always correctly optimized by PyVEX. To guarantee correctness, VEX optimizations have been disabled.
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg)
# [!]   <BV64 0x0>
# [+] {"time": "2025-08-07 14:50:44,458", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 24592, "size": 8, "pc": 269939, "guards": [], "access": "write", "label": "msg", "start": 16, "end": 24, "expr": "<BV64 0x0>", "class": "smallworld.analyses.field_detection.hints.PartialByteFieldWriteHint"}}
# [*] Partial write to known field
# [*]   address:    0x6010
# [*]   size:       8
# [*]   pc:         0x41e73
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg[16:24]
# [*]   expr:       <BV64 0x0>
# [!] <SimulationManager with 1 deadended>
# [!] []
# [!] State at <BV64 0x41e73>:
# [!]   Guards:
# [!]   Fields:
# [!]     0x6000 - 0x6030: msg = <BV384 msg>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>

# %% [markdown]
# # First Results
#
# (This code so far is collected in `dns_0.py`.)  The analysis produced by `FieldDetectionAnalysis` yields the following hint:
#
# ```
# [*] Partial write to known field
# [*]   address:    0x6010
# [*]   size:       8
# [*]   pc:         0x41e73
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg[16:24]
# [*]   expr:       <BV64 0x0>
# ```
# The code at `0x41e73` tried to write 8 bytes of zero starting 16 bytes into our `msg` buffer.
# But we defined `msg` as a 512 byte contiguous region and didn't expect to see a field.
#
# With this information in hand we can redefine `msg` as the following

# %%
gdata[0] = smallworld.state.SymbolicValue(16, None, None, "msg.unk-0x0")
gdata[16] = smallworld.state.SymbolicValue(8, None, None, "msg.a")
gdata[24] = smallworld.state.SymbolicValue(24, None, None, "msg.unk-0x18")

# %% [markdown]
# We're not sure what `msg.a` is, but we know it's very likely a field.
# We're on our way!
#
# Running our updated script gives a very similar hint to the first:

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6010: <smallworld.state.state.SymbolicValue object at 0x782938192770> := msg.unk-0x0
# [+] {"time": "2025-08-07 14:50:53,611", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 16, "label": "msg.unk-0x0", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x78290110b310> := buf
# [+] {"time": "2025-08-07 14:50:53,612", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x782901109060> := off
# [+] {"time": "2025-08-07 14:50:53,614", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x782938192f50> := msg.a
# [+] {"time": "2025-08-07 14:50:53,615", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x782901109090> := msg.unk-0x18
# [+] {"time": "2025-08-07 14:50:53,616", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 24, "label": "msg.unk-0x18", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] 0x7fffffffc000 - 0x800000000000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7829011cc040>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7829011cc040>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [+] Storing 8 bytes at 0x7ffffffffff8
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.unk-0x18)
# [!]   <BV64 0x0>
# [+] {"time": "2025-08-07 14:50:54,040", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 24600, "size": 8, "pc": 269951, "guards": [], "access": "write", "label": "msg.unk-0x18", "start": 0, "end": 8, "expr": "<BV64 0x0>", "class": "smallworld.analyses.field_detection.hints.PartialByteFieldWriteHint"}}
# [*] Partial write to known field
# [*]   address:    0x6018
# [*]   size:       8
# [*]   pc:         0x41e7f
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg.unk-0x18[0:8]
# [*]   expr:       <BV64 0x0>
# [!] <SimulationManager with 1 deadended>
# [!] []
# [!] State at <BV64 0x41e7f>:
# [!]   Guards:
# [!]   Fields:
# [!]     0x6000 - 0x6010: msg.unk-0x0 = <BV128 msg.unk-0x0>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_8_64 = <BV64 0x0>
# [!]     0x6018 - 0x6030: msg.unk-0x18 = <BV192 msg.unk-0x18>

# %% [markdown]
# Running our updated script gives a very similar hint to the first:
#
# ```
# [*] Partial write to known field
# [*]   address:    0x6018
# [*]   size:       8
# [*]   pc:         0x41e7f
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg.unk.0x18[0:8]
# [*]   expr:       <BV64 0x0>
# ```
#
# In fact, four iterations tell us the same thing;
# the program writes zero to four 8-byte fields right next to each other:

# %%
gdata[0] = smallworld.state.SymbolicValue(16, None, None, "msg.unk-0x0")
gdata[16] = smallworld.state.SymbolicValue(8, None, None, "msg.a")
gdata[24] = smallworld.state.SymbolicValue(8, None, None, "msg.b")
gdata[32] = smallworld.state.SymbolicValue(8, None, None, "msg.c")
gdata[40] = smallworld.state.SymbolicValue(8, None, None, "msg.d")

# %% [markdown]
# Some more iterations, and we start decoding `msg.unk-0x0`.

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7828ff7cbf40> := msg.unk-0x0
# [+] {"time": "2025-08-07 14:50:59,203", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 16, "label": "msg.unk-0x0", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x78290110b310> := buf
# [+] {"time": "2025-08-07 14:50:59,204", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x782901109060> := off
# [+] {"time": "2025-08-07 14:50:59,205", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7829012c6da0> := msg.a
# [+] {"time": "2025-08-07 14:50:59,206", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x78290110bd90> := msg.b
# [+] {"time": "2025-08-07 14:50:59,207", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7828ff8178b0> := msg.c
# [+] {"time": "2025-08-07 14:50:59,209", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x782901109090> := msg.d
# [+] {"time": "2025-08-07 14:50:59,210", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] 0x7fffffffc000 - 0x800000000000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7828ff817f10>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7828ff817f10>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [+] Storing 8 bytes at 0x7ffffffffff8
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf)
# [!]   <BV16 Reverse(buf[4095:4080])>
# [+] {"time": "2025-08-07 14:51:00,189", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24624, "size": 2, "pc": 268304, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x6030
# [*]   size:       2
# [*]   pc:         0x41810
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] <SimulationManager with 1 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41810>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6010: msg.unk-0x0 = <BV128 msg.unk-0x0>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_16_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_17_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_18_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_19_64 = <BV64 0x0>

# %% [markdown]
# Iterating on this process we find that we have multiple 2 byte regions which we identify as parts of `msg.hdr`, since we suspect it's the part of the struct representing the DNS header.  The information in the final 4 bytes of this region are never referenced.  We leave them as a final 4 byte region we call `msg.hdr.unused`:

# %%
gdata[0] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.a")
gdata[2] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.b")
gdata[4] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.c")
gdata[6] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.d")
gdata[8] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.e")
gdata[10] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.f")
gdata[12] = smallworld.state.SymbolicValue(4, None, None, "msg.hdr.unused")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7828ff855bd0> := msg.hdr.a
# [+] {"time": "2025-08-07 14:51:04,310", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x78290110b310> := buf
# [+] {"time": "2025-08-07 14:51:04,311", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x782901109060> := off
# [+] {"time": "2025-08-07 14:51:04,314", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7829012c6da0> := msg.a
# [+] {"time": "2025-08-07 14:51:04,316", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x78290110bd90> := msg.b
# [+] {"time": "2025-08-07 14:51:04,318", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7828ff8178b0> := msg.c
# [+] {"time": "2025-08-07 14:51:04,321", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x782901109090> := msg.d
# [+] {"time": "2025-08-07 14:51:04,323", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7828ff817fd0> := msg.hdr.b
# [+] {"time": "2025-08-07 14:51:04,324", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7828ff7cbf40> := msg.hdr.c
# [+] {"time": "2025-08-07 14:51:04,325", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7828ff817e80> := msg.hdr.d
# [+] {"time": "2025-08-07 14:51:04,326", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3b50> := msg.hdr.e
# [+] {"time": "2025-08-07 14:51:04,328", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3ac0> := msg.hdr.f
# [+] {"time": "2025-08-07 14:51:04,329", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7828ff8b55d0> := msg.hdr.unused
# [+] {"time": "2025-08-07 14:51:04,331", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] 0x7fffffffc000 - 0x800000000000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7828ff8b5000>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7828ff8b5000>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [+] Storing 8 bytes at 0x7ffffffffff8
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf)
# [!]   <BV16 Reverse(buf[4095:4080])>
# [+] {"time": "2025-08-07 14:51:05,542", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24624, "size": 2, "pc": 268304, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x6030
# [*]   size:       2
# [*]   pc:         0x41810
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] <SimulationManager with 1 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41810>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a = <BV16 msg.hdr.a>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_34_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_35_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_36_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_37_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b = <BV16 msg.hdr.b>
# [!]     0x6004 - 0x6006: msg.hdr.c = <BV16 msg.hdr.c>
# [!]     0x6006 - 0x6008: msg.hdr.d = <BV16 msg.hdr.d>
# [!]     0x6008 - 0x600a: msg.hdr.e = <BV16 msg.hdr.e>
# [!]     0x600a - 0x600c: msg.hdr.f = <BV16 msg.hdr.f>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>

# %% [markdown]
# Repeating this process for `buf` we can further identify regions which we summarize as:

# %%
gdata[48] = smallworld.state.SymbolicValue(2, None, None, "buf.a")
gdata[50] = smallworld.state.SymbolicValue(2, None, None, "buf.b")
gdata[52] = smallworld.state.SymbolicValue(2, None, None, "buf.c")
gdata[54] = smallworld.state.SymbolicValue(2, None, None, "buf.d")
gdata[56] = smallworld.state.SymbolicValue(2, None, None, "buf.e")
gdata[58] = smallworld.state.SymbolicValue(2, None, None, "buf.f")
gdata[60] = smallworld.state.SymbolicValue(500, None, None, "buf")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7828ff855bd0> := msg.hdr.a
# [+] {"time": "2025-08-07 14:51:08,390", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4b80> := buf.a
# [+] {"time": "2025-08-07 14:51:08,392", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x782901109060> := off
# [+] {"time": "2025-08-07 14:51:08,392", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7829012c6da0> := msg.a
# [+] {"time": "2025-08-07 14:51:08,394", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x78290110bd90> := msg.b
# [+] {"time": "2025-08-07 14:51:08,396", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7828ff8178b0> := msg.c
# [+] {"time": "2025-08-07 14:51:08,396", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x782901109090> := msg.d
# [+] {"time": "2025-08-07 14:51:08,398", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7828ff817fd0> := msg.hdr.b
# [+] {"time": "2025-08-07 14:51:08,398", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7828ff7cbf40> := msg.hdr.c
# [+] {"time": "2025-08-07 14:51:08,399", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7828ff817e80> := msg.hdr.d
# [+] {"time": "2025-08-07 14:51:08,400", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3b50> := msg.hdr.e
# [+] {"time": "2025-08-07 14:51:08,402", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3ac0> := msg.hdr.f
# [+] {"time": "2025-08-07 14:51:08,403", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7828ff8b55d0> := msg.hdr.unused
# [+] {"time": "2025-08-07 14:51:08,404", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7828ff8b47c0> := buf.b
# [+] {"time": "2025-08-07 14:51:08,405", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x78290110b310> := buf.c
# [+] {"time": "2025-08-07 14:51:08,406", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x782901109150> := buf.d
# [+] {"time": "2025-08-07 14:51:08,408", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4a00> := buf.e
# [+] {"time": "2025-08-07 14:51:08,410", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4bb0> := buf.f
# [+] {"time": "2025-08-07 14:51:08,411", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4be0> := buf
# [+] {"time": "2025-08-07 14:51:08,412", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] 0x7fffffffc000 - 0x800000000000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7828ff7926e0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7828ff7926e0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [+] Storing 8 bytes at 0x7ffffffffff8
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_67_16>
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x1076>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_63_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_74_64 = <BV64 off_72_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_58_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_59_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_60_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_61_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_65_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_67_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_69_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_71_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_73_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# The work above is summarized in `dns_1.py`.

# %% [markdown]
# # Adding malloc
#
# Notice that the `FieldDetectionAnalysis` routine no longer provides information about a partial access to a known field, so execution continues.  The last successful read is reported to be at instruction `0x41ed2`, and that the analysis ends there with the last known good state being reported as:
#
# ```
# [!] State at <BV64 0x1076>:
# ```
#
# We loaded our ELF at 0x40000 so something's way off.
# If we disassemble the code and look around 0x1ed2 (which is 0x41ed2 minus the loading address 0x40000) we find:
#
# ```
# $> objdump -d -R ./bin/dns.amd64.elf
# ...
#     1ed2:       0f b7 40 04             movzwl 0x4(%rax),%eax
#     1ed6:       48 69 f8 08 01 00 00    imul   $0x108,%rax,%rdi
#     1edd:       e8 8e f1 ff ff          call   1070 <malloc@plt>
# ...
# ```
#
# This is an external call to `malloc()` which we have not loaded.
#
# We have not yet discussed how to handle an external call like this.  One strategey would be to stub out `malloc()` and carry on.  Howerver, we would
# like to know what is happening inside the heap-allocated buffers as well.
# Luckily, `FieldDetectionAnalysis` comes with a malloc model.
# Let's update our harness:

# %% [markdown]
# Note: At this point we recreate our machine so any changes we made along the way are reset.

# %%
def reinitialize_demo():
    # reinitializing outside of this routine
    global machine
    global platform
    global analysis
    global cpu
    global sym
    global stack
    global sp
    global code


    # Create a machine
    machine = smallworld.state.Machine()

    # Load the code
    filepath = "bin/dns.amd64.elf"
    with open(filepath, "rb") as f:
        code = smallworld.state.memory.code.Executable.from_elf(f, 0x40000)
        machine.add(code)

    # Apply the code's bounds to the machine
    for bound in code.bounds:
       machine.add_bound(bound[0], bound[1])

    # Use the ELF's notion of the platform
    platform = code.platform

    # Create the analysis; we'll need it later.
    analysis = FieldDetectionAnalysis(platform)

    # Create a CPU
    cpu = smallworld.state.cpus.CPU.for_platform(platform)
    machine.add(cpu)

    # Use lief to find the address of parse_dns_message
    sym = code.get_symbol_value("parse_dns_message")
    cpu.rip.set(sym)

    # Add a blank stack
    stack = smallworld.state.memory.stack.Stack.for_platform(
        platform, 0x7FFFFFFFC000, 0x4000
    )
    machine.add(stack)
    machine.add(gdata)

    stack.push_integer(0x01010101, 8, None)

    # Configure the stack pointer
    sp = stack.get_pointer()
    cpu.rsp.set(sp)

    # Configure arguments
    # arg 0: pointer to buf
    cpu.rdi.set(gdata.address + 48)
    cpu.rdi.set_label("PTR buf")
    # arg 1: buffer capacity
    cpu.rsi.set(512)
    cpu.rsi.set_label("cap")
    # arg 2: pointer to off
    cpu.rdx.set(gdata.address + 560)
    cpu.rdx.set_label("PTR off")
    # arg 3: pointer to msg
    cpu.rcx.set(gdata.address)
    cpu.rcx.set_label("PTR msg")
reinitialize_demo()
# Out:
# [+] Address: 40000
# [+] {"time": "2025-08-07 14:51:21,294", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:51:21,295", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:51:21,296", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:51:21,296", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}

# %%
from smallworld.analyses.field_detection import MallocModel, FreeModel
# Add a blank heap 
heap = smallworld.state.memory.heap.BumpAllocator(0x20000, 0x10000)
machine.add(heap)

# Configure malloc and free models
malloc = MallocModel(
    0x10000, heap, platform, analysis.mem_read_hook, analysis.mem_write_hook
)
machine.add(malloc)
machine.add_bound(malloc._address, malloc._address + 16)

free = FreeModel(0x1036)
machine.add(free)
machine.add_bound(free._address, free._address + 16)

# %% [markdown]
# This will invoke a function hook mimicking `malloc()` if we call address 0x10000.
# If we were in a raw binary, we'd have to do some manual patching
# to tell it where we put `malloc()`, but this is an ELF.
# Let's use the relocation entries to our advantage:

# %%
# Apply relocations to malloc
code.update_symbol_value("malloc", malloc._address)

# %% [markdown]
# So we can continue our analysis here or if you want to run outside this notebook the worke we have done up to this point is fully contained in `dns_2.py`:

# %%
machine.analyze(analysis)
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x20000 - 0x30000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7828ff855bd0> := msg.hdr.a
# [+] {"time": "2025-08-07 14:51:26,709", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4b80> := buf.a
# [+] {"time": "2025-08-07 14:51:26,712", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x782901109060> := off
# [+] {"time": "2025-08-07 14:51:26,714", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7829012c6da0> := msg.a
# [+] {"time": "2025-08-07 14:51:26,716", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x78290110bd90> := msg.b
# [+] {"time": "2025-08-07 14:51:26,719", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7828ff8178b0> := msg.c
# [+] {"time": "2025-08-07 14:51:26,721", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x782901109090> := msg.d
# [+] {"time": "2025-08-07 14:51:26,724", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7828ff817fd0> := msg.hdr.b
# [+] {"time": "2025-08-07 14:51:26,725", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7828ff7cbf40> := msg.hdr.c
# [+] {"time": "2025-08-07 14:51:26,727", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7828ff817e80> := msg.hdr.d
# [+] {"time": "2025-08-07 14:51:26,730", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3b50> := msg.hdr.e
# [+] {"time": "2025-08-07 14:51:26,732", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3ac0> := msg.hdr.f
# [+] {"time": "2025-08-07 14:51:26,734", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7828ff8b55d0> := msg.hdr.unused
# [+] {"time": "2025-08-07 14:51:26,736", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7828ff8b47c0> := buf.b
# [+] {"time": "2025-08-07 14:51:26,739", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x78290110b310> := buf.c
# [+] {"time": "2025-08-07 14:51:26,742", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x782901109150> := buf.d
# [+] {"time": "2025-08-07 14:51:26,744", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4a00> := buf.e
# [+] {"time": "2025-08-07 14:51:26,746", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4bb0> := buf.f
# [+] {"time": "2025-08-07 14:51:26,750", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4be0> := buf
# [+] {"time": "2025-08-07 14:51:26,751", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x78290110a3e0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x78290110a3e0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_103_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.c_103_16
# [*] Concretize them to continue analysis
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x10000>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_99_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_110_64 = <BV64 off_108_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_94_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_95_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_96_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_97_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_101_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_103_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_105_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_107_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_109_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# This ran for much longer, but eventually halted with an error similar to this:
#
# ```
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.c_27_16
# [*] Concretize them to continue analysis
# ```
#
# This output indicates that the analysis was able to deduce that the `msg.hdr.c` field
# gives the numbe of items allocated in our buffer.  In fact, if we scroll up to instruction
# 0x418d0 we see that `msg.hdr.c` gets filled in by the contents of `buf.c` so if we want to
# concretize `msg.hdr.c` we need to assign a concrete value to `buf.c` (and give it a new name):

# %%
gdata[52] = smallworld.state.BytesValue(b"\x00\x01", "buf.msg.hdr.c")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x20000 - 0x30000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7a130797f280> := msg.hdr.a
# [+] {"time": "2025-07-08 09:59:53,543", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7a130784b4c0> := buf.a
# [+] {"time": "2025-07-08 09:59:53,545", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7a133c3a19c0> := off
# [+] {"time": "2025-07-08 09:59:53,546", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7a1309287400> := msg.a
# [+] {"time": "2025-07-08 09:59:53,548", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x7a13093b5690> := msg.b
# [+] {"time": "2025-07-08 09:59:53,549", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7a13093b5360> := msg.c
# [+] {"time": "2025-07-08 09:59:53,550", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7a133c3a2b00> := msg.d
# [+] {"time": "2025-07-08 09:59:53,551", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7a130797f2e0> := msg.hdr.b
# [+] {"time": "2025-07-08 09:59:53,552", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7a130797e920> := msg.hdr.c
# [+] {"time": "2025-07-08 09:59:53,553", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7a130797e980> := msg.hdr.d
# [+] {"time": "2025-07-08 09:59:53,554", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7a130797e9e0> := msg.hdr.e
# [+] {"time": "2025-07-08 09:59:53,555", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7a130797ea40> := msg.hdr.f
# [+] {"time": "2025-07-08 09:59:53,556", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7a130797eaa0> := msg.hdr.unused
# [+] {"time": "2025-07-08 09:59:53,558", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7a130784ae90> := buf.b
# [+] {"time": "2025-07-08 09:59:53,558", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x7a1307651f00> := buf.msg.hdr.c
# [+] {"time": "2025-07-08 09:59:53,559", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x7a13093b7ca0> := buf.d
# [+] {"time": "2025-07-08 09:59:53,560", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7a1307848a00> := buf.e
# [+] {"time": "2025-07-08 09:59:53,561", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7a130784bac0> := buf.f
# [+] {"time": "2025-07-08 09:59:53,562", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7a130784bb20> := buf
# [+] {"time": "2025-07-08 09:59:53,563", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7a13073dc4f0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7a13073dc4f0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_138_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_138_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_146_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_145_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_145_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf)
# [!]   <BV8 buf[3999:3992]>
# [+] {"time": "2025-07-08 09:59:57,561", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24636, "size": 1, "pc": 267639, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_138_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_145_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 1, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603c
# [*]   size:       1
# [*]   pc:         0x41577
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_138_16))> [[<BV16 msg.hdr.c_138_16>]]
# [*]     0x4155a: <Bool cap - off_145_64 >= 0x1> [[<BV64 off_145_64>, <BV64 cap>]]
# [*]   field:      buf[0:1]
# [!] <SimulationManager with 5 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41577>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_138_16))>
# [!]     0x4155a: <Bool cap - off_145_64 >= 0x1>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_134_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_145_64 = <BV64 off_143_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_146_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_130_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_131_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_132_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_136_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_138_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_140_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_142_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_144_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# ## Analyzing the behavior of malloc
#
# Scrolling up to the malloc call after the memory read at 0x41ed2 we see the following output from the malloc:
#
# ```
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [+] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [+]   <BV64 0x20010>
# ```
#
# Let's take this one line at a time:
#
# - `malloc: Alloc'd 264 bytes at 0x20010`:  Since we assigned 0x1 to the length in `buf.c`,
# this line is telling us that space for the struct is 264 bytes (the `malloc()` model would
# warn us if the length computation was more complex than "variable * magnitude".)
#
# - `Storing 8 bytes at 0x20008`: Malloc returns a pointer to the newly allocated memory so the address of the heap memory is stored there. #TODO - confirm this is true?
#
# - `  Length field msg.hdr.c not known`: We haven't told the `malloc()` model that it should track structs allocated using `msg.hdr.c`, or what they should look like. #TODO - review this comment, I don't fully understand it
#
# - `0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)`: The pointer to our new heap array is stored in `msg.a`, making `msg.hdr.c` the length of `msg.a`.
#
# We wrap up this section by noting that execution stopped on another read of a single byte from a larger buffer.  We'll finish this treatment of models with three final actions:
# - combine all the model work into a routine that can be called when we reinitialize our analysis
# - update our harness to take account of the single byte
# - run again

# %%
def add_malloc_free_models():
    global code
    global malloc
    global free
    global heap

    # Add a blank heap
    heap = smallworld.state.memory.heap.BumpAllocator(0x20000, 0x10000)
    machine.add(heap)

    # Configure malloc and free models
    malloc = MallocModel(
        0x10000, heap, platform, analysis.mem_read_hook, analysis.mem_write_hook
    )
    machine.add(malloc)
    machine.add_bound(malloc._address, malloc._address + 16)

    free = FreeModel(0x1036)
    machine.add(free)
    machine.add_bound(free._address, free._address + 16)

    # Apply relocations to malloc
    code.update_symbol_value("malloc", malloc._address)
  
reinitialize_demo()
add_malloc_free_models()
gdata[60] = smallworld.state.SymbolicValue(1, None, None, "buf.g")
gdata[61] = smallworld.state.SymbolicValue(499, None, None, "buf")
machine.analyze(analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-08-07 14:55:52,117", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:55:52,117", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:55:52,118", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:55:52,119", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7828ff855bd0> := msg.hdr.a
# [+] {"time": "2025-08-07 14:55:52,123", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4b80> := buf.a
# [+] {"time": "2025-08-07 14:55:52,124", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x782901109060> := off
# [+] {"time": "2025-08-07 14:55:52,125", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7829012c6da0> := msg.a
# [+] {"time": "2025-08-07 14:55:52,126", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x78290110bd90> := msg.b
# [+] {"time": "2025-08-07 14:55:52,127", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7828ff8178b0> := msg.c
# [+] {"time": "2025-08-07 14:55:52,128", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x782901109090> := msg.d
# [+] {"time": "2025-08-07 14:55:52,129", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7828ff817fd0> := msg.hdr.b
# [+] {"time": "2025-08-07 14:55:52,130", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7828ff7cbf40> := msg.hdr.c
# [+] {"time": "2025-08-07 14:55:52,131", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7828ff817e80> := msg.hdr.d
# [+] {"time": "2025-08-07 14:55:52,132", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3b50> := msg.hdr.e
# [+] {"time": "2025-08-07 14:55:52,133", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3ac0> := msg.hdr.f
# [+] {"time": "2025-08-07 14:55:52,136", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7828ff8b55d0> := msg.hdr.unused
# [+] {"time": "2025-08-07 14:55:52,137", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7828ff8b47c0> := buf.b
# [+] {"time": "2025-08-07 14:55:52,140", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x78290110b310> := buf.c
# [+] {"time": "2025-08-07 14:55:52,143", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x782901109150> := buf.d
# [+] {"time": "2025-08-07 14:55:52,145", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4a00> := buf.e
# [+] {"time": "2025-08-07 14:55:52,148", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4bb0> := buf.f
# [+] {"time": "2025-08-07 14:55:52,151", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x7828fe4758a0> := buf.g
# [+] {"time": "2025-08-07 14:55:52,154", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.g", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7828ff793ac0> := buf
# [+] {"time": "2025-08-07 14:55:52,157", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 499, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x20000 - 0x30000
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7828ff2dfc10>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7828ff2dfc10>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x6230
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x7ffffffffff8
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_145_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_145_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_145_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_145_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_140_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.c_140_16
# [*] Concretize them to continue analysis
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x10000>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_136_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_147_64 = <BV64 off_145_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_131_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_132_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_133_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_134_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_138_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_140_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_142_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_144_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_146_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>

# %% [markdown]
# # Stage 2 DNS exploration: Next control field
#
# The end of our last run produced new output.  In particular, it noted that `buf.g` seems to be
# influencing whether the first two bytes of `buf` are a single field or multiple fields.  What
# conditions are making this happen?  To address this question, we look at the various reports
# of `Partial access to known field` and look at the conditions that were required for that
# partial access to occurr.  This happens in three cases.  Extracting just the information
# relevent to `buf.g` we have:
#
# ### Case 1:
# ```
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x415c8
# [*]   access:     read
# [*]   guards:
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]   field:      buf[0:1]
# ```
# We get to this case exactly when the two high bits set on `buf.g`.  So since `buf.g` is a byte,
# `buf.g` is 64 and 255 inclusive.
#
# ### Case 2:
# ```
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x41592: <Bool buf.g == 0> [[<BV8 buf.g>]]
# [*]   field:      buf[0:2]
# ```
# We get to this case exactly when `buf.g == 0`.
#
# ### Case 3:
# ```
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x416b9
# [*]   access:     read
# [*]   guards:
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) != 192> [[<BV8 buf.g>]]
# [*]     0x4161c: <Bool (buf.g & 192) == 0> [[<BV8 buf.g>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.g)) < 0xff then 1 else 0) | (if buf.g == 255 then 1 else 0)) != 0> [[<BV8 buf.g>]]
# [*]     0x4165c: <Bool cap - off_184_64 >= (0#32 .. (0#24 .. buf.g))> [[<BV8 buf.g>, <BV64 off_184_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.g))> [[<BV8 buf.g>]]
# [*]   field:      buf[0:1]
# ```
# The conditions on `buf.g` look much more complicated here but with a little work
# it is not hard to see that this case arises exactly when the two high bits are
# unset on `buf.g` and `buf.g` non-zero.  So since `buf.g` is a byte, `buf.g` is
# between 1 and 63 inclusive.

# %% [markdown]
# ## Trying some concrete examples
#
# So can we try setting `buf.g` to some concrete values?  Of course, let's try a few:
#
# ### Case 1: `64 <= buf.g <= 255`
#
# Let's try setting the buffer to 64 and see what happens.  Having used symbolic execution
# in the past, we wrap our analysis with a timeout to catch in case it runs forever!

# %%
from smallworld.analyses.field_detection import MallocModel, FreeModel
import claripy
import timeout_decorator

@timeout_decorator.timeout(40)  # argument is in seconds
def analyze_with_timeout(machine, analysis):
    try:
        machine.analyze(analysis)
    except timeout_decorator.timeout_decorator.TimeoutError:
        print("Analysis timeout")


reinitialize_demo()
add_malloc_free_models()
gdata[61] = smallworld.state.SymbolicValue(1, None, None, "buf.one")
gdata[62] = smallworld.state.SymbolicValue(498, None, None, "buf")

# Add constraint to buf.g
machine.add_constraint(
    claripy.UGT(claripy.BVS("buf.g", 8, explicit_name=True), claripy.BVV(64, 8))
)

analyze_with_timeout(machine, analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-08-07 14:56:56,768", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:56:56,770", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:56:56,770", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:56:56,772", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7828ff855bd0> := msg.hdr.a
# [+] {"time": "2025-08-07 14:56:56,781", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4b80> := buf.a
# [+] {"time": "2025-08-07 14:56:56,782", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x782901109060> := off
# [+] {"time": "2025-08-07 14:56:56,784", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7829012c6da0> := msg.a
# [+] {"time": "2025-08-07 14:56:56,785", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x78290110bd90> := msg.b
# [+] {"time": "2025-08-07 14:56:56,786", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7828ff8178b0> := msg.c
# [+] {"time": "2025-08-07 14:56:56,787", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x782901109090> := msg.d
# [+] {"time": "2025-08-07 14:56:56,788", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7828ff817fd0> := msg.hdr.b
# [+] {"time": "2025-08-07 14:56:56,789", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7828ff7cbf40> := msg.hdr.c
# [+] {"time": "2025-08-07 14:56:56,791", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7828ff817e80> := msg.hdr.d
# [+] {"time": "2025-08-07 14:56:56,792", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3b50> := msg.hdr.e
# [+] {"time": "2025-08-07 14:56:56,794", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3ac0> := msg.hdr.f
# [+] {"time": "2025-08-07 14:56:56,795", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7828ff8b55d0> := msg.hdr.unused
# [+] {"time": "2025-08-07 14:56:56,797", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7828ff8b47c0> := buf.b
# [+] {"time": "2025-08-07 14:56:56,799", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x78290110b310> := buf.c
# [+] {"time": "2025-08-07 14:56:56,800", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x782901109150> := buf.d
# [+] {"time": "2025-08-07 14:56:56,802", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4a00> := buf.e
# [+] {"time": "2025-08-07 14:56:56,803", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4bb0> := buf.f
# [+] {"time": "2025-08-07 14:56:56,804", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x7828fe4758a0> := buf.g
# [+] {"time": "2025-08-07 14:56:56,805", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.g", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x603e: <smallworld.state.state.SymbolicValue object at 0x7828fe09af20> := buf.one
# [+] {"time": "2025-08-07 14:56:56,806", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 1, "label": "buf.one", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603e - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7828fe48a5c0> := buf
# [+] {"time": "2025-08-07 14:56:56,807", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24638, "size": 498, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x20000 - 0x30000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7828fe489e40>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7828fe489e40>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x6230
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_175_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_175_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_175_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_175_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_177_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_177_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_177_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_177_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_179_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_179_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_179_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_179_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_181_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_181_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_181_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_181_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_183_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_183_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_183_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_183_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_178_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.c_178_16
# [*] Concretize them to continue analysis
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x10000>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_174_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_185_64 = <BV64 off_183_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_169_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_170_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_171_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_172_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_176_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_178_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_180_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_182_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_184_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x603e: buf.one = <BV8 buf.one>
# [!]     0x603e - 0x6230: buf = <BV3984 buf>

# %% [markdown]
# Notice that this has run to `0x1010101` which is the return value from this subroutine.  In other words, this exectuion has run to completeion.  Further subdividing `buf.a` into `buf.a1` and `buf.a2` we have:

# %%
reinitialize_demo()
add_malloc_free_models()
gdata[48] = smallworld.state.SymbolicValue(1, None, None, "buf.a1")
gdata[49] = smallworld.state.SymbolicValue(1, None, None, "buf.a2")

# Add constraint to buf.g
machine.add_constraint(
    claripy.UGT(claripy.BVS("buf.g", 8, explicit_name=True), claripy.BVV(64, 8))
)

analyze_with_timeout(machine, analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-08-07 14:57:13,255", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:57:13,256", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:57:13,257", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:57:13,258", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7828ff855bd0> := msg.hdr.a
# [+] {"time": "2025-08-07 14:57:13,265", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6031: <smallworld.state.state.SymbolicValue object at 0x7828ff2dd870> := buf.a1
# [+] {"time": "2025-08-07 14:57:13,266", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 1, "label": "buf.a1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x782901109060> := off
# [+] {"time": "2025-08-07 14:57:13,267", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7829012c6da0> := msg.a
# [+] {"time": "2025-08-07 14:57:13,268", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x78290110bd90> := msg.b
# [+] {"time": "2025-08-07 14:57:13,269", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7828ff8178b0> := msg.c
# [+] {"time": "2025-08-07 14:57:13,270", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x782901109090> := msg.d
# [+] {"time": "2025-08-07 14:57:13,272", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7828ff817fd0> := msg.hdr.b
# [+] {"time": "2025-08-07 14:57:13,273", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7828ff7cbf40> := msg.hdr.c
# [+] {"time": "2025-08-07 14:57:13,274", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7828ff817e80> := msg.hdr.d
# [+] {"time": "2025-08-07 14:57:13,275", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3b50> := msg.hdr.e
# [+] {"time": "2025-08-07 14:57:13,276", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3ac0> := msg.hdr.f
# [+] {"time": "2025-08-07 14:57:13,277", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7828ff8b55d0> := msg.hdr.unused
# [+] {"time": "2025-08-07 14:57:13,278", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7828ff8b47c0> := buf.b
# [+] {"time": "2025-08-07 14:57:13,279", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x78290110b310> := buf.c
# [+] {"time": "2025-08-07 14:57:13,281", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x782901109150> := buf.d
# [+] {"time": "2025-08-07 14:57:13,282", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4a00> := buf.e
# [+] {"time": "2025-08-07 14:57:13,283", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4bb0> := buf.f
# [+] {"time": "2025-08-07 14:57:13,284", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x7828fe4758a0> := buf.g
# [+] {"time": "2025-08-07 14:57:13,286", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.g", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x603e: <smallworld.state.state.SymbolicValue object at 0x7828fe09af20> := buf.one
# [+] {"time": "2025-08-07 14:57:13,287", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 1, "label": "buf.one", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603e - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7828fe48a5c0> := buf
# [+] {"time": "2025-08-07 14:57:13,288", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24638, "size": 498, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6031 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7828fdf384c0> := buf.a2
# [+] {"time": "2025-08-07 14:57:13,289", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24625, "size": 1, "label": "buf.a2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x20000 - 0x30000
# [!] 0x7fffffffc000 - 0x800000000000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7828fe07ee60>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7828fe07ee60>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x6230
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x7ffffffffff8
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_214_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_214_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_214_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_214_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_216_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_216_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_216_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_216_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_218_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_218_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_218_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_218_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_220_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_220_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_220_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_220_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_222_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_222_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_222_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_222_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_217_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.c_217_16
# [*] Concretize them to continue analysis
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x10000>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_213_16 = <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6031: buf.a1 = <BV8 buf.a1>
# [!]     0x6230 - 0x6238: off_224_64 = <BV64 off_222_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_208_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_209_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_210_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_211_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_215_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_217_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_219_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_221_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_223_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x603e: buf.one = <BV8 buf.one>
# [!]     0x603e - 0x6230: buf = <BV3984 buf>
# [!]     0x6031 - 0x6032: buf.a2 = <BV8 buf.a2>

# %% [markdown]
# And iterating a few times:

# %%
reinitialize_demo()
add_malloc_free_models()
gdata[4] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.c1")
gdata[5] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.c2")
gdata[50] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.b1")
gdata[51] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.b2")
gdata[56] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.e1")
gdata[57] = smallworld.state.SymbolicValue(1, None, None, "buf.msg.hdr.e2")
gdata[61] = smallworld.state.SymbolicValue(1, None, None, "buf.1")
gdata[62] = smallworld.state.SymbolicValue(1, None, None, "buf.2")
gdata[63] = smallworld.state.SymbolicValue(1, None, None, "buf.3")
gdata[64] = smallworld.state.SymbolicValue(1, None, None, "buf.4")
gdata[65] = smallworld.state.SymbolicValue(495, None, None, "buf.rest")
# Add constraint to buf.g
machine.add_constraint(
    claripy.UGT(claripy.BVS("buf.g", 8, explicit_name=True), claripy.BVV(64, 8))
)

analyze_with_timeout(machine, analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-08-07 14:57:16,785", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:57:16,786", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:57:16,787", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:57:16,788", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7828ff855bd0> := msg.hdr.a
# [+] {"time": "2025-08-07 14:57:16,794", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6031: <smallworld.state.state.SymbolicValue object at 0x7828ff2dd870> := buf.a1
# [+] {"time": "2025-08-07 14:57:16,796", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 1, "label": "buf.a1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x782901109060> := off
# [+] {"time": "2025-08-07 14:57:16,798", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7829012c6da0> := msg.a
# [+] {"time": "2025-08-07 14:57:16,800", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x78290110bd90> := msg.b
# [+] {"time": "2025-08-07 14:57:16,802", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7828ff8178b0> := msg.c
# [+] {"time": "2025-08-07 14:57:16,803", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x782901109090> := msg.d
# [+] {"time": "2025-08-07 14:57:16,805", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7828ff817fd0> := msg.hdr.b
# [+] {"time": "2025-08-07 14:57:16,808", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6005: <smallworld.state.state.SymbolicValue object at 0x7828fe0b3dc0> := buf.msg.hdr.c1
# [+] {"time": "2025-08-07 14:57:16,809", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 1, "label": "buf.msg.hdr.c1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7828ff817e80> := msg.hdr.d
# [+] {"time": "2025-08-07 14:57:16,809", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3b50> := msg.hdr.e
# [+] {"time": "2025-08-07 14:57:16,810", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3ac0> := msg.hdr.f
# [+] {"time": "2025-08-07 14:57:16,812", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7828ff8b55d0> := msg.hdr.unused
# [+] {"time": "2025-08-07 14:57:16,813", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6033: <smallworld.state.state.SymbolicValue object at 0x7828ff7cbf40> := buf.msg.hdr.b1
# [+] {"time": "2025-08-07 14:57:16,813", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 1, "label": "buf.msg.hdr.b1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x78290110b310> := buf.c
# [+] {"time": "2025-08-07 14:57:16,814", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x782901109150> := buf.d
# [+] {"time": "2025-08-07 14:57:16,816", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x6039: <smallworld.state.state.SymbolicValue object at 0x7828fe468580> := buf.msg.hdr.e1
# [+] {"time": "2025-08-07 14:57:16,816", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 1, "label": "buf.msg.hdr.e1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4bb0> := buf.f
# [+] {"time": "2025-08-07 14:57:16,817", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x7828fe4758a0> := buf.g
# [+] {"time": "2025-08-07 14:57:16,818", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.g", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x603e: <smallworld.state.state.SymbolicValue object at 0x7828fe469a80> := buf.1
# [+] {"time": "2025-08-07 14:57:16,819", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 1, "label": "buf.1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603e - 0x603f: <smallworld.state.state.SymbolicValue object at 0x7828fe46ba00> := buf.2
# [+] {"time": "2025-08-07 14:57:16,820", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24638, "size": 1, "label": "buf.2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6031 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7828fdf384c0> := buf.a2
# [+] {"time": "2025-08-07 14:57:16,821", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24625, "size": 1, "label": "buf.a2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6005 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7828fe0b0b20> := buf.msg.hdr.c2
# [+] {"time": "2025-08-07 14:57:16,822", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24581, "size": 1, "label": "buf.msg.hdr.c2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6033 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7828ff8173a0> := buf.msg.hdr.b2
# [+] {"time": "2025-08-07 14:57:16,823", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24627, "size": 1, "label": "buf.msg.hdr.b2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6039 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7828fe46bb80> := buf.msg.hdr.e2
# [+] {"time": "2025-08-07 14:57:16,824", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24633, "size": 1, "label": "buf.msg.hdr.e2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603f - 0x6040: <smallworld.state.state.SymbolicValue object at 0x7828fe09af20> := buf.3
# [+] {"time": "2025-08-07 14:57:16,825", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24639, "size": 1, "label": "buf.3", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6040 - 0x6041: <smallworld.state.state.SymbolicValue object at 0x7828fe46ba30> := buf.4
# [+] {"time": "2025-08-07 14:57:16,826", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24640, "size": 1, "label": "buf.4", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6041 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7828fe46b5b0> := buf.rest
# [+] {"time": "2025-08-07 14:57:16,827", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24641, "size": 495, "label": "buf.rest", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x20000 - 0x30000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7828fe4a7730>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7828fe4a7730>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x6230
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_259_64>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_259_64>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_259_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_259_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_261_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_261_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_261_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_261_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_262_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_262_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_262_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_262_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_264_64>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_264_64>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_264_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_264_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_266_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_266_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_266_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_266_64 + 0x2>
# [!]   Write to entire field off
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    buf.c
# [*] Concretize them to continue analysis
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x10000>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_258_16 = <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6031: buf.a1 = <BV8 buf.a1>
# [!]     0x6230 - 0x6238: off_268_64 = <BV64 off_266_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_253_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_254_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_255_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_256_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_260_16 = <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6005: buf.c = <BV16 buf.c>
# [!]     0x6006 - 0x6008: msg.hdr.d_263_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_265_16 = <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_267_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6033: buf.msg.hdr.b1 = <BV8 buf.msg.hdr.b1>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x6039: buf.msg.hdr.e1 = <BV8 buf.msg.hdr.e1>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x603e: buf.1 = <BV8 buf.1>
# [!]     0x603e - 0x603f: buf.2 = <BV8 buf.2>
# [!]     0x6031 - 0x6032: buf.a2 = <BV8 buf.a2>
# [!]     0x6005 - 0x6006: buf.c = <BV16 buf.c>
# [!]     0x6033 - 0x6034: buf.msg.hdr.b2 = <BV8 buf.msg.hdr.b2>
# [!]     0x6039 - 0x603a: buf.msg.hdr.e2 = <BV8 buf.msg.hdr.e2>
# [!]     0x603f - 0x6040: buf.3 = <BV8 buf.3>
# [!]     0x6040 - 0x6041: buf.4 = <BV8 buf.4>
# [!]     0x6041 - 0x6230: buf.rest = <BV3960 buf.rest>

# %% [markdown]
# We are again asked to concretize a value, this time `msg.hdr.d`.

# %%
gdata[54] = smallworld.state.BytesValue(b"\x00\x01", "buf.msg.hdr.d")
reinitialize_demo()
add_malloc_free_models()
machine.add_constraint(
    claripy.UGT(claripy.BVS("buf.g", 8, explicit_name=True), claripy.BVV(64, 8))
)
analyze_with_timeout(machine, analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-08-07 14:57:24,260", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:57:24,261", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:57:24,262", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-08-07 14:57:24,262", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x7828ff855bd0> := msg.hdr.a
# [+] {"time": "2025-08-07 14:57:24,267", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6031: <smallworld.state.state.SymbolicValue object at 0x7828ff2dd870> := buf.a1
# [+] {"time": "2025-08-07 14:57:24,268", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 1, "label": "buf.a1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x782901109060> := off
# [+] {"time": "2025-08-07 14:57:24,269", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7829012c6da0> := msg.a
# [+] {"time": "2025-08-07 14:57:24,270", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x78290110bd90> := msg.b
# [+] {"time": "2025-08-07 14:57:24,272", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x7828ff8178b0> := msg.c
# [+] {"time": "2025-08-07 14:57:24,273", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x782901109090> := msg.d
# [+] {"time": "2025-08-07 14:57:24,274", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x7828ff817fd0> := msg.hdr.b
# [+] {"time": "2025-08-07 14:57:24,275", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6005: <smallworld.state.state.SymbolicValue object at 0x7828fe0b3dc0> := buf.msg.hdr.c1
# [+] {"time": "2025-08-07 14:57:24,275", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 1, "label": "buf.msg.hdr.c1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x7828ff817e80> := msg.hdr.d
# [+] {"time": "2025-08-07 14:57:24,277", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3b50> := msg.hdr.e
# [+] {"time": "2025-08-07 14:57:24,278", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7828ff8a3ac0> := msg.hdr.f
# [+] {"time": "2025-08-07 14:57:24,279", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7828ff8b55d0> := msg.hdr.unused
# [+] {"time": "2025-08-07 14:57:24,280", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6033: <smallworld.state.state.SymbolicValue object at 0x7828ff7cbf40> := buf.msg.hdr.b1
# [+] {"time": "2025-08-07 14:57:24,281", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 1, "label": "buf.msg.hdr.b1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x78290110b310> := buf.c
# [+] {"time": "2025-08-07 14:57:24,282", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.BytesValue object at 0x7828fde140a0> := buf.msg.hdr.d
# [+] {"time": "2025-08-07 14:57:24,284", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x6039: <smallworld.state.state.SymbolicValue object at 0x7828fe468580> := buf.msg.hdr.e1
# [+] {"time": "2025-08-07 14:57:24,285", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 1, "label": "buf.msg.hdr.e1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7828ff8b4bb0> := buf.f
# [+] {"time": "2025-08-07 14:57:24,286", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x7828fe4758a0> := buf.g
# [+] {"time": "2025-08-07 14:57:24,287", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.g", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x603e: <smallworld.state.state.SymbolicValue object at 0x7828fe469a80> := buf.1
# [+] {"time": "2025-08-07 14:57:24,288", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 1, "label": "buf.1", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603e - 0x603f: <smallworld.state.state.SymbolicValue object at 0x7828fe46ba00> := buf.2
# [+] {"time": "2025-08-07 14:57:24,289", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24638, "size": 1, "label": "buf.2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6031 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x7828fdf384c0> := buf.a2
# [+] {"time": "2025-08-07 14:57:24,290", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24625, "size": 1, "label": "buf.a2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6005 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7828fe0b0b20> := buf.msg.hdr.c2
# [+] {"time": "2025-08-07 14:57:24,291", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24581, "size": 1, "label": "buf.msg.hdr.c2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6033 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7828ff8173a0> := buf.msg.hdr.b2
# [+] {"time": "2025-08-07 14:57:24,292", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24627, "size": 1, "label": "buf.msg.hdr.b2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6039 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7828fe46bb80> := buf.msg.hdr.e2
# [+] {"time": "2025-08-07 14:57:24,293", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24633, "size": 1, "label": "buf.msg.hdr.e2", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603f - 0x6040: <smallworld.state.state.SymbolicValue object at 0x7828fe09af20> := buf.3
# [+] {"time": "2025-08-07 14:57:24,294", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24639, "size": 1, "label": "buf.3", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6040 - 0x6041: <smallworld.state.state.SymbolicValue object at 0x7828fe46ba30> := buf.4
# [+] {"time": "2025-08-07 14:57:24,296", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24640, "size": 1, "label": "buf.4", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6041 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7828fe46b5b0> := buf.rest
# [+] {"time": "2025-08-07 14:57:24,298", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24641, "size": 495, "label": "buf.rest", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x20000 - 0x30000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7828fde07c40>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7828fde07c40>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6036
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_302_64>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_302_64>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_302_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_302_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_304_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_304_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_304_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_304_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_305_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.msg.hdr.d)
# [!]   <BV16 Reverse(buf.msg.hdr.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_305_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.msg.hdr.d)
# [!]   <BV16 Reverse(buf.msg.hdr.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_305_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_305_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_307_64>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_307_64>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_307_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_307_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_309_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_309_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_309_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_309_64 + 0x2>
# [!]   Write to entire field off
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    buf.c
# [*] Concretize them to continue analysis
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x10000>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_301_16 = <BV16 (0#32 .. (0#16 .. (buf.a2 .. buf.a1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.a2 .. buf.a1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6031: buf.a1 = <BV8 buf.a1>
# [!]     0x6230 - 0x6238: off_311_64 = <BV64 off_309_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_296_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_297_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_298_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_299_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_303_16 = <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.b2 .. buf.msg.hdr.b1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6005: buf.c = <BV16 buf.c>
# [!]     0x6006 - 0x6008: msg.hdr.d_306_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_308_16 = <BV16 (0#32 .. (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. (buf.msg.hdr.e2 .. buf.msg.hdr.e1)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_310_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6033: buf.msg.hdr.b1 = <BV8 buf.msg.hdr.b1>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.msg.hdr.d = <BV16 buf.msg.hdr.d>
# [!]     0x6038 - 0x6039: buf.msg.hdr.e1 = <BV8 buf.msg.hdr.e1>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x603e: buf.1 = <BV8 buf.1>
# [!]     0x603e - 0x603f: buf.2 = <BV8 buf.2>
# [!]     0x6031 - 0x6032: buf.a2 = <BV8 buf.a2>
# [!]     0x6005 - 0x6006: buf.c = <BV16 buf.c>
# [!]     0x6033 - 0x6034: buf.msg.hdr.b2 = <BV8 buf.msg.hdr.b2>
# [!]     0x6039 - 0x603a: buf.msg.hdr.e2 = <BV8 buf.msg.hdr.e2>
# [!]     0x603f - 0x6040: buf.3 = <BV8 buf.3>
# [!]     0x6040 - 0x6041: buf.4 = <BV8 buf.4>
# [!]     0x6041 - 0x6230: buf.rest = <BV3960 buf.rest>
