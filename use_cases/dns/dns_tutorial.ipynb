# %% [markdown]
# # Deducing Struct Layout with Symbolic Execution
# The goal of this tutorial is to determine the input format
# accepted by the test program `dns.{arch}.elf`
# without reading the source or resorting to manual RE.
#
# We'll use memory labelling to lay out a hypothetical message structure
# in our machine state, and then use `FieldDetectionAnalysis` to
# detect inconsistencies between our hypothesis and how the code accesses the data.
# By iterating this process, we will refine our hypothesis until it matches
# what the code accepts.

# %% [markdown]
# ## Setup & Installation
# Install the required packages as described in the install directions.
#
# You can build the example programs by running `make all` from this directory.
# This requires the cross-compiler toolchains installed as part of the apt dependencies;
# this analysis will work on any architecture supported by angr.
#
# Let's test this program against the example input `examples/answer.dat`:
#
# ```
# $> hexdump -C examples/answer.dat
# 00000000  ce 70 81 80 00 01 00 01  00 00 00 01 06 67 6f 6f  |.p...........goo|
# 00000010  67 6c 65 03 63 6f 6d 00  00 01 00 01 c0 0c 00 01  |gle.com.........|
# 00000020  00 01 00 00 00 d2 00 04  8e fa 41 ce 00 00 29 04  |..........A...).|
# 00000030  c4 00 00 00 00 00 1c 00  0a 00 18 cb 6e 4b 21 27  |............nK!'|
# 00000040  ca a2 eb 8f fc 9f 64 67  85 5f 7f cf 3e 38 e4 56  |......dg._..>8.V|
# 00000050  80 72 f9                                          |.r.|
# 00000053
#
# $> ./bin/dns.amd64.elf examples/answer.dat
# DNS Message:
#         TID:          ce70
#         FLAGS:        0120
#         # Questions:  1
#         # Answers:    0
#         # Auth. Rs:   0
#         # Extra Rs:   1
# Question:
#         Name:         google.com
#         Type:         1
#         Class:        1
# Record:
#         Name:
#         Type:         41
#         Class:        1232
# ```
#
# If it's not apparent yet, this program parses basic DNS messages.
# However, the exact structure accepted by the parser isn't obvious.
# We could decompile the binary and try to elicit the structure but
# we are goign to used SmallWord analysis capabilites to figure it out.
#
# ## Harnessing the Parser
#
# For sanity's sake, let's assume we know that the parser is implemented in `parse_dns_msg()`,
# and that we roughly know its arguments from `main()`:
#
# - **Arg 1:** `uint8_t *` pointing to an input buffer
# - **Arg 2:** `size_t` holding its size
# - **Arg 3:** `size_t *` pointing to a value starting at zero
# - **Arg 4:** `struct *` pointing to an unknown struct
#
# Our goal for this exercise is to figure out the structure of argument 1,
# which we'll call `buf`, and argument 4, which we'll call `msg`.
#
# First, we set up some smallworld boilerplate.
# This configures logging, as well as the hinter
# that will let us see the output from our analysis.

# %%
import logging
import pathlib

import smallworld
import smallworld.analyses.field_detection
import smallworld.analyses.unstable.angr.visitor
from smallworld.analyses.field_detection import FieldDetectionAnalysis

# Set up logging and hinting                                                                                                                                                                                                         
smallworld.logging.setup_logging(level=logging.INFO)
smallworld.hinting.setup_hinting(stream=True, verbose=True)

log = logging.getLogger("smallworld")
# Out:
# /home/cr33967/SmallWorld/smallworld/venv/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.2 is exactly one major version older than the runtime version 6.30.2 at angr/protos/primitives.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/cr33967/SmallWorld/smallworld/venv/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.2 is exactly one major version older than the runtime version 6.30.2 at angr/protos/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/cr33967/SmallWorld/smallworld/venv/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.2 is exactly one major version older than the runtime version 6.30.2 at angr/protos/cfg.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/cr33967/SmallWorld/smallworld/venv/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.2 is exactly one major version older than the runtime version 6.30.2 at angr/protos/xrefs.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/cr33967/SmallWorld/smallworld/venv/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.2 is exactly one major version older than the runtime version 6.30.2 at angr/protos/variables.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %% [markdown]
# Next, we create the basic machine state, load our ELF file into a smallworld state object, and add the code to the machine.
#
# Since we don't expect a specific platform, we can use the platform definition parsed out of the ELF headers.
#
# Also, since this is the only ELF we're loading, we can use its notion of program bounds to define which memory the analysis can execute.

# %%
# Create a machine
machine = smallworld.state.Machine()

# Load the code
filepath = "bin/dns.amd64.elf"
with open(filepath, "rb") as f:
    code = smallworld.state.memory.code.Executable.from_elf(f, 0x40000)
    machine.add(code)

# Apply the code's bounds to the machine
for bound in code.bounds:
    machine.add_bound(bound[0], bound[1])

# Use the ELF's notion of the platform
platform = code.platform

 # Create the analysis; we'll need it later.
analysis = FieldDetectionAnalysis(platform)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-06-30 18:27:04,586", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:27:04,587", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:27:04,589", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:27:04,590", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}

# %%
# Create a CPU
cpu = smallworld.state.cpus.CPU.for_platform(platform)
machine.add(cpu)

# Use lief to find the address of parse_dns_message
sym = code.get_symbol_value("parse_dns_message")
cpu.rip.set(sym)

# Add a blank stack
stack = smallworld.state.memory.stack.Stack.for_platform(
    platform, 0x7FFFFFFFC000, 0x4000
)
machine.add(stack)

stack.push_integer(0x01010101, 8, None)

# Configure the stack pointer
sp = stack.get_pointer()
cpu.rsp.set(sp)

# %% [markdown]
# Now that we have the program set up, we can start to model the inputs to `parse_dns_message()`.
# We know we need a message struct, a memory buffer, and a `size_t`
# that are all passed by reference.
#
# For ease of modelling, let's just allocate them all as globals.
#
# To start, we'll allocate `buf` and `msg` as blank swaths of memory.
# As we learn more about their internal structure from the analysis,
# we will come back and refine this part of our harness.

# %%
# Configure somewhere for arguments to live                                                                                                                                                                                          
gdata = smallworld.state.memory.Memory(0x6000, 0x1000)
machine.add(gdata)
# DNS message struct                                                                                                                                                                                                                 
# Sort of cheating that I know how big it is.                                                                                                                                                                                        
gdata[0] = smallworld.state.SymbolicValue(48, None, None, "msg")
# Input buffer                                                                                                                                                                                                                       
gdata[48] = smallworld.state.SymbolicValue(512, None, None, "buf")
# Offset into buffer                                                                                                                                                                                                                 
gdata[560] = smallworld.state.IntegerValue(0, 8, "off", False)

# %% [markdown]
# Next, we use what we know about the function signature to assign values to registers.
# We know that the first arg points to `buf`, the second is the size of `buf`,
# the third points to `off`, and the fourth points to `msg`.

# %%
# Configure arguments                                                                                                                                                                                                                
# arg 0: pointer to buf                                                                                                                                                                                                              
cpu.rdi.set(gdata.address + 48)
cpu.rdi.set_label("PTR buf")
# arg 1: buffer capacity                                                                                                                                                                                                             
cpu.rsi.set(512)
cpu.rsi.set_label("cap")
# arg 2: pointer to off                                                                                                                                                                                                              
cpu.rdx.set(gdata.address + 560)
cpu.rdx.set_label("PTR off")
# arg 3: pointer to msg                                                                                                                                                                                                              
cpu.rcx.set(gdata.address)
cpu.rcx.set_label("PTR msg")

# %% [markdown]
# At long last, we're reading to actually run our analysis.

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x73d9bfee2dd0> := msg
# [+] {"time": "2025-06-30 18:27:04,639", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 48, "label": "msg", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x73d9bfee3520> := buf
# [+] {"time": "2025-06-30 18:27:04,641", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x73d9bfee2b60> := off
# [+] {"time": "2025-06-30 18:27:04,642", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x73d9aa6b70d0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x73d9aa6b70d0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] Self-modifying code is not always correctly optimized by PyVEX. To guarantee correctness, VEX optimizations have been disabled.
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg)
# [!]   <BV64 0x0>
# [+] {"time": "2025-06-30 18:27:05,031", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 24592, "size": 8, "pc": 269939, "guards": [], "access": "write", "label": "msg", "start": 16, "end": 24, "expr": "<BV64 0x0>", "class": "smallworld.analyses.field_detection.hints.PartialByteFieldWriteHint"}}
# [*] Partial write to known field
# [*]   address:    0x6010
# [*]   size:       8
# [*]   pc:         0x41e73
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg[16:24]
# [*]   expr:       <BV64 0x0>
# [!] <SimulationManager with 1 deadended>
# [!] []
# [!] State at <BV64 0x41e73>:
# [!]   Guards:
# [!]   Fields:
# [!]     0x6000 - 0x6030: msg = <BV384 msg>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>

# %% [markdown]
# # First Results
#
# (This code so far is collected in `dns_0.py`.)  The analysis produced by `FieldDetectionAnalysis` yields the following hint:
#
# ```
# [*] Partial write to known field
# [*]   pc:         0x41e73
# [*]   address:    0x6010
# [*]   size:       8
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg[16:24]
# [*]   expr:       <BV64 0x0>
# ```
#
# The code at `0x41e73` tried to write 8 bytes of zero 16 byptes into our `msg` buffer.
# But we defined `msg` as a 512 byte contiguous region and didn't expect to see a field.
#
# With this information in hand we can redefine `msg` as the following

# %%
gdata[0] = smallworld.state.SymbolicValue(16, None, None, "msg.unk-0x0")
gdata[16] = smallworld.state.SymbolicValue(8, None, None, "msg.a")
gdata[24] = smallworld.state.SymbolicValue(24, None, None, "msg.unk-0x18")

# %% [markdown]
# We're not sure what `msg.a` is, but we know it's very likely a field.
# We're on our way!
#
# Running our updated script gives a very similar hint to the first:

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6010: <smallworld.state.state.SymbolicValue object at 0x73d9aa57a650> := msg.unk-0x0
# [+] {"time": "2025-06-30 18:27:05,067", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 16, "label": "msg.unk-0x0", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x73d9bfee3520> := buf
# [+] {"time": "2025-06-30 18:27:05,069", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x73d9bfee2b60> := off
# [+] {"time": "2025-06-30 18:27:05,072", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x73d9aa6d6110> := msg.a
# [+] {"time": "2025-06-30 18:27:05,073", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x73d9bfee2dd0> := msg.unk-0x18
# [+] {"time": "2025-06-30 18:27:05,075", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 24, "label": "msg.unk-0x18", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x73d9aa578eb0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x73d9aa578eb0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.unk-0x18)
# [!]   <BV64 0x0>
# [+] {"time": "2025-06-30 18:27:05,487", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 24600, "size": 8, "pc": 269951, "guards": [], "access": "write", "label": "msg.unk-0x18", "start": 0, "end": 8, "expr": "<BV64 0x0>", "class": "smallworld.analyses.field_detection.hints.PartialByteFieldWriteHint"}}
# [*] Partial write to known field
# [*]   address:    0x6018
# [*]   size:       8
# [*]   pc:         0x41e7f
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg.unk-0x18[0:8]
# [*]   expr:       <BV64 0x0>
# [!] <SimulationManager with 1 deadended>
# [!] []
# [!] State at <BV64 0x41e7f>:
# [!]   Guards:
# [!]   Fields:
# [!]     0x6000 - 0x6010: msg.unk-0x0 = <BV128 msg.unk-0x0>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_8_64 = <BV64 0x0>
# [!]     0x6018 - 0x6030: msg.unk-0x18 = <BV192 msg.unk-0x18>

# %% [markdown]
# Running our updated script gives a very similar hint to the first:
#
# ```
# [*] Partial write to known field
# [*]   pc:         0x41e7f
# [*]   address:    0x6018
# [*]   size:       8
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg.unk.0x18[0:8]
# [*]   expr:       <BV64 0x0>
# ```
#
# In fact, four iterations tell us the same thing;
# the program writes zero to four 8-byte fields right next to each other:

# %%
gdata[0] = smallworld.state.SymbolicValue(16, None, None, "msg.unk-0x0")
gdata[16] = smallworld.state.SymbolicValue(8, None, None, "msg.a")
gdata[24] = smallworld.state.SymbolicValue(8, None, None, "msg.b")
gdata[32] = smallworld.state.SymbolicValue(8, None, None, "msg.c")
gdata[40] = smallworld.state.SymbolicValue(8, None, None, "msg.d")

# %% [markdown]
# Some more iterations, and we start decoding `msg.unk-0x0`.

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6010: <smallworld.state.state.SymbolicValue object at 0x73d9aa5ab400> := msg.unk-0x0
# [+] {"time": "2025-06-30 18:27:05,521", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 16, "label": "msg.unk-0x0", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x73d9bfee3520> := buf
# [+] {"time": "2025-06-30 18:27:05,524", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x73d9bfee2b60> := off
# [+] {"time": "2025-06-30 18:27:05,526", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x73d9aa57bcd0> := msg.a
# [+] {"time": "2025-06-30 18:27:05,528", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x73d9aa57a650> := msg.b
# [+] {"time": "2025-06-30 18:27:05,529", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x73d9aa6d6110> := msg.c
# [+] {"time": "2025-06-30 18:27:05,531", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x73d9bfee2dd0> := msg.d
# [+] {"time": "2025-06-30 18:27:05,533", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x73d9a8bee9b0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x73d9a8bee9b0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf)
# [!]   <BV16 Reverse(buf[4095:4080])>
# [+] {"time": "2025-06-30 18:27:06,395", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24624, "size": 2, "pc": 268304, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x6030
# [*]   size:       2
# [*]   pc:         0x41810
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] <SimulationManager with 1 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41810>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6010: msg.unk-0x0 = <BV128 msg.unk-0x0>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_16_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_17_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_18_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_19_64 = <BV64 0x0>

# %% [markdown]
# Iterating on this process we find that we have multiple 2 byte regions which we identify as parts of `msg.hdr`, since we suspect it's the part of the struct representing the DNS header.  The information in the final 4 bytes of this region are never referenced.  We leave them as a final 4 byte region we call `msg.hdr.unused`:

# %%
gdata[0] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.a")
gdata[2] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.b")
gdata[4] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.c")
gdata[6] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.d")
gdata[8] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.e")
gdata[10] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.f")
gdata[12] = smallworld.state.SymbolicValue(4, None, None, "msg.hdr.unused")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x73d9a8c77f40> := msg.hdr.a
# [+] {"time": "2025-06-30 18:27:06,428", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x73d9bfee3520> := buf
# [+] {"time": "2025-06-30 18:27:06,430", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x73d9bfee2b60> := off
# [+] {"time": "2025-06-30 18:27:06,431", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x73d9aa57bcd0> := msg.a
# [+] {"time": "2025-06-30 18:27:06,433", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x73d9aa57a650> := msg.b
# [+] {"time": "2025-06-30 18:27:06,434", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x73d9aa6d6110> := msg.c
# [+] {"time": "2025-06-30 18:27:06,435", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x73d9bfee2dd0> := msg.d
# [+] {"time": "2025-06-30 18:27:06,436", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x73d9a8c77fa0> := msg.hdr.b
# [+] {"time": "2025-06-30 18:27:06,438", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x73d9aa5ab400> := msg.hdr.c
# [+] {"time": "2025-06-30 18:27:06,440", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x73d9aa5ea920> := msg.hdr.d
# [+] {"time": "2025-06-30 18:27:06,440", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x73d9a8c75f90> := msg.hdr.e
# [+] {"time": "2025-06-30 18:27:06,442", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x73d9a8c755d0> := msg.hdr.f
# [+] {"time": "2025-06-30 18:27:06,443", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x73d9a8c75a80> := msg.hdr.unused
# [+] {"time": "2025-06-30 18:27:06,444", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x73d9a8c75d20>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x73d9a8c75d20>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf)
# [!]   <BV16 Reverse(buf[4095:4080])>
# [+] {"time": "2025-06-30 18:27:07,442", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24624, "size": 2, "pc": 268304, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x6030
# [*]   size:       2
# [*]   pc:         0x41810
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] <SimulationManager with 1 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41810>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a = <BV16 msg.hdr.a>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_34_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_35_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_36_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_37_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b = <BV16 msg.hdr.b>
# [!]     0x6004 - 0x6006: msg.hdr.c = <BV16 msg.hdr.c>
# [!]     0x6006 - 0x6008: msg.hdr.d = <BV16 msg.hdr.d>
# [!]     0x6008 - 0x600a: msg.hdr.e = <BV16 msg.hdr.e>
# [!]     0x600a - 0x600c: msg.hdr.f = <BV16 msg.hdr.f>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>

# %% [markdown]
# Repeating this process for `buf` we can further identify regions which we summarize as:

# %%
gdata[48] = smallworld.state.SymbolicValue(2, None, None, "buf.a")
gdata[50] = smallworld.state.SymbolicValue(2, None, None, "buf.b")
gdata[52] = smallworld.state.SymbolicValue(2, None, None, "buf.c")
gdata[54] = smallworld.state.SymbolicValue(2, None, None, "buf.d")
gdata[56] = smallworld.state.SymbolicValue(2, None, None, "buf.e")
gdata[58] = smallworld.state.SymbolicValue(2, None, None, "buf.f")
gdata[60] = smallworld.state.SymbolicValue(500, None, None, "buf")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x73d9a8c77f40> := msg.hdr.a
# [+] {"time": "2025-06-30 18:27:07,480", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x73d9a8b416c0> := buf.a
# [+] {"time": "2025-06-30 18:27:07,481", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x73d9bfee2b60> := off
# [+] {"time": "2025-06-30 18:27:07,482", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x73d9aa57bcd0> := msg.a
# [+] {"time": "2025-06-30 18:27:07,484", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x73d9aa57a650> := msg.b
# [+] {"time": "2025-06-30 18:27:07,486", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x73d9aa6d6110> := msg.c
# [+] {"time": "2025-06-30 18:27:07,487", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x73d9bfee2dd0> := msg.d
# [+] {"time": "2025-06-30 18:27:07,489", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x73d9a8c77fa0> := msg.hdr.b
# [+] {"time": "2025-06-30 18:27:07,492", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x73d9aa5ab400> := msg.hdr.c
# [+] {"time": "2025-06-30 18:27:07,495", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x73d9aa5ea920> := msg.hdr.d
# [+] {"time": "2025-06-30 18:27:07,498", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x73d9a8c75f90> := msg.hdr.e
# [+] {"time": "2025-06-30 18:27:07,500", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x73d9a8c755d0> := msg.hdr.f
# [+] {"time": "2025-06-30 18:27:07,501", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x73d9a8c75a80> := msg.hdr.unused
# [+] {"time": "2025-06-30 18:27:07,503", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x73d9a8b42da0> := buf.b
# [+] {"time": "2025-06-30 18:27:07,504", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x73d9bfee3520> := buf.c
# [+] {"time": "2025-06-30 18:27:07,506", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x73d9aa6b7be0> := buf.d
# [+] {"time": "2025-06-30 18:27:07,508", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x73d9a8b431f0> := buf.e
# [+] {"time": "2025-06-30 18:27:07,510", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x73d9a8b43610> := buf.f
# [+] {"time": "2025-06-30 18:27:07,513", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x73d9a8b43670> := buf
# [+] {"time": "2025-06-30 18:27:07,516", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x73d9a8c77ca0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x73d9a8c77ca0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_64_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_66_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_68_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_70_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_72_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_67_16>
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x1076>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_63_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_74_64 = <BV64 off_72_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_58_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_59_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_60_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_61_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_65_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_67_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_69_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_71_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_73_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# The work above is summarized in `dns_1.py`.

# %% [markdown]
# # Adding malloc
#
# Notice that the `FieldDetectionAnalysis` routine no longer provides information about a partial access to an known fields, so execution continues.  The last successful read is reported to be at instruction 0x41ed2, and that the analysis ends there with the last known good state being reported as:
#
# ```
# [!] State at <BV64 0x1076>:
# ```
#
# We loaded our ELF at 0x40000 so something's way off.
# If we disassemble the code and look around 0x1ed2 (which is 0x41ed2 minus the loading address 0x40000) we find:
#
# ```
# $> objdump -d -R ./bin/dns.amd64.elf
# ...
#     1ed2:       0f b7 40 04             movzwl 0x4(%rax),%eax
#     1ed6:       48 69 f8 08 01 00 00    imul   $0x108,%rax,%rdi
#     1edd:       e8 8e f1 ff ff          call   1070 <malloc@plt>
# ...
# ```
#
# This is an external call to `malloc()` which we have not loaded.
#
# We have not yet discussed how to handle an external call like this.  One strategey would be to stub out `malloc()` and carry on.  Howerver, we would
# like to know what is happening inside the heap-allocated buffers as well.
# Luckily, `FieldDetectionAnalysis` comes with a malloc model.
# Let's update our harness:

# %% [markdown]
# Note: At this point we recreate our machine so any changes we made along the way are reset.

# %%
def reinitialize_demo_A():
    # Create a machine
    machine = smallworld.state.Machine()

    # Load the code
    filepath = "bin/dns.amd64.elf"
    with open(filepath, "rb") as f:
        code = smallworld.state.memory.code.Executable.from_elf(f, 0x40000)
        machine.add(code)

    # Apply the code's bounds to the machine
    for bound in code.bounds:
       machine.add_bound(bound[0], bound[1])

    # Use the ELF's notion of the platform
    platform = code.platform

    # Create the analysis; we'll need it later.
    analysis = FieldDetectionAnalysis(platform)

    # Create a CPU
    cpu = smallworld.state.cpus.CPU.for_platform(platform)
    machine.add(cpu)

    # Use lief to find the address of parse_dns_message
    sym = code.get_symbol_value("parse_dns_message")
    cpu.rip.set(sym)

    # Add a blank stack
    stack = smallworld.state.memory.stack.Stack.for_platform(
        platform, 0x7FFFFFFFC000, 0x4000
    )
    machine.add(stack)

    stack.push_integer(0x01010101, 8, None)

    # Configure the stack pointer
    sp = stack.get_pointer()
    cpu.rsp.set(sp)
reinitialize_demo_A()
# Out:
# [+] Address: 40000
# [+] {"time": "2025-06-30 18:27:10,678", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:27:10,679", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:27:10,680", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:27:10,681", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}

# %%
from smallworld.analyses.field_detection import MallocModel, FreeModel
# Add a blank heap 
heap = smallworld.state.memory.heap.BumpAllocator(0x20000, 0x10000)
machine.add(heap)

# Configure malloc and free models
malloc = MallocModel(
    0x10000, heap, platform, analysis.mem_read_hook, analysis.mem_write_hook
)
machine.add(malloc)
machine.add_bound(malloc._address, malloc._address + 16)

free = FreeModel(0x1036)
machine.add(free)
machine.add_bound(free._address, free._address + 16)

# %% [markdown]
# This will invoke a function hook mimicking `malloc()` if we call address 0x10000.
# If we were in a raw binary, we'd have to do some manual patching
# to tell it where we put `malloc()`, but this is an ELF.
# Let's use the relocation entries to our advantage:

# %%
# Apply relocations to malloc
code.update_symbol_value("malloc", malloc._address)

# %% [markdown]
# So we can continue our analysis here or if you want to run outside this notebook the worke we have done up to this point is fully contained in `dns_2.py`:

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x20000 - 0x30000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x73d9a8c77f40> := msg.hdr.a
# [+] {"time": "2025-06-30 18:27:10,721", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x73d9a8b416c0> := buf.a
# [+] {"time": "2025-06-30 18:27:10,723", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x73d9bfee2b60> := off
# [+] {"time": "2025-06-30 18:27:10,725", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x73d9aa57bcd0> := msg.a
# [+] {"time": "2025-06-30 18:27:10,726", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x73d9aa57a650> := msg.b
# [+] {"time": "2025-06-30 18:27:10,727", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x73d9aa6d6110> := msg.c
# [+] {"time": "2025-06-30 18:27:10,729", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x73d9bfee2dd0> := msg.d
# [+] {"time": "2025-06-30 18:27:10,730", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x73d9a8c77fa0> := msg.hdr.b
# [+] {"time": "2025-06-30 18:27:10,731", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x73d9aa5ab400> := msg.hdr.c
# [+] {"time": "2025-06-30 18:27:10,732", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x73d9aa5ea920> := msg.hdr.d
# [+] {"time": "2025-06-30 18:27:10,733", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x73d9a8c75f90> := msg.hdr.e
# [+] {"time": "2025-06-30 18:27:10,734", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x73d9a8c755d0> := msg.hdr.f
# [+] {"time": "2025-06-30 18:27:10,735", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x73d9a8c75a80> := msg.hdr.unused
# [+] {"time": "2025-06-30 18:27:10,737", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x73d9a8b42da0> := buf.b
# [+] {"time": "2025-06-30 18:27:10,738", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x73d9bfee3520> := buf.c
# [+] {"time": "2025-06-30 18:27:10,739", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x73d9aa6b7be0> := buf.d
# [+] {"time": "2025-06-30 18:27:10,740", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x73d9a8b431f0> := buf.e
# [+] {"time": "2025-06-30 18:27:10,741", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x73d9a8b43610> := buf.f
# [+] {"time": "2025-06-30 18:27:10,742", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x73d9a8b43670> := buf
# [+] {"time": "2025-06-30 18:27:10,744", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x73d9a8aa1c60>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x73d9a8aa1c60>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_100_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_102_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_104_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_106_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_108_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_103_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.c_103_16
# [*] Concretize them to continue analysis
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x10000>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_99_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_110_64 = <BV64 off_108_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_94_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_95_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_96_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_97_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_101_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_103_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_105_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_107_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_109_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# This ran for much longer, but eventually halted with an error similar to this:
#
# ```
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.c_27_16
# [*] Concretize them to continue analysis
# ```
#
# This output indicates that the analysis was able to deduce that the `msg.hdr.c` field
# gives the numbe of items allocated in our buffer.  In fact, if we scroll up to instruction
# 0x418d0 we see that `msg.hdr.c` gets filled in by the contents of `buf.c` so if we want to
# concretize `msg.hdr.c` we need to assign a concrete value to `buf.c` (and give it a new name):

# %%
gdata[52] = smallworld.state.BytesValue(b"\x00\x01", "buf.msg.hdr.c")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x20000 - 0x30000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x73d9a8c77f40> := msg.hdr.a
# [+] {"time": "2025-06-30 18:27:14,033", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x73d9a8b416c0> := buf.a
# [+] {"time": "2025-06-30 18:27:14,034", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x73d9bfee2b60> := off
# [+] {"time": "2025-06-30 18:27:14,038", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x73d9aa57bcd0> := msg.a
# [+] {"time": "2025-06-30 18:27:14,041", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x73d9aa57a650> := msg.b
# [+] {"time": "2025-06-30 18:27:14,043", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x73d9aa6d6110> := msg.c
# [+] {"time": "2025-06-30 18:27:14,045", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x73d9bfee2dd0> := msg.d
# [+] {"time": "2025-06-30 18:27:14,047", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x73d9a8c77fa0> := msg.hdr.b
# [+] {"time": "2025-06-30 18:27:14,048", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x73d9aa5ab400> := msg.hdr.c
# [+] {"time": "2025-06-30 18:27:14,050", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x73d9aa5ea920> := msg.hdr.d
# [+] {"time": "2025-06-30 18:27:14,052", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x73d9a8c75f90> := msg.hdr.e
# [+] {"time": "2025-06-30 18:27:14,054", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x73d9a8c755d0> := msg.hdr.f
# [+] {"time": "2025-06-30 18:27:14,055", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x73d9a8c75a80> := msg.hdr.unused
# [+] {"time": "2025-06-30 18:27:14,057", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x73d9a8b42da0> := buf.b
# [+] {"time": "2025-06-30 18:27:14,058", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x73d9a8b43400> := buf.msg.hdr.c
# [+] {"time": "2025-06-30 18:27:14,061", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x73d9aa6b7be0> := buf.d
# [+] {"time": "2025-06-30 18:27:14,063", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x73d9a8b431f0> := buf.e
# [+] {"time": "2025-06-30 18:27:14,065", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x73d9a8b43610> := buf.f
# [+] {"time": "2025-06-30 18:27:14,066", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x73d9a8b43670> := buf
# [+] {"time": "2025-06-30 18:27:14,068", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x73d9a88b1a80>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x73d9a88b1a80>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_135_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_137_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_139_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_141_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_143_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_138_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_138_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_146_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_145_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_145_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf)
# [!]   <BV8 buf[3999:3992]>
# [+] {"time": "2025-06-30 18:27:18,219", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24636, "size": 1, "pc": 267639, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_138_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_145_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 1, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603c
# [*]   size:       1
# [*]   pc:         0x41577
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_138_16))> [[<BV16 msg.hdr.c_138_16>]]
# [*]     0x4155a: <Bool cap - off_145_64 >= 0x1> [[<BV64 off_145_64>, <BV64 cap>]]
# [*]   field:      buf[0:1]
# [!] <SimulationManager with 5 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41577>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_138_16))>
# [!]     0x4155a: <Bool cap - off_145_64 >= 0x1>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_134_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_145_64 = <BV64 off_143_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_146_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_130_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_131_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_132_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_136_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_138_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_140_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_142_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_144_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# ## Analyzing the behavior of malloc
#
# Scrolling up to the malloc call after the memory read at 0x41ed2 we see the following output from the malloc:
#
# ```
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [+] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [+]   <BV64 0x20010>
# ```
#
# Let's take this one line at a time:
#
# - `malloc: Alloc'd 264 bytes at 0x20010`:  Since we assigned 0x1 to the length in `buf.c`,
# this line is telling us that space for the struct is 264 bytes (the `malloc()` model would
# warn us if the length computation was more complex than "variable * magnitude".)
#
# - `Storing 8 bytes at 0x20008`: Malloc returns a pointer to the newly allocated memory so the address of the heap memory is stored there. #TODO - confirm this is true?
#
# - `  Length field msg.hdr.c not known`: We haven't told the `malloc()` model that it should track structs allocated using `msg.hdr.c`, or what they should look like. #TODO - review this comment, I don't fully understand it
#
# - `0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)`: The pointer to our new heap array is stored in `msg.a`, making `msg.hdr.c` the length of `msg.a`.
#
# We wrap up this section by noting that execution stopped on another read of a single byte from a larger buffer.  Let's update our harness and run again:

# %%
reinitialize_demo_A()
gdata[60] = smallworld.state.SymbolicValue(1, None, None, "buf.g")
gdata[61] = smallworld.state.SymbolicValue(499, None, None, "buf")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [+] Address: 40000
# [+] {"time": "2025-06-30 18:27:18,257", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:27:18,258", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:27:18,259", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:27:18,260", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x20000 - 0x30000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x73d9a8c77f40> := msg.hdr.a
# [+] {"time": "2025-06-30 18:27:18,268", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x73d9a8b416c0> := buf.a
# [+] {"time": "2025-06-30 18:27:18,270", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x73d9bfee2b60> := off
# [+] {"time": "2025-06-30 18:27:18,273", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x73d9aa57bcd0> := msg.a
# [+] {"time": "2025-06-30 18:27:18,274", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x73d9aa57a650> := msg.b
# [+] {"time": "2025-06-30 18:27:18,276", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x73d9aa6d6110> := msg.c
# [+] {"time": "2025-06-30 18:27:18,277", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x73d9bfee2dd0> := msg.d
# [+] {"time": "2025-06-30 18:27:18,279", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x73d9a8c77fa0> := msg.hdr.b
# [+] {"time": "2025-06-30 18:27:18,281", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x73d9aa5ab400> := msg.hdr.c
# [+] {"time": "2025-06-30 18:27:18,283", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x73d9aa5ea920> := msg.hdr.d
# [+] {"time": "2025-06-30 18:27:18,284", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x73d9a8c75f90> := msg.hdr.e
# [+] {"time": "2025-06-30 18:27:18,285", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x73d9a8c755d0> := msg.hdr.f
# [+] {"time": "2025-06-30 18:27:18,286", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x73d9a8c75a80> := msg.hdr.unused
# [+] {"time": "2025-06-30 18:27:18,288", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unused", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x73d9a8b42da0> := buf.b
# [+] {"time": "2025-06-30 18:27:18,289", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x73d9a8b43400> := buf.msg.hdr.c
# [+] {"time": "2025-06-30 18:27:18,291", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x73d9aa6b7be0> := buf.d
# [+] {"time": "2025-06-30 18:27:18,293", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x73d9a8b431f0> := buf.e
# [+] {"time": "2025-06-30 18:27:18,296", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x73d9a8b43610> := buf.f
# [+] {"time": "2025-06-30 18:27:18,297", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x73d9a8bb3fd0> := buf.g
# [+] {"time": "2025-06-30 18:27:18,300", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.g", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x6230: <smallworld.state.state.SymbolicValue object at 0x73d9a8bb0850> := buf
# [+] {"time": "2025-06-30 18:27:18,303", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 499, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x73d9a8a03d00>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x73d9a8a03d00>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_172_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_172_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_172_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_172_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_174_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_174_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.c)
# [!]   <BV16 Reverse(buf.msg.hdr.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_174_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_174_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_176_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_176_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_176_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_176_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_178_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_178_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_178_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_178_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_180_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_180_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_180_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_180_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_175_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_175_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_183_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_182_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_182_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf.g)
# [!]   <BV8 buf.g>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_182_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_182_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x415c5: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_184_64>
# [!] 0x415c8: READING 0x603d - 0x603e (buf)
# [!]   <BV8 buf[3991:3984]>
# [+] {"time": "2025-06-30 18:27:22,953", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24637, "size": 1, "pc": 267720, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_175_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_182_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 1, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x415c8
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))> [[<BV16 msg.hdr.c_175_16>]]
# [*]     0x4155a: <Bool cap - off_182_64 >= 0x1> [[<BV64 off_182_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) == 192> [[<BV8 buf.g>]]
# [*]   field:      buf[0:1]
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_184_64>
# [!] 0x41652: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_184_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_184_64>
# [!] 0x41a44: READING 0x603d - 0x603f (buf)
# [!]   <BV16 Reverse(buf[3991:3976])>
# [+] {"time": "2025-06-30 18:27:23,373", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24637, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_175_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_182_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268839, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_184_64", 64]}]}, {"op": "BVV", "args": [4, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))> [[<BV16 msg.hdr.c_175_16>]]
# [*]     0x4155a: <Bool cap - off_182_64 >= 0x1> [[<BV64 off_182_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g == 0> [[<BV8 buf.g>]]
# [*]     0x41a27: <Bool cap - off_184_64 >= 0x4> [[<BV64 off_184_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] 0x416b2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_184_64>
# [!] 0x416b9: READING 0x603d - 0x603e (buf)
# [!]   <BV8 buf[3991:3984]>
# [+] {"time": "2025-06-30 18:27:23,704", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24637, "size": 1, "pc": 267961, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_175_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_182_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.g", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_184_64", 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.g", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 1, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x416b9
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))> [[<BV16 msg.hdr.c_175_16>]]
# [*]     0x4155a: <Bool cap - off_182_64 >= 0x1> [[<BV64 off_182_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.g != 0> [[<BV8 buf.g>]]
# [*]     0x415ab: <Bool (buf.g & 192) != 192> [[<BV8 buf.g>]]
# [*]     0x4161c: <Bool (buf.g & 192) == 0> [[<BV8 buf.g>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.g)) < 0xff then 1 else 0) | (if buf.g == 255 then 1 else 0)) != 0> [[<BV8 buf.g>]]
# [*]     0x4165c: <Bool cap - off_184_64 >= (0#32 .. (0#24 .. buf.g))> [[<BV8 buf.g>, <BV64 off_184_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.g))> [[<BV8 buf.g>]]
# [*]   field:      buf[0:1]
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_183_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_183_64>
# [!] <SimulationManager with 16 unsat, 4 deadended>
# [!] []
# [!] State at <BV64 0x415c8>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))>
# [!]     0x4155a: <Bool cap - off_182_64 >= 0x1>
# [!]     0x41592: <Bool buf.g != 0>
# [!]     0x415ab: <Bool (buf.g & 192) == 192>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_171_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_184_64 = <BV64 off_182_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_183_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_167_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_168_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_169_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_173_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_175_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_177_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_179_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_181_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [!] State at <BV64 0x41a44>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))>
# [!]     0x4155a: <Bool cap - off_182_64 >= 0x1>
# [!]     0x41592: <Bool buf.g == 0>
# [!]     0x41a27: <Bool cap - off_184_64 >= 0x4>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_171_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_184_64 = <BV64 off_182_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_183_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_167_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_168_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_169_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_173_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_175_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_177_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_179_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_181_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [!] State at <BV64 0x416b9>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))>
# [!]     0x4155a: <Bool cap - off_182_64 >= 0x1>
# [!]     0x41592: <Bool buf.g != 0>
# [!]     0x415ab: <Bool (buf.g & 192) != 192>
# [!]     0x4161c: <Bool (buf.g & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.g)) < 0xff then 1 else 0) | (if buf.g == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_184_64 >= (0#32 .. (0#24 .. buf.g))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.g))>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_171_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_184_64 = <BV64 off_182_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_183_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_167_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_168_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_169_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_173_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_175_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_177_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_179_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_181_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [!] State at <BV64 0x1036>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_175_16))>
# [!]     0x4155a: <Bool cap - off_182_64 >= 0x1>
# [!]     0x41592: <Bool buf.g != 0>
# [!]     0x415ab: <Bool (buf.g & 192) != 192>
# [!]     0x4161c: <Bool (buf.g & 192) != 0>
# [!]     0x421bd: <Bool msg.a_183_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_171_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_184_64 = <BV64 off_182_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_183_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_167_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_168_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_169_64 = <BV64 0x0>
# [!]     0x6002 - 0x6004: msg.hdr.b_173_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_175_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_177_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_179_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_181_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unused = <BV32 msg.hdr.unused>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6034 - 0x6036: buf.msg.hdr.c = <BV16 buf.msg.hdr.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.g = <BV8 buf.g>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [*] Multiple field defs starting at buf[0]:
# [*]     buf[0:1]
# [*]     buf[0:2]
# [*]   One or more of the following fields may control the format,
# [*]   either as a flag, type code or length:
# [*]     buf.g

# %% [markdown]
# # Stage 2 DNS exploration: Next control field
#
# Moving forward, we get to 4 possible states
# with two live branches identifying different fields.
# Analysis tells us the choice is likely controlled
# by buf.a, either as a length or as a type code.

# %% [markdown]
# ```
#
# [*]     0x41592: <Bool buf.a != 0> [[<BV8 buf.a>]]
# [*]     0x415ab: <Bool (buf.a & 192) == 192> [[<BV8 buf.a>]]
# [*]   field:      buf[0:1]
# ...
# [*]     0x41592: <Bool buf.a == 0> [[<BV8 buf.a>]]
# [*]     0x41a27: <Bool cap - off_36_64 >= 0x4> [[<BV64 off_36_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# ...
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.msg.a.len_27_16))> [[<BV16 msg.hdr.msg.a.len_27_16>]]
# [*]     0x4155a: <Bool cap - off_34_64 >= 0x1> [[<BV64 off_34_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.a != 0> [[<BV8 buf.a>]]
# [*]     0x415ab: <Bool (buf.a & 192) != 192> [[<BV8 buf.a>]]
# [*]     0x4161c: <Bool (buf.a & 192) == 0> [[<BV8 buf.a>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.a)) < 0xff then 1 else 0) | (if buf.a == 255 then 1 else 0)) != 0> [[<BV8 buf.a>]]
# [*]     0x4165c: <Bool cap - off_36_64 >= (0#32 .. (0#24 .. buf.a))> [[<BV8 buf.a>, <BV64 off_36_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.a))> [[<BV8 buf.a>]]
# [*]   field:      buf[0:1]
# ...
#
# ```

# %%
def reinitialize_demo_B():
    reinitialize_demo_A()
    from smallworld.analyses.field_detection import MallocModel, FreeModel
    import claripy
    
    # Add a blank heap
    heap = smallworld.state.memory.heap.BumpAllocator(0x20000, 0x10000)
    machine.add(heap)

    # Configure malloc and free models
    malloc = MallocModel(
        0x10000, heap, platform, analysis.mem_read_hook, analysis.mem_write_hook
    )
    machine.add(malloc)
    machine.add_bound(malloc._address, malloc._address + 16)

    free = FreeModel(0x1036)
    machine.add(free)
    machine.add_bound(free._address, free._address + 16)

    # Apply relocations to malloc
    code.update_symbol_value("malloc", malloc._address)



# Add constraint to buf.a
machine.add_constraint(
    claripy.UGT(claripy.BVS("buf.g", 8, explicit_name=True), claripy.BVV(0, 8))
)
machine.analyze(analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-06-30 18:28:31,204", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:28:31,206", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:28:31,208", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-06-30 18:28:31,209", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[20], line 8
#       4 # Add constraint to buf.a
#       5 machine.add_constraint(
#       6     claripy.UGT(claripy.BVS("buf.g", 8, explicit_name=True), claripy.BVV(0, 8))
#       7 )
# ----> 8 machine.analyze(analysis)
#
# File ~/SmallWorld/smallworld/smallworld/state/state.py:805, in Machine.analyze(self, analysis)
#     798 def analyze(self, analysis: analyses.Analysis) -> None:
#     799     """Run the given analysis on this machine.
#     800
#     801     Arguments:
#     802         analysis: The analysis to run.
#     803     """
# --> 805     analysis.run(self)
#
# File ~/SmallWorld/smallworld/smallworld/analyses/field_detection/field_analysis.py:341, in FieldDetectionMixin.run(self, machine)
#     337 filt.activate()
#     339 # Set up the emulator
# --> 341 machine.apply(self.emulator)
#     342 self.emulator.add_extension("fda", fda)
#     344 # Capture the labeled memory ranges
#
# File ~/SmallWorld/smallworld/smallworld/state/state.py:757, in Machine.apply(self, emulator)
#     755     emulator.add_exit_point(address)
#     756 for start, end in self.get_bounds():
# --> 757     emulator.add_bound(start, end)
#     759 if isinstance(emulator, emulators.ConstrainedEmulator):
#     760     for expr in self._constraints:
#
# File ~/SmallWorld/smallworld/smallworld/emulators/angr/angr.py:1402, in AngrEmulator.add_bound(self, start, end)
#    1399     self._code_bounds.append((start, end))
#    1401 elif self._dirty and not self._linear:
# -> 1402     raise NotImplementedError(
#    1403         "Accessing bounds not supported once execution begins"
#    1404     )
#    1406 else:
#    1407     self.state.scratch.bounds.add_range((start, end))
#
# NotImplementedError: Accessing bounds not supported once execution begins
