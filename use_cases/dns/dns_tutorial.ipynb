# %% [markdown]
# # Deducing Struct Layout with Symbolic Execution
# The goal of this tutorial is to determine the input format
# accepted by the test program `dns.{arch}.elf`
# without reading the source or resorting to manual RE.
#
# We'll use memory labelling to lay out a hypothetical message structure
# in our machine state, and then use `FieldDetectionAnalysis` to
# detect inconsistencies between our hypothesis and how the code accesses the data.
# By iterating this process, we will refine our hypothesis until it matches
# what the code accepts.

# %% [markdown]
# ## Setup & Installation
# Install the required packages as described in the install directions.
#
# You can build the example programs by running `make all` from this directory.
# This requires the cross-compiler toolchains installed as part of the apt dependencies;
# this analysis will work on any architecture supported by angr.
#
# Let's test this program against the example input `examples/answer.dat`:
#
# ```
# $> hexdump -C examples/answer.dat
# 00000000  ce 70 81 80 00 01 00 01  00 00 00 01 06 67 6f 6f  |.p...........goo|
# 00000010  67 6c 65 03 63 6f 6d 00  00 01 00 01 c0 0c 00 01  |gle.com.........|
# 00000020  00 01 00 00 00 d2 00 04  8e fa 41 ce 00 00 29 04  |..........A...).|
# 00000030  c4 00 00 00 00 00 1c 00  0a 00 18 cb 6e 4b 21 27  |............nK!'|
# 00000040  ca a2 eb 8f fc 9f 64 67  85 5f 7f cf 3e 38 e4 56  |......dg._..>8.V|
# 00000050  80 72 f9                                          |.r.|
# 00000053
#
# $> ./bin/dns.amd64.elf examples/answer.dat
# DNS Message:
#         TID:          ce70
#         FLAGS:        0120
#         # Questions:  1
#         # Answers:    0
#         # Auth. Rs:   0
#         # Extra Rs:   1
# Question:
#         Name:         google.com
#         Type:         1
#         Class:        1
# Record:
#         Name:
#         Type:         41
#         Class:        1232
# ```
#
# If it's not apparent yet, this program parses basic DNS messages.
# However, the exact structure accepted by the parser isn't obvious.
# We could decompile the binary and try to elicit the structure but
# we are going to use SmallWord analysis capabilites to figure it out.
#
# ## Harnessing the Parser
#
# For sanity's sake, let's assume we know that the parser is implemented in `parse_dns_msg()`,
# and that we roughly know its arguments from `main()`:
#
# - **Arg 1:** `uint8_t *` pointing to an input buffer
# - **Arg 2:** `size_t` holding its size
# - **Arg 3:** `size_t *` pointing to a value starting at zero
# - **Arg 4:** `struct *` pointing to an unknown struct
#
# Our goal for this exercise is to figure out the structure of argument 1,
# which we'll call `buf`, and argument 4, which we'll call `msg`.
#
# First, we set up some smallworld boilerplate.
# This configures logging, as well as the hinter
# that will let us see the output from our analysis.

# %%
import warnings

warnings.filterwarnings(
    "ignore", message="Protobuf gencode version .* is exactly one major version older.*"
)

# %%
import logging
import pathlib
import claripy  # from angr, an abstracted constraint-solving wrapper
import timeout_decorator  # to allow capping execution time for symbolic analysis
import smallworld
import smallworld.analyses.field_detection
import smallworld.analyses.unstable.angr.visitor
from smallworld.analyses.field_detection import FieldDetectionAnalysis

# Set up logging and hinting
smallworld.logging.setup_logging(level=logging.INFO, force_colors=True)
smallworld.hinting.setup_hinting(stream=True, verbose=True, force_colors=True)

log = logging.getLogger("smallworld")

# %% [markdown]
# Next, we create the basic machine state, load our ELF file into a smallworld state object, and add the code to the machine.
#
# Since we don't expect a specific platform, we can use the platform definition parsed out of the ELF headers.
#
# Also, since this is the only ELF we're loading, we can use its notion of program bounds to define which memory the analysis can execute.

# %%
# Create a machine
machine = smallworld.state.Machine()

# Load the code
filepath = "bin/dns.amd64.elf"
with open(filepath, "rb") as f:
    code = smallworld.state.memory.code.Executable.from_elf(f, 0x40000)
    machine.add(code)

# Apply the code's bounds to the machine
for bound in code.bounds:
    machine.add_bound(bound[0], bound[1])

# Use the ELF's notion of the platform
platform = code.platform

# Create the analysis; we'll need it later.
analysis = FieldDetectionAnalysis(platform)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-09-05 14:15:14,064", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:14,065", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:14,066", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:14,066", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}

# %%
# Create a CPU
cpu = smallworld.state.cpus.CPU.for_platform(platform)
machine.add(cpu)

# Use lief to find the address of parse_dns_message
sym = code.get_symbol_value("parse_dns_message")
cpu.rip.set(sym)

# Add a blank stack
stack = smallworld.state.memory.stack.Stack.for_platform(
    platform, 0x7FFFFFFFC000, 0x4000
)
machine.add(stack)

stack.push_integer(0x01010101, 8, None)

# Configure the stack pointer
sp = stack.get_pointer()
cpu.rsp.set(sp)

# %% [markdown]
# ## Setting up memory
# Now that we have the program set up, we can start to model the inputs to `parse_dns_message()`.
# We know we need a message struct, a memory buffer, and a `size_t`
# that are all passed by reference.
#
# For ease of modelling, let's just allocate them all as globals.
#
# To start, we'll allocate `buf` and `msg` as blank swaths of memory.
# As we learn more about their internal structure from the analysis,
# we will come back and refine this part of our harness.

# %%
# Configure somewhere for arguments to live
gdata = smallworld.state.memory.Memory(0x6000, 0x1000)
machine.add(gdata)
# DNS message struct
# Sort of cheating that I know how big it is.
gdata[0] = smallworld.state.SymbolicValue(48, None, None, "msg")
# Input buffer
gdata[48] = smallworld.state.SymbolicValue(512, None, None, "buf")
# Offset into buffer
gdata[560] = smallworld.state.IntegerValue(0, 8, "off", False)

# %% [markdown]
# Next, we use what we know about the function signature to assign values to registers.
# We know that the first arg points to `buf`, the second is the size of `buf`,
# the third points to `off`, and the fourth points to `msg`.

# %%
# Configure arguments
# arg 0: pointer to buf
cpu.rdi.set(gdata.address + 48)
cpu.rdi.set_label("PTR buf")
# arg 1: buffer capacity
cpu.rsi.set(512)
cpu.rsi.set_label("cap")
# arg 2: pointer to off
cpu.rdx.set(gdata.address + 560)
cpu.rdx.set_label("PTR off")
# arg 3: pointer to msg
cpu.rcx.set(gdata.address)
cpu.rcx.set_label("PTR msg")

# %% [markdown]
# Because we'll be using symbolic analysis, we'll want the option to set a timeout on analysis, in case the state explodes. We'll define an `analysis_with_timeout` function here

# %%
# We're going to create the option to pass a timeout when doing analysis
@timeout_decorator.timeout(120)  # argument is in seconds
def analyze_with_timeout(machine, analysis):
    try:
        machine.analyze(analysis)
    except timeout_decorator.timeout_decorator.TimeoutError:
        print("Analysis timeout")

# %% [markdown]
# At long last, we're reading to actually run our analysis, this time we won't have to worry about state explosion.

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg
# [+] {"time": "2025-09-05 14:15:14,110", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 48, "label": "msg", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7568b6c4d060> := buf
# [+] {"time": "2025-09-05 14:15:14,112", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:14,114", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x756894b42200>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x756894b42200>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] Self-modifying code is not always correctly optimized by PyVEX. To guarantee correctness, VEX optimizations have been disabled.
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg)
# [!]   <BV64 0x0>
# [+] {"time": "2025-09-05 14:15:14,505", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 24592, "size": 8, "pc": 269939, "guards": [], "access": "write", "label": "msg", "start": 16, "end": 24, "expr": "<BV64 0x0>", "class": "smallworld.analyses.field_detection.hints.PartialByteFieldWriteHint"}}
# [*] Partial write to known field
# [*]   address:    0x6010
# [*]   size:       8
# [*]   pc:         0x41e73
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg[16:24]
# [*]   expr:       <BV64 0x0>
# [!] <SimulationManager with 1 deadended>
# [!] []
# [!] State at <BV64 0x41e73>:
# [!]   Guards:
# [!]   Fields:
# [!]     0x6000 - 0x6030: msg = <BV384 msg>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>

# %% [markdown]
# _The work so far is captured in `dns_0.py`_
#
# ## Deducing Accessed Fields
# The analysis produced by `FieldDetectionAnalysis` yields the following hint:
#
# ```
# [*] Partial write to known field
# [*]   address:    0x6010
# [*]   size:       8
# [*]   pc:         0x41e73
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg[16:24]
# [*]   expr:       <BV64 0x0>
# ```
# The code at `0x41e73` tried to write 8 bytes of zero starting 16 bytes into our `msg` buffer.
# But we defined `msg` as a 48 byte contiguous region and didn't expect to see a field.
#
# With this information in hand we can redefine `msg` as the following

# %%
gdata[0] = smallworld.state.SymbolicValue(
    16, None, None, "msg.hdr.unk"
)  # we're going to assume the first bytes are a header
gdata[16] = smallworld.state.SymbolicValue(8, None, None, "msg.a")
gdata[24] = smallworld.state.SymbolicValue(24, None, None, "msg.unk")

# %% [markdown]
# We're not sure what `msg.a` is, but we know it's very likely a field.
# We're on our way!
#
# Running our updated script gives a very similar hint to the first:

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6010: <smallworld.state.state.SymbolicValue object at 0x756894bb2a40> := msg.hdr.unk
# [+] {"time": "2025-09-05 14:15:14,535", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 16, "label": "msg.hdr.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7568b6c4d060> := buf
# [+] {"time": "2025-09-05 14:15:14,536", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:14,537", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x756894b42380> := msg.a
# [+] {"time": "2025-09-05 14:15:14,538", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg.unk
# [+] {"time": "2025-09-05 14:15:14,540", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 24, "label": "msg.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7568931d9480>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7568931d9480>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.unk)
# [!]   <BV64 0x0>
# [+] {"time": "2025-09-05 14:15:14,913", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 24600, "size": 8, "pc": 269951, "guards": [], "access": "write", "label": "msg.unk", "start": 0, "end": 8, "expr": "<BV64 0x0>", "class": "smallworld.analyses.field_detection.hints.PartialByteFieldWriteHint"}}
# [*] Partial write to known field
# [*]   address:    0x6018
# [*]   size:       8
# [*]   pc:         0x41e7f
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg.unk[0:8]
# [*]   expr:       <BV64 0x0>
# [!] <SimulationManager with 1 deadended>
# [!] []
# [!] State at <BV64 0x41e7f>:
# [!]   Guards:
# [!]   Fields:
# [!]     0x6000 - 0x6010: msg.hdr.unk = <BV128 msg.hdr.unk>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_8_64 = <BV64 0x0>
# [!]     0x6018 - 0x6030: msg.unk = <BV192 msg.unk>

# %% [markdown]
# Running our updated script gives a very similar hint to the first:
#
# ```
# [*] Partial write to known field
# [*]   address:    0x6018
# [*]   size:       8
# [*]   pc:         0x41e7f
# [*]   access:     write
# [*]   guards:
# [*]   field:      msg.unk[0:8]
# [*]   expr:       <BV64 0x0>
# ```
#
# In fact, four iterations tell us the same thing;
# the program writes zero to four 8-byte fields right next to each other:

# %%
gdata[0] = smallworld.state.SymbolicValue(16, None, None, "msg.hdr.unk")
gdata[16] = smallworld.state.SymbolicValue(8, None, None, "msg.a")
gdata[24] = smallworld.state.SymbolicValue(8, None, None, "msg.b")
gdata[32] = smallworld.state.SymbolicValue(8, None, None, "msg.c")
gdata[40] = smallworld.state.SymbolicValue(8, None, None, "msg.d")

# %%
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6010: <smallworld.state.state.SymbolicValue object at 0x75689323beb0> := msg.hdr.unk
# [+] {"time": "2025-09-05 14:15:14,943", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 16, "label": "msg.hdr.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7568b6c4d060> := buf
# [+] {"time": "2025-09-05 14:15:14,944", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 512, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:14,945", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7568931d9420> := msg.a
# [+] {"time": "2025-09-05 14:15:14,947", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x756894bb2a40> := msg.b
# [+] {"time": "2025-09-05 14:15:14,948", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x756894b42380> := msg.c
# [+] {"time": "2025-09-05 14:15:14,950", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg.d
# [+] {"time": "2025-09-05 14:15:14,951", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x756893252a10>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x756893252a10>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf)
# [!]   <BV16 Reverse(buf[4095:4080])>
# [+] {"time": "2025-09-05 14:15:15,739", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24624, "size": 2, "pc": 268304, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x6030
# [*]   size:       2
# [*]   pc:         0x41810
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] <SimulationManager with 1 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41810>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6010: msg.hdr.unk = <BV128 msg.hdr.unk>
# [!]     0x6030 - 0x6230: buf = <BV4096 buf>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_16_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_17_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_18_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_19_64 = <BV64 0x0>

# %% [markdown]
# Continuing this process we first find that we have a 2 byte regions of `buf` referenced. Let's label it and move forward.
#
# Also remember, we'll also need to redefine the memory _after_ this 2 byte variable so that smallworld is tracking the memory space and will alert us to accesses.

# %%
gdata[48] = smallworld.state.SymbolicValue(2, None, None, "buf.a")
gdata[50] = smallworld.state.SymbolicValue(510, None, None, "buf")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6010: <smallworld.state.state.SymbolicValue object at 0x75689323beb0> := msg.hdr.unk
# [+] {"time": "2025-09-05 14:15:15,759", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 16, "label": "msg.hdr.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x756894b26920> := buf.a
# [+] {"time": "2025-09-05 14:15:15,761", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:15,762", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7568931d9420> := msg.a
# [+] {"time": "2025-09-05 14:15:15,764", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x756894bb2a40> := msg.b
# [+] {"time": "2025-09-05 14:15:15,766", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x756894b42380> := msg.c
# [+] {"time": "2025-09-05 14:15:15,768", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg.d
# [+] {"time": "2025-09-05 14:15:15,769", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x756894b26fe0> := buf
# [+] {"time": "2025-09-05 14:15:15,770", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 510, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7568930e3070>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7568930e3070>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.unk)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [+] {"time": "2025-09-05 14:15:16,640", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 24576, "size": 2, "pc": 268349, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "write", "label": "msg.hdr.unk", "start": 0, "end": 2, "expr": "<BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>", "class": "smallworld.analyses.field_detection.hints.PartialByteFieldWriteHint"}}
# [*] Partial write to known field
# [*]   address:    0x6000
# [*]   size:       2
# [*]   pc:         0x4183d
# [*]   access:     write
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]   field:      msg.hdr.unk[0:2]
# [*]   expr:       <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!] <SimulationManager with 1 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x4183d>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6010: msg.hdr.unk = <BV128 msg.hdr.unk>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off = <BV64 off>
# [!]     0x6010 - 0x6018: msg.a_29_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_30_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_31_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_32_64 = <BV64 0x0>
# [!]     0x6032 - 0x6230: buf = <BV4080 buf>

# %% [markdown]
# Iterating on this process we find that we have multiple 2 byte regions which we identify as parts of `msg.hdr`, since we suspect it's the part of the struct representing the DNS header.  The information in the final 4 bytes of this region are never referenced.  We leave them as a final 4 byte region we call `msg.hdr.unused`:

# %%
gdata[0] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.a")
gdata[2] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.b")
gdata[4] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.c")
gdata[6] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.d")
gdata[8] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.e")
gdata[10] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.f")
gdata[12] = smallworld.state.SymbolicValue(4, None, None, "msg.hdr.unk")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x75689320e3e0> := msg.hdr.a
# [+] {"time": "2025-09-05 14:15:16,662", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x756894b26920> := buf.a
# [+] {"time": "2025-09-05 14:15:16,664", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:16,665", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7568931d9420> := msg.a
# [+] {"time": "2025-09-05 14:15:16,667", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x756894bb2a40> := msg.b
# [+] {"time": "2025-09-05 14:15:16,667", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x756894b42380> := msg.c
# [+] {"time": "2025-09-05 14:15:16,669", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg.d
# [+] {"time": "2025-09-05 14:15:16,670", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x756894b26fe0> := buf
# [+] {"time": "2025-09-05 14:15:16,671", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 510, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x75689320c0a0> := msg.hdr.b
# [+] {"time": "2025-09-05 14:15:16,672", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x75689323beb0> := msg.hdr.c
# [+] {"time": "2025-09-05 14:15:16,674", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x75689323ace0> := msg.hdr.d
# [+] {"time": "2025-09-05 14:15:16,676", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7568931b5810> := msg.hdr.e
# [+] {"time": "2025-09-05 14:15:16,678", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7568931b50c0> := msg.hdr.f
# [+] {"time": "2025-09-05 14:15:16,679", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7568931b52d0> := msg.hdr.unk
# [+] {"time": "2025-09-05 14:15:16,680", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x75689317e1d0>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x75689317e1d0>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_54_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf)
# [!]   <BV16 Reverse(buf[4079:4064])>
# [+] {"time": "2025-09-05 14:15:17,994", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24626, "size": 2, "pc": 268377, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x6032
# [*]   size:       2
# [*]   pc:         0x41859
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] <SimulationManager with 1 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41859>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_53_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_54_64 = <BV64 Reverse(off) + 0x2>
# [!]     0x6010 - 0x6018: msg.a_48_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_49_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_50_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_51_64 = <BV64 0x0>
# [!]     0x6032 - 0x6230: buf = <BV4080 buf>
# [!]     0x6002 - 0x6004: msg.hdr.b = <BV16 msg.hdr.b>
# [!]     0x6004 - 0x6006: msg.hdr.c = <BV16 msg.hdr.c>
# [!]     0x6006 - 0x6008: msg.hdr.d = <BV16 msg.hdr.d>
# [!]     0x6008 - 0x600a: msg.hdr.e = <BV16 msg.hdr.e>
# [!]     0x600a - 0x600c: msg.hdr.f = <BV16 msg.hdr.f>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>

# %% [markdown]
# Repeating this process for the remaining part of `buf` we can further identify regions which we summarize as:

# %%
gdata[50] = smallworld.state.SymbolicValue(2, None, None, "buf.b")
gdata[52] = smallworld.state.SymbolicValue(2, None, None, "buf.c")
gdata[54] = smallworld.state.SymbolicValue(2, None, None, "buf.d")
gdata[56] = smallworld.state.SymbolicValue(2, None, None, "buf.e")
gdata[58] = smallworld.state.SymbolicValue(2, None, None, "buf.f")
gdata[60] = smallworld.state.SymbolicValue(500, None, None, "buf")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x75689320e3e0> := msg.hdr.a
# [+] {"time": "2025-09-05 14:15:18,035", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x756894b26920> := buf.a
# [+] {"time": "2025-09-05 14:15:18,038", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:18,039", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7568931d9420> := msg.a
# [+] {"time": "2025-09-05 14:15:18,042", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x756894bb2a40> := msg.b
# [+] {"time": "2025-09-05 14:15:18,043", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x756894b42380> := msg.c
# [+] {"time": "2025-09-05 14:15:18,044", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg.d
# [+] {"time": "2025-09-05 14:15:18,046", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7568931b7bb0> := buf.b
# [+] {"time": "2025-09-05 14:15:18,047", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x75689320c0a0> := msg.hdr.b
# [+] {"time": "2025-09-05 14:15:18,048", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x75689323beb0> := msg.hdr.c
# [+] {"time": "2025-09-05 14:15:18,050", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x75689323ace0> := msg.hdr.d
# [+] {"time": "2025-09-05 14:15:18,050", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7568931b5810> := msg.hdr.e
# [+] {"time": "2025-09-05 14:15:18,051", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7568931b50c0> := msg.hdr.f
# [+] {"time": "2025-09-05 14:15:18,053", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7568931b52d0> := msg.hdr.unk
# [+] {"time": "2025-09-05 14:15:18,054", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x7568931b6e60> := buf.c
# [+] {"time": "2025-09-05 14:15:18,055", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x756894b26fe0> := buf.d
# [+] {"time": "2025-09-05 14:15:18,056", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7568930e33a0> := buf.e
# [+] {"time": "2025-09-05 14:15:18,057", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7568931b7370> := buf.f
# [+] {"time": "2025-09-05 14:15:18,058", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7568931b71f0> := buf
# [+] {"time": "2025-09-05 14:15:18,059", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x756892ee4040>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x756892ee4040>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_80_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_80_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_80_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_80_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_82_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_82_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_82_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_82_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_84_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_84_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_84_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_84_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_86_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_86_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_86_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_86_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_88_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_88_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_88_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_88_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_83_16>
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x1076>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_79_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_90_64 = <BV64 off_88_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_74_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_75_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_76_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_77_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_81_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_83_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_85_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_87_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_89_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# _The work so far is captured in `dns_1.py`_

# %% [markdown]
# ## Bringing in Malloc
# Notice that the `FieldDetectionAnalysis` routine no longer provides information about a partial access to a known field, so execution continues.  The last successful read is reported to be at instruction `0x41ed2`, and that the analysis ends there with the last known good state being reported as:
#
# ```
# [!] State at <BV64 0x1076>:
# ```
#
# We loaded our ELF at `0x40000` so something's way off.
# If we disassemble the code and look around `0x1ed2` (which is `0x41ed2` minus the loading address `0x40000`) we find:
#
# ```
# $> objdump -d -R ./bin/dns.amd64.elf
# ...
#     1ed2:       0f b7 40 04             movzwl 0x4(%rax),%eax
#     1ed6:       48 69 f8 08 01 00 00    imul   $0x108,%rax,%rdi
#     1edd:       e8 8e f1 ff ff          call   1070 <malloc@plt>
# ...
# ```
#
# This is an external call to `malloc()` which we have not loaded.
#
# We have not yet discussed how to handle an external call like this.  One strategey would be to stub out `malloc()` and carry on.  Howerver, we would like to know what is happening inside the heap-allocated buffers as well. Luckily, `FieldDetectionAnalysis` comes with a malloc model.
#
# Let's update our harness:

# %% [markdown]
# _Note: At this point we recreate our machine so any changes we made along the way are reset._

# %%
def reinitialize_demo():
    # reinitializing outside of this routine
    global machine
    global platform
    global analysis
    global cpu
    global sym
    global stack
    global sp
    global code

    # Create a machine
    machine = smallworld.state.Machine()

    # Load the code
    filepath = "bin/dns.amd64.elf"
    with open(filepath, "rb") as f:
        code = smallworld.state.memory.code.Executable.from_elf(f, 0x40000)
        machine.add(code)

    # Apply the code's bounds to the machine
    for bound in code.bounds:
        machine.add_bound(bound[0], bound[1])

    # Use the ELF's notion of the platform
    platform = code.platform

    # Create the analysis; we'll need it later.
    analysis = FieldDetectionAnalysis(platform)

    # Create a CPU
    cpu = smallworld.state.cpus.CPU.for_platform(platform)
    machine.add(cpu)

    # Use lief to find the address of parse_dns_message
    sym = code.get_symbol_value("parse_dns_message")
    cpu.rip.set(sym)

    # Add a blank stack
    stack = smallworld.state.memory.stack.Stack.for_platform(
        platform, 0x7FFFFFFFC000, 0x4000
    )
    machine.add(stack)
    machine.add(gdata)

    stack.push_integer(0x01010101, 8, None)

    # Configure the stack pointer
    sp = stack.get_pointer()
    cpu.rsp.set(sp)

    # Configure arguments
    # arg 0: pointer to buf
    cpu.rdi.set(gdata.address + 48)
    cpu.rdi.set_label("PTR buf")
    # arg 1: buffer capacity
    cpu.rsi.set(512)
    cpu.rsi.set_label("cap")
    # arg 2: pointer to off
    cpu.rdx.set(gdata.address + 560)
    cpu.rdx.set_label("PTR off")
    # arg 3: pointer to msg
    cpu.rcx.set(gdata.address)
    cpu.rcx.set_label("PTR msg")


reinitialize_demo()
# Out:
# [+] Address: 40000
# [+] {"time": "2025-09-05 14:15:21,237", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:21,239", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:21,240", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:21,240", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}

# %%
from smallworld.analyses.field_detection import MallocModel, FreeModel

# Add a blank heap
heap = smallworld.state.memory.heap.BumpAllocator(0x20000, 0x10000)
machine.add(heap)

# Configure malloc and free models
malloc = MallocModel(
    0x10000, heap, platform, analysis.mem_read_hook, analysis.mem_write_hook
)
machine.add(malloc)
machine.add_bound(malloc._address, malloc._address + 16)

free = FreeModel(0x1036)
machine.add(free)
machine.add_bound(free._address, free._address + 16)

# %% [markdown]
# This will invoke a function hook mimicking `malloc()` if we call address `x10000`. If we were in a raw binary, we'd have to do some manual patching to tell it where we put `malloc()`, but this is an ELF.
#
# Let's use the relocation entries to our advantage:

# %%
# Apply relocations to malloc
code.update_symbol_value("malloc", malloc._address)

# %%
machine.analyze(analysis)
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x20000 - 0x30000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x75689320e3e0> := msg.hdr.a
# [+] {"time": "2025-09-05 14:15:21,267", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x756894b26920> := buf.a
# [+] {"time": "2025-09-05 14:15:21,268", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:21,270", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7568931d9420> := msg.a
# [+] {"time": "2025-09-05 14:15:21,271", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x756894bb2a40> := msg.b
# [+] {"time": "2025-09-05 14:15:21,272", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x756894b42380> := msg.c
# [+] {"time": "2025-09-05 14:15:21,273", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg.d
# [+] {"time": "2025-09-05 14:15:21,274", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7568931b7bb0> := buf.b
# [+] {"time": "2025-09-05 14:15:21,275", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x75689320c0a0> := msg.hdr.b
# [+] {"time": "2025-09-05 14:15:21,276", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x75689323beb0> := msg.hdr.c
# [+] {"time": "2025-09-05 14:15:21,277", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x75689323ace0> := msg.hdr.d
# [+] {"time": "2025-09-05 14:15:21,278", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7568931b5810> := msg.hdr.e
# [+] {"time": "2025-09-05 14:15:21,279", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7568931b50c0> := msg.hdr.f
# [+] {"time": "2025-09-05 14:15:21,280", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7568931b52d0> := msg.hdr.unk
# [+] {"time": "2025-09-05 14:15:21,281", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.SymbolicValue object at 0x7568931b6e60> := buf.c
# [+] {"time": "2025-09-05 14:15:21,282", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x756894b26fe0> := buf.d
# [+] {"time": "2025-09-05 14:15:21,283", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7568930e33a0> := buf.e
# [+] {"time": "2025-09-05 14:15:21,284", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7568931b7370> := buf.f
# [+] {"time": "2025-09-05 14:15:21,285", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7568931b71f0> := buf
# [+] {"time": "2025-09-05 14:15:21,286", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x756894b40520>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x756894b40520>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_116_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_116_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_116_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_116_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_118_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_118_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.c)
# [!]   <BV16 Reverse(buf.c)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_118_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_118_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_120_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_120_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_120_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_120_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_122_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_122_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_122_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_122_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_124_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_124_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_124_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_124_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_119_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.c_119_16
# [*] Concretize them to continue analysis
# [!] <SimulationManager with 2 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x10000>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_115_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_126_64 = <BV64 off_124_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_110_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_111_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_112_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_113_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_117_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_119_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.c)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.c)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_121_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_123_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_125_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.c = <BV16 buf.c>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# _The work so far is captured in `dns_2.py`_
#
# This ran for much longer, but eventually halted with an error similar to this:
#
# ```
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.c_119_16
# [*] Concretize them to continue analysis
# ```
#
# This output indicates that the analysis was able to deduce that the `msg.hdr.c` field gives the numbe of items allocated in our buffer.  In fact, if we scroll up to instruction `0x418d0` we see that `msg.hdr.c` gets filled in by the contents of `buf.c`.
#
# In order to concretize `msg.hdr.c` we need to assign a concrete value to `buf.c` (and give it a new name):

# %%
gdata[52] = smallworld.state.BytesValue(b"\x00\x01", "buf.msg.a.len")
machine.analyze(FieldDetectionAnalysis(platform))
# Out:
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x20000 - 0x30000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x75689320e3e0> := msg.hdr.a
# [+] {"time": "2025-09-05 14:15:24,442", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x756894b26920> := buf.a
# [+] {"time": "2025-09-05 14:15:24,443", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:24,444", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7568931d9420> := msg.a
# [+] {"time": "2025-09-05 14:15:24,445", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x756894bb2a40> := msg.b
# [+] {"time": "2025-09-05 14:15:24,447", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x756894b42380> := msg.c
# [+] {"time": "2025-09-05 14:15:24,447", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg.d
# [+] {"time": "2025-09-05 14:15:24,448", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7568931b7bb0> := buf.b
# [+] {"time": "2025-09-05 14:15:24,449", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x75689320c0a0> := msg.hdr.b
# [+] {"time": "2025-09-05 14:15:24,451", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x75689323beb0> := msg.hdr.c
# [+] {"time": "2025-09-05 14:15:24,452", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x75689323ace0> := msg.hdr.d
# [+] {"time": "2025-09-05 14:15:24,453", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7568931b5810> := msg.hdr.e
# [+] {"time": "2025-09-05 14:15:24,454", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7568931b50c0> := msg.hdr.f
# [+] {"time": "2025-09-05 14:15:24,455", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7568931b52d0> := msg.hdr.unk
# [+] {"time": "2025-09-05 14:15:24,456", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x756892d97490> := buf.msg.a.len
# [+] {"time": "2025-09-05 14:15:24,457", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.a.len", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x756894b26fe0> := buf.d
# [+] {"time": "2025-09-05 14:15:24,458", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7568930e33a0> := buf.e
# [+] {"time": "2025-09-05 14:15:24,459", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7568931b7370> := buf.f
# [+] {"time": "2025-09-05 14:15:24,460", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7568931b71f0> := buf
# [+] {"time": "2025-09-05 14:15:24,461", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 500, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x756892c22890>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x756892c22890>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_151_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_151_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_151_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_151_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_153_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.a.len)
# [!]   <BV16 Reverse(buf.msg.a.len)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_153_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.a.len)
# [!]   <BV16 Reverse(buf.msg.a.len)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.a.len)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.a.len)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.c
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_153_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_153_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_155_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_155_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_155_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_155_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_157_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_157_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_157_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_157_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_159_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_159_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_159_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_159_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_154_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.c)
# [!]   <BV16 msg.hdr.c_154_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_162_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_161_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_161_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf)
# [!]   <BV8 buf[3999:3992]>
# [+] {"time": "2025-09-05 14:15:28,607", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24636, "size": 1, "pc": 267639, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.c_154_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_161_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 1, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603c
# [*]   size:       1
# [*]   pc:         0x41577
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_154_16))> [[<BV16 msg.hdr.c_154_16>]]
# [*]     0x4155a: <Bool cap - off_161_64 >= 0x1> [[<BV64 off_161_64>, <BV64 cap>]]
# [*]   field:      buf[0:1]
# [!] <SimulationManager with 5 unsat, 1 deadended>
# [!] []
# [!] State at <BV64 0x41577>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.c_154_16))>
# [!]     0x4155a: <Bool cap - off_161_64 >= 0x1>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_150_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_161_64 = <BV64 off_159_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_162_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_146_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_147_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_148_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_152_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.c_154_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.a.len)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.a.len)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_156_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_158_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_160_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.a.len = <BV16 buf.msg.a.len>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x6230: buf = <BV4000 buf>

# %% [markdown]
# ## Analyzing the behavior of malloc
#
# Scrolling up to the malloc call after the memory read at `0x41ed2` we see the following output from the malloc:
#
# ```
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.c not known
# [+] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [+]   <BV64 0x20010>
# ```
#
# Let's take this one line at a time:
#
# - `malloc: Alloc'd 264 bytes at 0x20010`:  Since we assigned `0x0001` to the length in `buf.c`, this line is telling us that space for the struct is 264 bytes (the `malloc()` model would  warn us if the length computation was more complex than "variable * magnitude".)
#
# - `Storing 8 bytes at 0x20008`: Malloc returns a pointer to the newly allocated memory so the address of the heap memory is stored there.
#
# - `Length field msg.hdr.c not known`: We haven't told the `malloc()` model that it should track structs allocated using `msg.hdr.c`, or what they should look like.
#
# - `0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)`: The pointer to our new heap array is stored in `msg.a`, making `msg.hdr.c` the length of `msg.a`. Let's update our harness with a better name for this pointer.
#
# Let's go ahead and define a more clear variable name, since it appears the `len` value is being used to determine how many chunks of memory to allocate. This seems like behaviour we'd expect when allocating structs, so let's update to reflect that.

# %% [markdown]
# We wrap up this section by noting that execution stopped on another read of a single byte from a larger buffer.  We'll finish this treatment of models with four final actions:
# - combine all the model work into a routine that can be called when we reinitialize our analysis
# - update our harness to take account of the single byte, we'll assume this is part of a struct
# - update our variable names to better reflect usage
# - run again

# %%
def add_malloc_free_models():
    global code
    global malloc
    global free
    global heap

    # Add a blank heap
    heap = smallworld.state.memory.heap.BumpAllocator(0x20000, 0x10000)
    machine.add(heap)

    # Configure malloc and free models
    malloc = MallocModel(
        0x10000, heap, platform, analysis.mem_read_hook, analysis.mem_write_hook
    )
    machine.add(malloc)
    machine.add_bound(malloc._address, malloc._address + 16)

    free = FreeModel(0x1036)
    machine.add(free)
    machine.add_bound(free._address, free._address + 16)

    # Apply relocations to malloc
    code.update_symbol_value("malloc", malloc._address)


reinitialize_demo()
add_malloc_free_models()
gdata[4] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.numstructs")
gdata[52] = smallworld.state.BytesValue(b"\x00\x01", "buf.msg.hdr.numstructs")
gdata[60] = smallworld.state.SymbolicValue(1, None, None, "buf.struct.var.a")
gdata[61] = smallworld.state.SymbolicValue(499, None, None, "buf")
machine.analyze(analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-09-05 14:15:28,638", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:28,639", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:28,639", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:28,640", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x20000 - 0x30000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x75689320e3e0> := msg.hdr.a
# [+] {"time": "2025-09-05 14:15:28,645", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x756894b26920> := buf.a
# [+] {"time": "2025-09-05 14:15:28,647", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:28,649", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7568931d9420> := msg.a
# [+] {"time": "2025-09-05 14:15:28,650", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x756894bb2a40> := msg.b
# [+] {"time": "2025-09-05 14:15:28,651", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x756894b42380> := msg.c
# [+] {"time": "2025-09-05 14:15:28,653", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg.d
# [+] {"time": "2025-09-05 14:15:28,655", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7568931b7bb0> := buf.b
# [+] {"time": "2025-09-05 14:15:28,656", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x75689320c0a0> := msg.hdr.b
# [+] {"time": "2025-09-05 14:15:28,658", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x7568931aa1d0> := msg.hdr.numstructs
# [+] {"time": "2025-09-05 14:15:28,659", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.numstructs", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x75689323ace0> := msg.hdr.d
# [+] {"time": "2025-09-05 14:15:28,661", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7568931b5810> := msg.hdr.e
# [+] {"time": "2025-09-05 14:15:28,663", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7568931b50c0> := msg.hdr.f
# [+] {"time": "2025-09-05 14:15:28,664", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7568931b52d0> := msg.hdr.unk
# [+] {"time": "2025-09-05 14:15:28,666", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x756892eb5240> := buf.msg.hdr.numstructs
# [+] {"time": "2025-09-05 14:15:28,668", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.numstructs", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x756894b26fe0> := buf.d
# [+] {"time": "2025-09-05 14:15:28,670", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7568930e33a0> := buf.e
# [+] {"time": "2025-09-05 14:15:28,671", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7568931b7370> := buf.f
# [+] {"time": "2025-09-05 14:15:28,673", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x756892eb53f0> := buf.struct.var.a
# [+] {"time": "2025-09-05 14:15:28,674", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.struct.var.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x6230: <smallworld.state.state.SymbolicValue object at 0x756892d97490> := buf
# [+] {"time": "2025-09-05 14:15:28,675", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 499, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x756892eb4a00>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x756892eb4a00>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [+] Storing 8 bytes at 0x7ffffffffff8
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_188_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_188_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_188_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_188_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_190_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.numstructs)
# [!]   <BV16 Reverse(buf.msg.hdr.numstructs)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_190_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.numstructs)
# [!]   <BV16 Reverse(buf.msg.hdr.numstructs)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.numstructs
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_190_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_190_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_192_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_192_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_192_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_192_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_194_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_194_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_194_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_194_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_196_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_196_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_196_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_196_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_191_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Length field msg.hdr.numstructs not known
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_191_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_199_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_198_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_198_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf.struct.var.a)
# [!]   <BV8 buf.struct.var.a>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_198_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_198_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x415c5: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_200_64>
# [!] 0x415c8: READING 0x603d - 0x603e (buf)
# [!]   <BV8 buf[3991:3984]>
# [+] {"time": "2025-09-05 14:15:32,916", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24637, "size": 1, "pc": 267720, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.numstructs_191_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_198_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 1, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x415c8
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_191_16))> [[<BV16 msg.hdr.numstructs_191_16>]]
# [*]     0x4155a: <Bool cap - off_198_64 >= 0x1> [[<BV64 off_198_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.var.a != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x415ab: <Bool (buf.struct.var.a & 192) == 192> [[<BV8 buf.struct.var.a>]]
# [*]   field:      buf[0:1]
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_200_64>
# [!] 0x41652: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_200_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_200_64>
# [!] 0x41a44: READING 0x603d - 0x603f (buf)
# [!]   <BV16 Reverse(buf[3991:3976])>
# [+] {"time": "2025-09-05 14:15:33,317", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24637, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.numstructs_191_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_198_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268839, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_200_64", 64]}]}, {"op": "BVV", "args": [4, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 2, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_191_16))> [[<BV16 msg.hdr.numstructs_191_16>]]
# [*]     0x4155a: <Bool cap - off_198_64 >= 0x1> [[<BV64 off_198_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.var.a == 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x41a27: <Bool cap - off_200_64 >= 0x4> [[<BV64 off_200_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] 0x416b2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_200_64>
# [!] 0x416b9: READING 0x603d - 0x603e (buf)
# [!]   <BV8 buf[3991:3984]>
# [+] {"time": "2025-09-05 14:15:33,766", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24637, "size": 1, "pc": 267961, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.numstructs_191_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_198_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_200_64", 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 0, "end": 1, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x416b9
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_191_16))> [[<BV16 msg.hdr.numstructs_191_16>]]
# [*]     0x4155a: <Bool cap - off_198_64 >= 0x1> [[<BV64 off_198_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.var.a != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x415ab: <Bool (buf.struct.var.a & 192) != 192> [[<BV8 buf.struct.var.a>]]
# [*]     0x4161c: <Bool (buf.struct.var.a & 192) == 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.var.a)) < 0xff then 1 else 0) | (if buf.struct.var.a == 255 then 1 else 0)) != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x4165c: <Bool cap - off_200_64 >= (0#32 .. (0#24 .. buf.struct.var.a))> [[<BV8 buf.struct.var.a>, <BV64 off_200_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.var.a))> [[<BV8 buf.struct.var.a>]]
# [*]   field:      buf[0:1]
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_199_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_199_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] <SimulationManager with 16 unsat, 4 deadended>
# [!] []
# [!] State at <BV64 0x415c8>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_191_16))>
# [!]     0x4155a: <Bool cap - off_198_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a != 0>
# [!]     0x415ab: <Bool (buf.struct.var.a & 192) == 192>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_187_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_200_64 = <BV64 off_198_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_199_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_183_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_184_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_185_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_189_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_191_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_193_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_195_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_197_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [!] State at <BV64 0x41a44>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_191_16))>
# [!]     0x4155a: <Bool cap - off_198_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a == 0>
# [!]     0x41a27: <Bool cap - off_200_64 >= 0x4>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_187_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_200_64 = <BV64 off_198_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_199_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_183_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_184_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_185_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_189_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_191_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_193_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_195_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_197_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [!] State at <BV64 0x416b9>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_191_16))>
# [!]     0x4155a: <Bool cap - off_198_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a != 0>
# [!]     0x415ab: <Bool (buf.struct.var.a & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.var.a & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.var.a)) < 0xff then 1 else 0) | (if buf.struct.var.a == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_200_64 >= (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_187_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_200_64 = <BV64 off_198_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_199_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_183_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_184_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_185_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_189_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_191_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_193_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_195_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_197_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_191_16))>
# [!]     0x4155a: <Bool cap - off_198_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a != 0>
# [!]     0x415ab: <Bool (buf.struct.var.a & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.var.a & 192) != 0>
# [!]     0x421bd: <Bool msg.a_199_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_187_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_200_64 = <BV64 off_198_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_201_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_183_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_184_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_185_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_189_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_191_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_193_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_195_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_197_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x6230: buf = <BV3992 buf>
# [*] Multiple field defs starting at buf[0]:
# [*]     buf[0:1]
# [*]     buf[0:2]
# [*]   One or more of the following fields may control the format,
# [*]   either as a flag, type code or length:
# [*]     buf.struct.var.a

# %% [markdown]
# # DNS exploration: Next control field
#
# The end of our last run produced new output.  In particular, it noted that `buf.struct.var.a` seems to be
# influencing whether the next two bytes of `buf` are a single field or multiple fields.  What conditions are making this happen?  To address this question, we look at the various reports of `Partial access to known field` and look at the conditions that were required for that partial access to occurr.  This happens in three cases.  Extracting just the information relevent to `buf.struct.var.a` we have:
#
# ### Case 1:
# ```
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x415c8
# [*]   access:     read
# [*]   guards:
# [*]     0x41592: <Bool buf.struct.var.a != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x415ab: <Bool (buf.struct.var.a & 192) == 192> [[<BV8 buf.struct.var.a>]]
# [*]   field:      buf[0:1]
# ```
# We get to this case exactly when the two high bits set on `buf.struct.var.a`.  So since its a byte, `buf.struct.var.a` is 64 and 255 inclusive.
#
# ### Case 2:
# ```
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x41592: <Bool buf.struct.var.a == 0> [[<BV8 buf.struct.var.a>]]
# [*]   field:      buf[0:2]
# ```
# We get to this case exactly when `buf.struct.var.a == 0`.
#
# ### Case 3:
# ```
# [*] Partial access to known field
# [*]   address:    0x603d
# [*]   size:       1
# [*]   pc:         0x416b9
# [*]   access:     read
# [*]   guards:
# [*]     0x41592: <Bool buf.struct.var.a != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x415ab: <Bool (buf.struct.var.a & 192) != 192> [[<BV8 buf.struct.var.a>]]
# [*]     0x4161c: <Bool (buf.struct.var.a & 192) == 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.var.a)) < 0xff then 1 else 0) | (if buf.struct.var.a == 255 then 1 else 0)) != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x4165c: <Bool cap - off_184_64 >= (0#32 .. (0#24 .. buf.struct.var.a))> [[<BV8 buf.struct.var.a>, <BV64 off_184_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.var.a))> [[<BV8 buf.struct.var.a>]]
# [*]   field:      buf[0:1]
# ```
# The conditions on `buf.struct.var.a` look much more complicated here but with a little work it is not hard to see that this case arises exactly when the two high bits are unset on `buf.struct.var.a` and `buf.struct.var.a` is non-zero.  Since its a byte, `buf.struct.var.a` is between 1 and 63 inclusive.
#
# Above we can see that in Case 1 and 3, the routine tries to read `buf[0:1]` as a field, and in Case 2, it tries to read `buf[0:2]` as a field. Expirimenting with Case 1 will show us that it exits the routine, only Case 2 and 3 continue parsing.
#
# For exploration purposes, let's expiriment with Case 3, where `buf[0:1]` is interperted as a field. Since only one byte is being interperted as a field, this may be the simpler case to begin with. If this analysis were to finish and be unsatisfactory, it is easily possible to come back and continue digging into the other cases and how they cause the buffer to be interperted. However, since we can only explore one possibility at a time, we're going to choose Case 3.
#
# First, we'll need to add a constraint that `buf.struct.var.a` will be greater than 0. Recall UGT here signifies an unsigned greater than operation, and we specify that buf.struct.var.a must be greater than the integer on the right, in this case we make this 0. It will then incriment to 1, since 1 is greater than 0. If you wanted to test Case 1, you could instead set the right side of this UGT argument to `claripy.BVV(64, 8)`.
#
# ```python
# claripy.UGT(claripy.BVS("buf.struct.var.a", 8, explicit_name=True), claripy.BVV(0, 8))
# ```
#
# We're also going to need to add the ability to track malloc'd arrays of items. We know from our last run that `msg.hdr.numstructs` is responsible for controlling how many homogenous structs of size 264 are malloc'd. We'll tell the program that we're going to allocate a number of structs based on `msg.hdr.numstructs`, that the struct will be of size 264, and if you see it to label it unknown (`unk`). Recall previously we defined `msg.hdr.numstructs` statically to equal `0x0001` so we will always get a single allocation of the struct.
#
# ```python
# malloc.bind_length_to_struct("msg.hdr.numstructs", "msg.struct.item", [(264, "unk")])
# ```
#
# Also, because we are now reading the first field of `buf` as it's own field, we'll define it seperatly. We also know the second byte can be defined seperatly, so we'll define it as well. We'll leave the rest of the buffer in tact for now.
#
# ```python
# gdata[61] = smallworld.state.SymbolicValue(1, None, None, "buf.struct.var.b")
# gdata[62] = smallworld.state.SymbolicValue(1, None, None, "buf.struct.var.c")
# gdata[63] = smallworld.state.SymbolicValue(497, None, None, "buf")
# ```

# %%
reinitialize_demo()
add_malloc_free_models()

gdata[4] = smallworld.state.SymbolicValue(2, None, None, "msg.hdr.numstructs")
gdata[61] = smallworld.state.SymbolicValue(1, None, None, "buf.struct.var.b")
gdata[62] = smallworld.state.SymbolicValue(1, None, None, "buf.struct.var.c")
gdata[63] = smallworld.state.SymbolicValue(497, None, None, "buf")

malloc.bind_length_to_struct("msg.hdr.numstructs", "msg.struct.item", [(264, "unk")])

machine.add_constraint(
    claripy.UGT(
        claripy.BVS("buf.struct.var.a", 8, explicit_name=True), claripy.BVV(0, 8)
    )
)


# We're going to create the option to pass a timeout when doing analysis
@timeout_decorator.timeout(180)  # argument is in seconds
def analyze_with_timeout(machine, analysis):
    try:
        machine.analyze(analysis)
    except timeout_decorator.timeout_decorator.TimeoutError:
        print("Analysis timeout")


analyze_with_timeout(machine, analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-09-05 14:15:34,367", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:34,369", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:34,369", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:34,369", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x75689320e3e0> := msg.hdr.a
# [+] {"time": "2025-09-05 14:15:34,374", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x756894b26920> := buf.a
# [+] {"time": "2025-09-05 14:15:34,375", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:34,376", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7568931d9420> := msg.a
# [+] {"time": "2025-09-05 14:15:34,377", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x756894bb2a40> := msg.b
# [+] {"time": "2025-09-05 14:15:34,378", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x756894b42380> := msg.c
# [+] {"time": "2025-09-05 14:15:34,379", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg.d
# [+] {"time": "2025-09-05 14:15:34,380", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7568931b7bb0> := buf.b
# [+] {"time": "2025-09-05 14:15:34,381", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x75689320c0a0> := msg.hdr.b
# [+] {"time": "2025-09-05 14:15:34,382", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x756892eb5450> := msg.hdr.numstructs
# [+] {"time": "2025-09-05 14:15:34,383", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.numstructs", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x75689323ace0> := msg.hdr.d
# [+] {"time": "2025-09-05 14:15:34,384", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7568931b5810> := msg.hdr.e
# [+] {"time": "2025-09-05 14:15:34,385", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7568931b50c0> := msg.hdr.f
# [+] {"time": "2025-09-05 14:15:34,386", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7568931b52d0> := msg.hdr.unk
# [+] {"time": "2025-09-05 14:15:34,387", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x756892eb5240> := buf.msg.hdr.numstructs
# [+] {"time": "2025-09-05 14:15:34,388", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.numstructs", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x756894b26fe0> := buf.d
# [+] {"time": "2025-09-05 14:15:34,389", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7568930e33a0> := buf.e
# [+] {"time": "2025-09-05 14:15:34,390", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7568931b7370> := buf.f
# [+] {"time": "2025-09-05 14:15:34,391", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.SymbolicValue object at 0x756892eb53f0> := buf.struct.var.a
# [+] {"time": "2025-09-05 14:15:34,392", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.struct.var.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x603e: <smallworld.state.state.SymbolicValue object at 0x756892f33400> := buf.struct.var.b
# [+] {"time": "2025-09-05 14:15:34,393", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 1, "label": "buf.struct.var.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603e - 0x603f: <smallworld.state.state.SymbolicValue object at 0x756892eb5420> := buf.struct.var.c
# [+] {"time": "2025-09-05 14:15:34,394", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24638, "size": 1, "label": "buf.struct.var.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603f - 0x6230: <smallworld.state.state.SymbolicValue object at 0x756892d97490> := buf
# [+] {"time": "2025-09-05 14:15:34,395", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24639, "size": 497, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x20000 - 0x30000
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x7568931b6110>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x7568931b6110>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_229_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_229_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_229_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_229_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_231_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.numstructs)
# [!]   <BV16 Reverse(buf.msg.hdr.numstructs)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_231_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.numstructs)
# [!]   <BV16 Reverse(buf.msg.hdr.numstructs)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.numstructs
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_231_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_231_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_233_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_233_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_233_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_233_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_235_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_235_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_235_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_235_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_237_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_237_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_237_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_237_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_232_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Alloc of 1 items
# [+] Storing 2112 bytes at 0x20010
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_232_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_240_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_239_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_239_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf.struct.var.a)
# [!]   <BV8 buf.struct.var.a>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_239_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_239_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x415c5: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_241_64>
# [!] 0x415c8: READING 0x603d - 0x603e (buf.struct.var.b)
# [!]   <BV8 buf.struct.var.b>
# [!] 0x415d7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_241_64>
# [!] 0x415de: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_241_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x41652: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_241_64>
# [!] 0x416b2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_241_64>
# [!] 0x416b9: READING 0x603d - 0x603e (buf.struct.var.b)
# [!]   <BV8 buf.struct.var.b>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_240_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_240_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41577: READING 0x6050 - 0x6051 (buf)
# [!]   <BV8 buf[3839:3832]>
# [+] {"time": "2025-09-05 14:15:40,702", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24656, "size": 1, "pc": 267639, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.numstructs_232_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_239_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "__or__", "args": [{"op": "__lshift__", "args": [{"op": "__and__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}, {"op": "BVV", "args": [63, 64]}]}, {"op": "BVV", "args": [8, 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}]}]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}]], "access": "read", "label": "buf", "start": 17, "end": 18, "class": "smallworld.analyses.field_detection.hints.PartialByteFieldAccessHint"}}
# [*] Partial access to known field
# [*]   address:    0x6050
# [*]   size:       1
# [*]   pc:         0x41577
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))> [[<BV16 msg.hdr.numstructs_232_16>]]
# [*]     0x4155a: <Bool cap - off_239_64 >= 0x1> [[<BV64 off_239_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.var.a != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x415ab: <Bool (buf.struct.var.a & 192) == 192> [[<BV8 buf.struct.var.a>]]
# [*]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.struct.var.a)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.struct.var.b))) >= 0x1> [[<BV8 buf.struct.var.b>, <BV8 buf.struct.var.a>, <BV64 cap>]]
# [*]   field:      buf[17:18]
# [!] 0x41740: WRITING 0x20010 - 0x20011 (msg.struct.item.0.unk)
# [!]   <BV8 buf.struct.var.b>
# [+] {"time": "2025-09-05 14:15:41,215", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 131088, "size": 1, "pc": 268096, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.numstructs_232_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_239_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_241_64", 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267979, {"op": "__ne__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}, {"op": "__and__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}]}, {"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268021, {"op": "__ne__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS",  ...
# [*] Partial write to known field
# [*]   address:    0x20010
# [*]   size:       1
# [*]   pc:         0x41740
# [*]   access:     write
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))> [[<BV16 msg.hdr.numstructs_232_16>]]
# [*]     0x4155a: <Bool cap - off_239_64 >= 0x1> [[<BV64 off_239_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.var.a != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x415ab: <Bool (buf.struct.var.a & 192) != 192> [[<BV8 buf.struct.var.a>]]
# [*]     0x4161c: <Bool (buf.struct.var.a & 192) == 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.var.a)) < 0xff then 1 else 0) | (if buf.struct.var.a == 255 then 1 else 0)) != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x4165c: <Bool cap - off_241_64 >= (0#32 .. (0#24 .. buf.struct.var.a))> [[<BV8 buf.struct.var.a>, <BV64 off_241_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.var.a))> [[<BV8 buf.struct.var.a>]]
# [*]     0x416cb: <Bool (SignExt(24, buf.struct.var.b) - 0x61[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x61[31:31])) != 0> [[<BV8 buf.struct.var.b>]]
# [*]     0x416f5: <Bool (SignExt(24, buf.struct.var.b) - 0x30[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x30[31:31])) != 0> [[<BV8 buf.struct.var.b>]]
# [*]     0x4172b: <Bool ((0#7 .. (if SignExt(24, buf.struct.var.b) == 0x2d then 1 else 0)) & 1) != 0> [[<BV8 buf.struct.var.b>]]
# [*]   field:      msg.struct.item.0.unk[0:1]
# [*]   expr:       <BV8 buf.struct.var.b>
# [!] 0x41740: WRITING 0x20010 - 0x20011 (msg.struct.item.0.unk)
# [!]   <BV8 buf.struct.var.b>
# [+] {"time": "2025-09-05 14:15:41,381", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 131088, "size": 1, "pc": 268096, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.numstructs_232_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_239_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_241_64", 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267979, {"op": "__ne__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}, {"op": "__and__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}]}, {"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268021, {"op": "__eq__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS",  ...
# [*] Partial write to known field
# [*]   address:    0x20010
# [*]   size:       1
# [*]   pc:         0x41740
# [*]   access:     write
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))> [[<BV16 msg.hdr.numstructs_232_16>]]
# [*]     0x4155a: <Bool cap - off_239_64 >= 0x1> [[<BV64 off_239_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.var.a != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x415ab: <Bool (buf.struct.var.a & 192) != 192> [[<BV8 buf.struct.var.a>]]
# [*]     0x4161c: <Bool (buf.struct.var.a & 192) == 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.var.a)) < 0xff then 1 else 0) | (if buf.struct.var.a == 255 then 1 else 0)) != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x4165c: <Bool cap - off_241_64 >= (0#32 .. (0#24 .. buf.struct.var.a))> [[<BV8 buf.struct.var.a>, <BV64 off_241_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.var.a))> [[<BV8 buf.struct.var.a>]]
# [*]     0x416cb: <Bool (SignExt(24, buf.struct.var.b) - 0x61[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x61[31:31])) != 0> [[<BV8 buf.struct.var.b>]]
# [*]     0x416f5: <Bool (SignExt(24, buf.struct.var.b) - 0x30[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x30[31:31])) == 0> [[<BV8 buf.struct.var.b>]]
# [*]     0x4172b: <Bool ((0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, <...>) == 0x2d then 1 else 0)) & 1)) != 0x0> [[<BV8 buf.struct.var.b>]]
# [*]   field:      msg.struct.item.0.unk[0:1]
# [*]   expr:       <BV8 buf.struct.var.b>
# [!] 0x41740: WRITING 0x20010 - 0x20011 (msg.struct.item.0.unk)
# [!]   <BV8 buf.struct.var.b>
# [+] {"time": "2025-09-05 14:15:41,517", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial write to known field", "address": 131088, "size": 1, "pc": 268096, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.numstructs_232_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_239_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.struct.var.a", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_241_64", 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.a", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267979, {"op": "__eq__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}, {"op": "__and__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}]}, {"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.var.b", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268021, {"op": "__eq__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS",  ...
# [*] Partial write to known field
# [*]   address:    0x20010
# [*]   size:       1
# [*]   pc:         0x41740
# [*]   access:     write
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))> [[<BV16 msg.hdr.numstructs_232_16>]]
# [*]     0x4155a: <Bool cap - off_239_64 >= 0x1> [[<BV64 off_239_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.var.a != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x415ab: <Bool (buf.struct.var.a & 192) != 192> [[<BV8 buf.struct.var.a>]]
# [*]     0x4161c: <Bool (buf.struct.var.a & 192) == 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.var.a)) < 0xff then 1 else 0) | (if buf.struct.var.a == 255 then 1 else 0)) != 0> [[<BV8 buf.struct.var.a>]]
# [*]     0x4165c: <Bool cap - off_241_64 >= (0#32 .. (0#24 .. buf.struct.var.a))> [[<BV8 buf.struct.var.a>, <BV64 off_241_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.var.a))> [[<BV8 buf.struct.var.a>]]
# [*]     0x416cb: <Bool (SignExt(24, buf.struct.var.b) - 0x61[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x61[31:31])) == 0> [[<BV8 buf.struct.var.b>]]
# [*]     0x416f5: <Bool (SignExt(24, buf.struct.var.b) - 0x30[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x30[31:31])) == 0> [[<BV8 buf.struct.var.b>]]
# [*]     0x4172b: <Bool ((0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, <...>) == 0x2d then 1 else 0)) & 1)) != 0x0> [[<BV8 buf.struct.var.b>]]
# [*]   field:      msg.struct.item.0.unk[0:1]
# [*]   expr:       <BV8 buf.struct.var.b>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_240_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_240_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_240_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_240_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_240_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_240_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_240_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_240_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] <SimulationManager with 36 unsat, 9 deadended>
# [!] []
# [!] State at <BV64 0x41577>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))>
# [!]     0x4155a: <Bool cap - off_239_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a != 0>
# [!]     0x415ab: <Bool (buf.struct.var.a & 192) == 192>
# [!]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.struct.var.a)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.struct.var.b))) >= 0x1>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_228_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_242_64 = <BV64 off_241_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_240_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_224_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_225_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_226_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_230_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_232_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_234_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_236_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_238_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x603e: buf.struct.var.b = <BV8 buf.struct.var.b>
# [!]     0x603e - 0x603f: buf.struct.var.c = <BV8 buf.struct.var.c>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20118: msg.struct.item.0.unk = <BV2112 msg.struct.item.0.unk>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))>
# [!]     0x4155a: <Bool cap - off_239_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a != 0>
# [!]     0x415ab: <Bool (buf.struct.var.a & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.var.a & 192) != 0>
# [!]     0x421bd: <Bool msg.a_240_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_228_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_241_64 = <BV64 off_239_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_243_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_224_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_225_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_226_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_230_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_232_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_234_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_236_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_238_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x603e: buf.struct.var.b = <BV8 buf.struct.var.b>
# [!]     0x603e - 0x603f: buf.struct.var.c = <BV8 buf.struct.var.c>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20118: msg.struct.item.0.unk = <BV2112 msg.struct.item.0.unk>
# [!] State at <BV64 0x41740>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))>
# [!]     0x4155a: <Bool cap - off_239_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a != 0>
# [!]     0x415ab: <Bool (buf.struct.var.a & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.var.a & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.var.a)) < 0xff then 1 else 0) | (if buf.struct.var.a == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_241_64 >= (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.var.b) - 0x61[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.var.b) - 0x30[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x30[31:31])) != 0>
# [!]     0x4172b: <Bool ((0#7 .. (if SignExt(24, buf.struct.var.b) == 0x2d then 1 else 0)) & 1) != 0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_228_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_241_64 = <BV64 off_239_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_240_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_224_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_225_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_226_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_230_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_232_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_234_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_236_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_238_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x603e: buf.struct.var.b = <BV8 buf.struct.var.b>
# [!]     0x603e - 0x603f: buf.struct.var.c = <BV8 buf.struct.var.c>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20118: msg.struct.item.0.unk = <BV2112 msg.struct.item.0.unk>
# [!] State at <BV64 0x41740>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))>
# [!]     0x4155a: <Bool cap - off_239_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a != 0>
# [!]     0x415ab: <Bool (buf.struct.var.a & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.var.a & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.var.a)) < 0xff then 1 else 0) | (if buf.struct.var.a == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_241_64 >= (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.var.b) - 0x61[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.var.b) - 0x30[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.var.b) - 0x39[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x39[31:31]) | (if SignExt(24, buf.struct.var.b) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.var.b) == 0x2d then 1 else 0)) & 1)) != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_228_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# ...
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.var.b) - 0x30[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.var.b) - 0x7a[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x7a[31:31]) | (if SignExt(24, buf.struct.var.b) == 0x7a then 1 else 0)) & 1) | (0#24 .. (0#7 .. SignExt(24, buf.struct.var.b) - 0x39[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x39[31:31]) | (if SignExt(24, buf.struct.var.b) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.var.b) == 0x2d then 1 else 0)) & 1)) != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_228_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_241_64 = <BV64 off_239_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_240_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_224_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_225_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_226_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_230_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_232_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_234_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_236_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_238_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x603e: buf.struct.var.b = <BV8 buf.struct.var.b>
# [!]     0x603e - 0x603f: buf.struct.var.c = <BV8 buf.struct.var.c>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20118: msg.struct.item.0.unk = <BV2112 msg.struct.item.0.unk>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))>
# [!]     0x4155a: <Bool cap - off_239_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a != 0>
# [!]     0x415ab: <Bool (buf.struct.var.a & 192) == 192>
# [!]     0x4155a: <Bool cap - (((0#32 .. (0#24 .. buf.struct.var.a)) & 0x3f) << 0x8 | (0#32 .. (0#24 .. buf.struct.var.b))) < 0x1>
# [!]     0x421bd: <Bool msg.a_240_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_228_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_242_64 = <BV64 off_241_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_244_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_224_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_225_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_226_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_230_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_232_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_234_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_236_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_238_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x603e: buf.struct.var.b = <BV8 buf.struct.var.b>
# [!]     0x603e - 0x603f: buf.struct.var.c = <BV8 buf.struct.var.c>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20118: msg.struct.item.0.unk = <BV2112 msg.struct.item.0.unk>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))>
# [!]     0x4155a: <Bool cap - off_239_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a != 0>
# [!]     0x415ab: <Bool (buf.struct.var.a & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.var.a & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.var.a)) < 0xff then 1 else 0) | (if buf.struct.var.a == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_241_64 >= (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.var.b) - 0x61[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.var.b) - 0x30[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x30[31:31])) != 0>
# [!]     0x4172b: <Bool ((0#7 .. (if SignExt(24, buf.struct.var.b) == 0x2d then 1 else 0)) & 1) == 0>
# [!]     0x421bd: <Bool msg.a_240_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_228_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_241_64 = <BV64 off_239_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_245_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_224_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_225_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_226_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_230_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_232_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_234_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_236_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_238_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x603e: buf.struct.var.b = <BV8 buf.struct.var.b>
# [!]     0x603e - 0x603f: buf.struct.var.c = <BV8 buf.struct.var.c>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20118: msg.struct.item.0.unk = <BV2112 msg.struct.item.0.unk>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))>
# [!]     0x4155a: <Bool cap - off_239_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a != 0>
# [!]     0x415ab: <Bool (buf.struct.var.a & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.var.a & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.var.a)) < 0xff then 1 else 0) | (if buf.struct.var.a == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_241_64 >= (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.var.b) - 0x61[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.var.b) - 0x30[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.var.b) - 0x39[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x39[31:31]) | (if SignExt(24, buf.struct.var.b) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.var.b) == 0x2d then 1 else 0)) & 1)) == 0x0>
# [!]     0x421bd: <Bool msg.a_240_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_228_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_241_64 = <BV64 off_239_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_246_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_224_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_225_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_226_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_230_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_232_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_234_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_236_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_238_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x603e: buf.struct.var.b = <BV8 buf.struct.var.b>
# [!]     0x603e - 0x603f: buf.struct.var.c = <BV8 buf.struct.var.c>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20118: msg.struct.item.0.unk = <BV2112 msg.struct.item.0.unk>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_232_16))>
# [!]     0x4155a: <Bool cap - off_239_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.var.a != 0>
# [!]     0x415ab: <Bool (buf.struct.var.a & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.var.a & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.var.a)) < 0xff then 1 else 0) | (if buf.struct.var.a == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_241_64 >= (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.var.a))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.var.b) - 0x61[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x61[31:31])) == 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.var.b) - 0x30[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.var.b) - 0x7a[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x7a[31:31]) | (if SignExt(24, buf.struct.var.b) == 0x7a then 1 else 0)) & 1) | (0#24 .. (0#7 .. SignExt(24, buf.struct.var.b) - 0x39[31:31] ^ (SignExt(24, buf.struct.var.b)[31:31] ^ 0) & (SignExt(24, buf.struct.var.b)[31:31] ^ SignExt(24, buf.struct.var.b) - 0x39[31:31]) | (if SignExt(24, buf.struct.var.b) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.var.b) == 0x2d then 1 else 0)) & 1)) == 0x0>
# [!]     0x421bd: <Bool msg.a_240_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_228_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_241_64 = <BV64 off_239_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_247_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_224_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_225_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_226_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_230_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_232_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_234_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_236_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_238_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.var.a = <BV8 buf.struct.var.a>
# [!]     0x603d - 0x603e: buf.struct.var.b = <BV8 buf.struct.var.b>
# [!]     0x603e - 0x603f: buf.struct.var.c = <BV8 buf.struct.var.c>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20118: msg.struct.item.0.unk = <BV2112 msg.struct.item.0.unk>

# %% [markdown]
# _The work so far is captured in `dns_4.py`_
#
# You can observe many constrained writes to `0x20010`, our formerly defined struct. Then, as the program exits, we encounter a large number of deadended states. The corresponding guards and fields sections of these states provide the symbolic constraints that can help inform our understanding of what is happening in the struct. Simplfiying and understanding symbolic constraints is a topic _well_ outside of the scope of this demo, but if you spend several hours doing analysis, you will find the following:
#
# `gdata[60]`: `buf.struct.var.a` becomes a length field, driving the length of a char buffer.
#
# `gdata[61]`: `buf.struct.var.b` becomes the first char of the string defined above.
#
# `gdata[62]`: `buf.struct.var.c` becomes a length field, driving the length of another buffer.
#
# We'll rename these items below to have more informative names.
#
# We'll remove the constraint on `buf.struct.var.a` being greater than 0 and instead set it to a static value, so we know what length to expect for the following char buffer.
#
# It's important to note that this DNS analysis is a research proof of concept. It would be infeasible to use symbolic analysis across fields 0-255 for example, hence why we constrain to 4 chars. While the format may be the same, it would require significantly more computing power. We are only going to explore very short domain names to keep the example more concise.
#
# ```python
# fields = [(1, f"text.{i}") for i in range(0, 3)]
# fields.append((253, "text"))
# fields.append((8, "unk"))
#
# malloc.bind_length_to_struct("msg.hdr.numstructs", "msg.struct.item", fields)
# ```
#
# We can also now label the items we've found in the struct:
#
# ```python
# gdata[60] = smallworld.state.IntegerValue(1, 1, "buf.struct.string0.len")
# gdata[61] = smallworld.state.SymbolicValue(1, None, None, "buf.struct.string0[0]")
# gdata[62] = smallworld.state.IntegerValue(0, 1, "buf.struct.string1.len")
# ```

# %%
reinitialize_demo()
add_malloc_free_models()

fields = [(1, f"text.{i}") for i in range(0, 3)]
fields.append((253, "text"))
fields.append(
    (8, "unk")
)  # We know there's 256 bytes of text, but 264 bytes of the struct total, so we block off the remaining 8 bytes

malloc.bind_length_to_struct("msg.hdr.numstructs", "msg.struct.item", fields)

gdata[60] = smallworld.state.IntegerValue(1, 1, "buf.struct.string0.len")
gdata[61] = smallworld.state.SymbolicValue(1, None, None, "buf.struct.string0[0]")
gdata[62] = smallworld.state.IntegerValue(0, 1, "buf.struct.string1.len")
gdata[63] = smallworld.state.SymbolicValue(497, None, None, "buf")

analyze_with_timeout(machine, analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-09-05 14:15:42,739", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:42,740", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:42,740", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:42,741", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x20000 - 0x30000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x75689320e3e0> := msg.hdr.a
# [+] {"time": "2025-09-05 14:15:42,746", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x756894b26920> := buf.a
# [+] {"time": "2025-09-05 14:15:42,747", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:42,748", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7568931d9420> := msg.a
# [+] {"time": "2025-09-05 14:15:42,749", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x756894bb2a40> := msg.b
# [+] {"time": "2025-09-05 14:15:42,750", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x756894b42380> := msg.c
# [+] {"time": "2025-09-05 14:15:42,751", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg.d
# [+] {"time": "2025-09-05 14:15:42,752", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7568931b7bb0> := buf.b
# [+] {"time": "2025-09-05 14:15:42,753", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x75689320c0a0> := msg.hdr.b
# [+] {"time": "2025-09-05 14:15:42,754", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x756892eb5450> := msg.hdr.numstructs
# [+] {"time": "2025-09-05 14:15:42,755", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.numstructs", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x75689323ace0> := msg.hdr.d
# [+] {"time": "2025-09-05 14:15:42,756", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7568931b5810> := msg.hdr.e
# [+] {"time": "2025-09-05 14:15:42,757", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7568931b50c0> := msg.hdr.f
# [+] {"time": "2025-09-05 14:15:42,758", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7568931b52d0> := msg.hdr.unk
# [+] {"time": "2025-09-05 14:15:42,759", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x756892eb5240> := buf.msg.hdr.numstructs
# [+] {"time": "2025-09-05 14:15:42,760", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.numstructs", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x756894b26fe0> := buf.d
# [+] {"time": "2025-09-05 14:15:42,761", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7568930e33a0> := buf.e
# [+] {"time": "2025-09-05 14:15:42,762", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7568931b7370> := buf.f
# [+] {"time": "2025-09-05 14:15:42,763", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.IntegerValue object at 0x756892ee7a00> := buf.struct.string0.len
# [+] {"time": "2025-09-05 14:15:42,764", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.struct.string0.len", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x603e: <smallworld.state.state.SymbolicValue object at 0x756892f8f190> := buf.struct.string0[0]
# [+] {"time": "2025-09-05 14:15:42,765", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 1, "label": "buf.struct.string0[0]", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603e - 0x603f: <smallworld.state.state.IntegerValue object at 0x756892eb53f0> := buf.struct.string1.len
# [+] {"time": "2025-09-05 14:15:42,766", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24638, "size": 1, "label": "buf.struct.string1.len", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603f - 0x6230: <smallworld.state.state.SymbolicValue object at 0x756892f33400> := buf
# [+] {"time": "2025-09-05 14:15:42,767", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24639, "size": 497, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x756893022e60>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x756893022e60>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x7ffffffffff8
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [+] Storing 1 bytes at 0x603c
# [+] Storing 1 bytes at 0x603e
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_273_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_273_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_273_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_273_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_275_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.numstructs)
# [!]   <BV16 Reverse(buf.msg.hdr.numstructs)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_275_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.numstructs)
# [!]   <BV16 Reverse(buf.msg.hdr.numstructs)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.numstructs
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_275_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_275_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_277_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_277_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_277_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_277_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_279_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_279_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_279_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_279_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_281_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_281_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_281_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_281_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_276_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Alloc of 1 items
# [+] Storing 2112 bytes at 0x20010
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_276_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_284_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_283_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_283_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf.struct.string0.len)
# [!]   <BV8 buf.struct.string0.len>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_283_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_283_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x41652: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_285_64>
# [!] 0x416b2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_285_64>
# [!] 0x416b9: READING 0x603d - 0x603e (buf.struct.string0[0])
# [!]   <BV8 buf.struct.string0[0]>
# [!] 0x41740: WRITING 0x20010 - 0x20011 (msg.struct.item.0.text.0)
# [!]   <BV8 buf.struct.string0[0]>
# [!]   Write to entire field msg.struct.item.0.text.0
# [!] 0x41740: WRITING 0x20010 - 0x20011 (msg.struct.item.0.text.0)
# [!]   <BV8 buf.struct.string0[0]>
# [!]   Write to entire field msg.struct.item.0.text.0
# [!] 0x41740: WRITING 0x20010 - 0x20011 (msg.struct.item.0.text.0)
# [!]   <BV8 buf.struct.string0[0]>
# [!]   Write to entire field msg.struct.item.0.text.0
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_285_64>
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_285_64>
# [!]   Write to entire field off
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_285_64>
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_285_64>
# [!]   Write to entire field off
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_284_64>
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_285_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_284_64>
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_285_64>
# [!]   Write to entire field off
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_284_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_289_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_284_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_284_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_290_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_289_64>
# [!] 0x41577: READING 0x603e - 0x603f (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_284_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_291_64>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_289_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_290_64>
# [!] 0x41577: READING 0x603e - 0x603f (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_289_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_290_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_291_64>
# [!] 0x41577: READING 0x603e - 0x603f (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_290_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_291_64>
# [!] 0x417ae: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_291_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x417ae: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x417ae: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_294_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_296_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_294_64>
# [!] 0x41a44: READING 0x603f - 0x6041 (buf)
# [!]   <BV16 Reverse(buf[3975:3960])>
# [+] {"time": "2025-09-05 14:15:51,947", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24639, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.numstructs_276_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_283_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0.len", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_285_64", 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0.len", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0.len", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267979, {"op": "__ne__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}, {"op": "__and__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}]}, {"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268021, {"op": "__ne__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__ ...
# [*] Partial access to known field
# [*]   address:    0x603f
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_276_16))> [[<BV16 msg.hdr.numstructs_276_16>]]
# [*]     0x4155a: <Bool cap - off_283_64 >= 0x1> [[<BV64 off_283_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.string0.len != 0> [[<BV8 buf.struct.string0.len>]]
# [*]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192> [[<BV8 buf.struct.string0.len>]]
# [*]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0> [[<BV8 buf.struct.string0.len>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0> [[<BV8 buf.struct.string0.len>]]
# [*]     0x4165c: <Bool cap - off_285_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))> [[<BV8 buf.struct.string0.len>, <BV64 off_285_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))> [[<BV8 buf.struct.string0.len>]]
# [*]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) != 0> [[<BV8 buf.struct.string0[0]>]]
# [*]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) != 0> [[<BV8 buf.struct.string0[0]>]]
# [*]     0x4172b: <Bool ((0#7 .. (if SignExt(24, buf.struct.string0[0]) == 0x2d then 1 else 0)) & 1) != 0> [[<BV8 buf.struct.string0[0]>]]
# [*]     0x416a4: <Bool 0x1 >= (0#32 .. (0#24 .. buf.struct.string0.len))> [[<BV8 buf.struct.string0.len>]]
# [*]     0x4155a: <Bool cap - off_289_64 >= 0x1> [[<BV64 off_289_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.string1.len == 0> [[<BV8 buf.struct.string1.len>]]
# [*]     0x41a27: <Bool cap - off_294_64 >= 0x4> [[<BV64 off_294_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_298_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_296_64>
# [!] 0x41a44: READING 0x603f - 0x6041 (buf)
# [!]   <BV16 Reverse(buf[3975:3960])>
# [+] {"time": "2025-09-05 14:15:52,220", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24639, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.numstructs_276_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_283_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0.len", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_285_64", 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0.len", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0.len", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267979, {"op": "__ne__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}, {"op": "__and__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}]}, {"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268021, {"op": "__eq__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__ ...
# [*] Partial access to known field
# [*]   address:    0x603f
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_276_16))> [[<BV16 msg.hdr.numstructs_276_16>]]
# [*]     0x4155a: <Bool cap - off_283_64 >= 0x1> [[<BV64 off_283_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.string0.len != 0> [[<BV8 buf.struct.string0.len>]]
# [*]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192> [[<BV8 buf.struct.string0.len>]]
# [*]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0> [[<BV8 buf.struct.string0.len>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0> [[<BV8 buf.struct.string0.len>]]
# [*]     0x4165c: <Bool cap - off_285_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))> [[<BV8 buf.struct.string0.len>, <BV64 off_285_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))> [[<BV8 buf.struct.string0.len>]]
# [*]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) != 0> [[<BV8 buf.struct.string0[0]>]]
# [*]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) == 0> [[<BV8 buf.struct.string0[0]>]]
# [*]     0x4172b: <Bool ((0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, <...>) == 0x2d then 1 else 0)) & 1)) != 0x0> [[<BV8 buf.struct.string0[0]>]]
# [*]     0x416a4: <Bool 0x1 >= (0#32 .. (0#24 .. buf.struct.string0.len))> [[<BV8 buf.struct.string0.len>]]
# [*]     0x4155a: <Bool cap - off_290_64 >= 0x1> [[<BV64 off_290_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.string1.len == 0> [[<BV8 buf.struct.string1.len>]]
# [*]     0x41a27: <Bool cap - off_296_64 >= 0x4> [[<BV64 off_296_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_298_64>
# [!] 0x41a44: READING 0x603f - 0x6041 (buf)
# [!]   <BV16 Reverse(buf[3975:3960])>
# [+] {"time": "2025-09-05 14:15:52,448", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Partial access to known field", "address": 24639, "size": 2, "pc": 268868, "guards": [[268275, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "Reverse", "args": [{"op": "BVS", "args": ["off", 64]}]}]}, {"op": "BVV", "args": [12, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [270103, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [16, {"op": "BVS", "args": ["msg.hdr.numstructs_276_16", 16]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267610, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_283_64", 64]}]}, {"op": "BVV", "args": [1, 64]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267666, {"op": "__ne__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267691, {"op": "__ne__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [192, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267804, {"op": "__eq__", "args": [{"op": "__and__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [192, 8]}]}, {"op": "BVV", "args": [0, 8]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267832, {"op": "__ne__", "args": [{"op": "__or__", "args": [{"op": "If", "args": [{"op": "__lt__", "args": [{"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0.len", 8]}]}]}, {"op": "BVV", "args": [255, 64]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "If", "args": [{"op": "__eq__", "args": [{"op": "BVS", "args": ["buf.struct.string0.len", 8]}, {"op": "BVV", "args": [255, 8]}]}, {"op": "BVV", "args": [1, 1]}, {"op": "BVV", "args": [0, 1]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267868, {"op": "__ge__", "args": [{"op": "__sub__", "args": [{"op": "BVS", "args": ["cap", 64]}, {"op": "BVS", "args": ["off_285_64", 64]}]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0.len", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267940, {"op": "__lt__", "args": [{"op": "BVV", "args": [0, 64]}, {"op": "ZeroExt", "args": [32, {"op": "ZeroExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0.len", 8]}]}]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [267979, {"op": "__eq__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}, {"op": "__and__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}]}, {"op": "BVV", "args": [0, 1]}]}, {"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}]}, {"op": "Extract", "args": [31, 31, {"op": "__sub__", "args": [{"op": "SignExt", "args": [24, {"op": "BVS", "args": ["buf.struct.string0[0]", 8]}]}, {"op": "BVV", "args": [97, 32]}]}]}]}]}]}, {"op": "BVV", "args": [0, 1]}], "class": "smallworld.analyses.field_detection.hints.ClaripySerializable"}], [268021, {"op": "__eq__", "args": [{"op": "__xor__", "args": [{"op": "Extract", "args": [31, 31, {"op": "__ ...
# [*] Partial access to known field
# [*]   address:    0x603f
# [*]   size:       2
# [*]   pc:         0x41a44
# [*]   access:     read
# [*]   guards:
# [*]     0x417f3: <Bool cap - Reverse(off) >= 0xc> [[<BV64 off>, <BV64 cap>]]
# [*]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_276_16))> [[<BV16 msg.hdr.numstructs_276_16>]]
# [*]     0x4155a: <Bool cap - off_283_64 >= 0x1> [[<BV64 off_283_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.string0.len != 0> [[<BV8 buf.struct.string0.len>]]
# [*]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192> [[<BV8 buf.struct.string0.len>]]
# [*]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0> [[<BV8 buf.struct.string0.len>]]
# [*]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0> [[<BV8 buf.struct.string0.len>]]
# [*]     0x4165c: <Bool cap - off_285_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))> [[<BV8 buf.struct.string0.len>, <BV64 off_285_64>, <BV64 cap>]]
# [*]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))> [[<BV8 buf.struct.string0.len>]]
# [*]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) == 0> [[<BV8 buf.struct.string0[0]>]]
# [*]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) == 0> [[<BV8 buf.struct.string0[0]>]]
# [*]     0x4172b: <Bool ((0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. <...>[31:31] ^ <...> & <...> | (if <...> == <...> then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, <...>) == 0x2d then 1 else 0)) & 1)) != 0x0> [[<BV8 buf.struct.string0[0]>]]
# [*]     0x416a4: <Bool 0x1 >= (0#32 .. (0#24 .. buf.struct.string0.len))> [[<BV8 buf.struct.string0.len>]]
# [*]     0x4155a: <Bool cap - off_291_64 >= 0x1> [[<BV64 off_291_64>, <BV64 cap>]]
# [*]     0x41592: <Bool buf.struct.string1.len == 0> [[<BV8 buf.struct.string1.len>]]
# [*]     0x41a27: <Bool cap - off_298_64 >= 0x4> [[<BV64 off_298_64>, <BV64 cap>]]
# [*]   field:      buf[0:2]
# [!] <SimulationManager with 43 unsat, 6 deadended>
# [!] []
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_276_16))>
# [!]     0x4155a: <Bool cap - off_283_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string0.len != 0>
# [!]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_285_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) != 0>
# [!]     0x4172b: <Bool ((0#7 .. (if SignExt(24, buf.struct.string0[0]) == 0x2d then 1 else 0)) & 1) == 0>
# [!]     0x421bd: <Bool msg.a_284_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_272_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_285_64 = <BV64 off_283_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_292_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_268_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_269_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_270_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_274_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_276_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_278_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_280_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_282_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.string0.len = <BV8 buf.struct.string0.len>
# [!]     0x603d - 0x603e: buf.struct.string0[0] = <BV8 buf.struct.string0[0]>
# [!]     0x603e - 0x603f: buf.struct.string1.len = <BV8 buf.struct.string1.len>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20011: msg.struct.item.0.text.0 = <BV8 msg.struct.item.0.text.0>
# [!]     0x20011 - 0x20012: msg.struct.item.0.text.1 = <BV8 msg.struct.item.0.text.1>
# [!]     0x20012 - 0x20013: msg.struct.item.0.text.2 = <BV8 msg.struct.item.0.text.2>
# [!]     0x20013 - 0x20110: msg.struct.item.0.text = <BV2024 msg.struct.item.0.text>
# [!]     0x20110 - 0x20118: msg.struct.item.0.unk = <BV64 msg.struct.item.0.unk>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_276_16))>
# [!]     0x4155a: <Bool cap - off_283_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string0.len != 0>
# [!]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_285_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.string0[0]) - 0x39[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x39[31:31]) | (if SignExt(24, buf.struct.string0[0]) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.string0[0]) == 0x2d then 1 else 0)) & 1)) == 0x0>
# [!]     0x421bd: <Bool msg.a_284_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_272_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_285_64 = <BV64 off_283_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_293_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_268_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_269_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_270_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_274_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_276_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_278_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_280_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_282_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.string0.len = <BV8 buf.struct.string0.len>
# [!]     0x603d - 0x603e: buf.struct.string0[0] = <BV8 buf.struct.string0[0]>
# [!]     0x603e - 0x603f: buf.struct.string1.len = <BV8 buf.struct.string1.len>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20011: msg.struct.item.0.text.0 = <BV8 msg.struct.item.0.text.0>
# [!]     0x20011 - 0x20012: msg.struct.item.0.text.1 = <BV8 msg.struct.item.0.text.1>
# [!]     0x20012 - 0x20013: msg.struct.item.0.text.2 = <BV8 msg.struct.item.0.text.2>
# [!]     0x20013 - 0x20110: msg.struct.item.0.text = <BV2024 msg.struct.item.0.text>
# [!]     0x20110 - 0x20118: msg.struct.item.0.unk = <BV64 msg.struct.item.0.unk>
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_276_16))>
# [!]     0x4155a: <Bool cap - off_283_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string0.len != 0>
# [!]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_285_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) == 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.string0[0]) - 0x7a[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x7a[31:31]) | (if SignExt(24, buf.struct.string0[0]) == 0x7a then 1 else 0)) & 1) | (0#24 .. (0#7 .. SignExt(24, buf.struct.string0[0]) - 0x39[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x39[31:31]) | (if SignExt(24, buf.struct.string0[0]) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.string0[0]) == 0x2d then 1 else 0)) & 1)) == 0x0>
# [!]     0x421bd: <Bool msg.a_284_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_272_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_285_64 = <BV64 off_283_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_295_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_268_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_269_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_270_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_274_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_276_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_278_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_280_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_282_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.string0.len = <BV8 buf.struct.string0.len>
# [!]     0x603d - 0x603e: buf.struct.string0[0] = <BV8 buf.struct.string0[0]>
# [!]     0x603e - 0x603f: buf.struct.string1.len = <BV8 buf.struct.string1.len>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20011: msg.struct.item.0.text.0 = <BV8 msg.struct.item.0.text.0>
# [!]     0x20011 - 0x20012: msg.struct.item.0.text.1 = <BV8 msg.struct.item.0.text.1>
# [!]     0x20012 - 0x20013: msg.struct.item.0.text.2 = <BV8 msg.struct.item.0.text.2>
# [!]     0x20013 - 0x20110: msg.struct.item.0.text = <BV2024 msg.struct.item.0.text>
# [!]     0x20110 - 0x20118: msg.struct.item.0.unk = <BV64 msg.struct.item.0.unk>
# [!] State at <BV64 0x41a44>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_276_16))>
# [!]     0x4155a: <Bool cap - off_283_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string0.len != 0>
# [!]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_285_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) != 0>
# [!]     0x4172b: <Bool ((0#7 .. (if SignExt(24, buf.struct.string0[0]) == 0x2d then 1 else 0)) & 1) != 0>
# [!]     0x416a4: <Bool 0x1 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x4155a: <Bool cap - off_289_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string1.len == 0>
# [!]     0x41a27: <Bool cap - off_294_64 >= 0x4>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_272_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_294_64 = <BV64 off_289_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_284_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_268_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_269_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_270_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_274_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_276_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_278_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_280_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_282_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.string0.len = <BV8 buf.struct.string0.len>
# [!]     0x603d - 0x603e: buf.struct.string0[0] = <BV8 buf.struct.string0[0]>
# [!]     0x603e - 0x603f: buf.struct.string1.len = <BV8 buf.struct.string1.len>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20011: msg.struct.item.0.text.0_286_8 = <BV8 buf.struct.string0[0]>
# [!]     0x20011 - 0x20012: msg.struct.item.0.text.1_297_8 = <BV8 0>
# [!]     0x20012 - 0x20013: msg.struct.item.0.text.2 = <BV8 msg.struct.item.0.text.2>
# [!]     0x20013 - 0x20110: msg.struct.item.0.text = <BV2024 msg.struct.item.0.text>
# [!]     0x20110 - 0x20118: msg.struct.item.0.unk = <BV64 msg.struct.item.0.unk>
# [!] State at <BV64 0x41a44>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_276_16))>
# [!]     0x4155a: <Bool cap - off_283_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string0.len != 0>
# [!]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_285_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.string0[0]) - 0x39[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x39[31:31]) | (if SignExt(24, buf.struct.string0[0]) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.string0[0]) == 0x2d then 1 else 0)) & 1)) != 0x0>
# [!]     0x416a4: <Bool 0x1 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x4155a: <Bool cap - off_290_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string1.len == 0>
# [!]     0x41a27: <Bool cap - off_296_64 >= 0x4>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_272_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_296_64 = <BV64 off_290_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_284_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_268_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_269_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_270_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_274_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_276_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_278_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_280_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_282_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.string0.len = <BV8 buf.struct.string0.len>
# [!]     0x603d - 0x603e: buf.struct.string0[0] = <BV8 buf.struct.string0[0]>
# [!]     0x603e - 0x603f: buf.struct.string1.len = <BV8 buf.struct.string1.len>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20011: msg.struct.item.0.text.0_287_8 = <BV8 buf.struct.string0[0]>
# [!]     0x20011 - 0x20012: msg.struct.item.0.text.1_299_8 = <BV8 0>
# [!]     0x20012 - 0x20013: msg.struct.item.0.text.2 = <BV8 msg.struct.item.0.text.2>
# [!]     0x20013 - 0x20110: msg.struct.item.0.text = <BV2024 msg.struct.item.0.text>
# [!]     0x20110 - 0x20118: msg.struct.item.0.unk = <BV64 msg.struct.item.0.unk>
# [!] State at <BV64 0x41a44>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_276_16))>
# [!]     0x4155a: <Bool cap - off_283_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string0.len != 0>
# [!]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_285_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) == 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.string0[0]) - 0x7a[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x7a[31:31]) | (if SignExt(24, buf.struct.string0[0]) == 0x7a then 1 else 0)) & 1) | (0#24 .. (0#7 .. SignExt(24, buf.struct.string0[0]) - 0x39[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x39[31:31]) | (if SignExt(24, buf.struct.string0[0]) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.string0[0]) == 0x2d then 1 else 0)) & 1)) != 0x0>
# [!]     0x416a4: <Bool 0x1 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x4155a: <Bool cap - off_291_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string1.len == 0>
# [!]     0x41a27: <Bool cap - off_298_64 >= 0x4>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_272_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_298_64 = <BV64 off_291_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_284_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_268_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_269_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_270_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_274_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_276_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_278_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_280_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_282_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.string0.len = <BV8 buf.struct.string0.len>
# [!]     0x603d - 0x603e: buf.struct.string0[0] = <BV8 buf.struct.string0[0]>
# [!]     0x603e - 0x603f: buf.struct.string1.len = <BV8 buf.struct.string1.len>
# [!]     0x603f - 0x6230: buf = <BV3976 buf>
# [!]     0x20010 - 0x20011: msg.struct.item.0.text.0_288_8 = <BV8 buf.struct.string0[0]>
# [!]     0x20011 - 0x20012: msg.struct.item.0.text.1_300_8 = <BV8 0>
# [!]     0x20012 - 0x20013: msg.struct.item.0.text.2 = <BV8 msg.struct.item.0.text.2>
# [!]     0x20013 - 0x20110: msg.struct.item.0.text = <BV2024 msg.struct.item.0.text>
# [!]     0x20110 - 0x20118: msg.struct.item.0.unk = <BV64 msg.struct.item.0.unk>

# %% [markdown]
# _The work so far is captured in `dns_5.py`_
#
# Once running this, we discover there a field from a `partial access to known field` at `buf[0:2]`. With this defined, we'll discover another field, once again at `buf[0:2]`. We can define those now.
#
# ```python
# gdata[64] = smallworld.state.SymbolicValue(2, None, None, "buf.struct.a")
# gdata[66] = smallworld.state.SymbolicValue(2, None, None, "buf.struct.b")
# gdata[68] = smallworld.state.SymbolicValue(492, None, None, "buf")
# ```
#
# With just these defined, we'll find another error (partial access in `msg.a.item.unk`), that these are referenced later. Seemingly the 2-byte ints are promoted to a 4-byte int, which is why the spacing is 4 bytes for each, not 2.
#
# These correspond to two fields following our prior struct def:
#
# ```python
# fields.append((4, "a"))
# fields.append((4, "b"))
# ```

# %%
reinitialize_demo()
add_malloc_free_models()

fields = [(1, f"text.{i}") for i in range(0, 3)]
fields.append((253, "text"))
fields.append((4, "a"))
fields.append((4, "b"))

malloc.bind_length_to_struct("msg.hdr.numstructs", "msg.struct.item", fields)

gdata[60] = smallworld.state.IntegerValue(2, 1, "buf.struct.string0.len")
gdata[61] = smallworld.state.SymbolicValue(1, None, None, "buf.struct.string0[0]")
gdata[62] = smallworld.state.SymbolicValue(1, None, None, "buf.struct.string0[1]")
gdata[63] = smallworld.state.IntegerValue(0, 1, "buf.struct.string1.len")
gdata[64] = smallworld.state.SymbolicValue(2, None, None, "buf.struct.a")
gdata[66] = smallworld.state.SymbolicValue(2, None, None, "buf.struct.b")
gdata[68] = smallworld.state.SymbolicValue(492, None, None, "buf")

analyze_with_timeout(machine, analysis)
# Out:
# [+] Address: 40000
# [+] {"time": "2025-09-05 14:15:52,621", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies interpreter b'/lib64/ld-linux-x86-64.so.2\\x00'", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:52,622", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program includes dynamic linking metadata", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:52,623", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies stack permissions", "class": "smallworld.hinting.hinting.Hint"}}
# [+] {"time": "2025-09-05 14:15:52,623", "level": "INFO", "source": "smallworld.state.memory.elf.elf", "content": {"message": "Program specifies RELRO data", "class": "smallworld.hinting.hinting.Hint"}}
# [!] 0x20000 - 0x30000
# [!] 0x6000 - 0x7000
# [!]   0x6000 - 0x6002: <smallworld.state.state.SymbolicValue object at 0x75689320e3e0> := msg.hdr.a
# [+] {"time": "2025-09-05 14:15:52,628", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24576, "size": 2, "label": "msg.hdr.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6030 - 0x6032: <smallworld.state.state.SymbolicValue object at 0x756894b26920> := buf.a
# [+] {"time": "2025-09-05 14:15:52,629", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24624, "size": 2, "label": "buf.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6230 - 0x6238: <smallworld.state.state.IntegerValue object at 0x7568b6c4c280> := off
# [+] {"time": "2025-09-05 14:15:52,631", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 25136, "size": 8, "label": "off", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6010 - 0x6018: <smallworld.state.state.SymbolicValue object at 0x7568931d9420> := msg.a
# [+] {"time": "2025-09-05 14:15:52,632", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24592, "size": 8, "label": "msg.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6018 - 0x6020: <smallworld.state.state.SymbolicValue object at 0x756894bb2a40> := msg.b
# [+] {"time": "2025-09-05 14:15:52,633", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24600, "size": 8, "label": "msg.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6020 - 0x6028: <smallworld.state.state.SymbolicValue object at 0x756894b42380> := msg.c
# [+] {"time": "2025-09-05 14:15:52,634", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24608, "size": 8, "label": "msg.c", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6028 - 0x6030: <smallworld.state.state.SymbolicValue object at 0x7568b6c4e4a0> := msg.d
# [+] {"time": "2025-09-05 14:15:52,635", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24616, "size": 8, "label": "msg.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6032 - 0x6034: <smallworld.state.state.SymbolicValue object at 0x7568931b7bb0> := buf.b
# [+] {"time": "2025-09-05 14:15:52,636", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24626, "size": 2, "label": "buf.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6002 - 0x6004: <smallworld.state.state.SymbolicValue object at 0x75689320c0a0> := msg.hdr.b
# [+] {"time": "2025-09-05 14:15:52,636", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24578, "size": 2, "label": "msg.hdr.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6004 - 0x6006: <smallworld.state.state.SymbolicValue object at 0x756892eb5450> := msg.hdr.numstructs
# [+] {"time": "2025-09-05 14:15:52,638", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24580, "size": 2, "label": "msg.hdr.numstructs", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6006 - 0x6008: <smallworld.state.state.SymbolicValue object at 0x75689323ace0> := msg.hdr.d
# [+] {"time": "2025-09-05 14:15:52,638", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24582, "size": 2, "label": "msg.hdr.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6008 - 0x600a: <smallworld.state.state.SymbolicValue object at 0x7568931b5810> := msg.hdr.e
# [+] {"time": "2025-09-05 14:15:52,640", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24584, "size": 2, "label": "msg.hdr.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600a - 0x600c: <smallworld.state.state.SymbolicValue object at 0x7568931b50c0> := msg.hdr.f
# [+] {"time": "2025-09-05 14:15:52,640", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24586, "size": 2, "label": "msg.hdr.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x600c - 0x6010: <smallworld.state.state.SymbolicValue object at 0x7568931b52d0> := msg.hdr.unk
# [+] {"time": "2025-09-05 14:15:52,641", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24588, "size": 4, "label": "msg.hdr.unk", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6034 - 0x6036: <smallworld.state.state.BytesValue object at 0x756892eb5240> := buf.msg.hdr.numstructs
# [+] {"time": "2025-09-05 14:15:52,642", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24628, "size": 2, "label": "buf.msg.hdr.numstructs", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6036 - 0x6038: <smallworld.state.state.SymbolicValue object at 0x756894b26fe0> := buf.d
# [+] {"time": "2025-09-05 14:15:52,643", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24630, "size": 2, "label": "buf.d", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6038 - 0x603a: <smallworld.state.state.SymbolicValue object at 0x7568930e33a0> := buf.e
# [+] {"time": "2025-09-05 14:15:52,644", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24632, "size": 2, "label": "buf.e", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603a - 0x603c: <smallworld.state.state.SymbolicValue object at 0x7568931b7370> := buf.f
# [+] {"time": "2025-09-05 14:15:52,645", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24634, "size": 2, "label": "buf.f", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603c - 0x603d: <smallworld.state.state.IntegerValue object at 0x7568931b7c40> := buf.struct.string0.len
# [+] {"time": "2025-09-05 14:15:52,646", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24636, "size": 1, "label": "buf.struct.string0.len", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603d - 0x603e: <smallworld.state.state.SymbolicValue object at 0x756892b48790> := buf.struct.string0[0]
# [+] {"time": "2025-09-05 14:15:52,647", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24637, "size": 1, "label": "buf.struct.string0[0]", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603e - 0x603f: <smallworld.state.state.SymbolicValue object at 0x756892ee7a00> := buf.struct.string0[1]
# [+] {"time": "2025-09-05 14:15:52,648", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24638, "size": 1, "label": "buf.struct.string0[1]", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x603f - 0x6040: <smallworld.state.state.IntegerValue object at 0x756892f8f190> := buf.struct.string1.len
# [+] {"time": "2025-09-05 14:15:52,649", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24639, "size": 1, "label": "buf.struct.string1.len", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6040 - 0x6042: <smallworld.state.state.SymbolicValue object at 0x7568931b6a10> := buf.struct.a
# [+] {"time": "2025-09-05 14:15:52,650", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24640, "size": 2, "label": "buf.struct.a", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6042 - 0x6044: <smallworld.state.state.SymbolicValue object at 0x756892f33400> := buf.struct.b
# [+] {"time": "2025-09-05 14:15:52,651", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24642, "size": 2, "label": "buf.struct.b", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!]   0x6044 - 0x6230: <smallworld.state.state.SymbolicValue object at 0x7568931b5c60> := buf
# [+] {"time": "2025-09-05 14:15:52,652", "level": "INFO", "source": "smallworld.analyses.field_detection.field_analysis", "content": {"message": "Tracking new field", "address": 24644, "size": 492, "label": "buf", "class": "smallworld.analyses.field_detection.hints.TrackedFieldHint"}}
# [!] 0x7fffffffc000 - 0x800000000000
# [!] 0x40000 - 0x46000
# [!] No entry_point was specified for blob <smallworld.utils.SparseIO object at 0x756892eb4310>, assuming 0
# [!] No base_addr was specified for blob <smallworld.utils.SparseIO object at 0x756892eb4310>, assuming 0
# [+] Linking None
# [+] Mapping None at 0x0
# [!] Disabling IRSB translation cache because support for self-modifying code is enabled.
# [+] Linking cle##externs
# [+] Mapping cle##externs at 0x100000
# [+] Storing 8 bytes at 0x20000
# [+] Storing 8 bytes at 0x20008
# [+] Storing 8 bytes at 0x6230
# [+] Storing 2 bytes at 0x6034
# [+] Storing 1 bytes at 0x603c
# [+] Storing 1 bytes at 0x603f
# [+] Storing 8 bytes at 0x7ffffffffff8
# [!] 0x41e73: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41e7f: WRITING 0x6018 - 0x6020 (msg.b)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.b
# [!] 0x41e8b: WRITING 0x6020 - 0x6028 (msg.c)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.c
# [!] 0x41e97: WRITING 0x6028 - 0x6030 (msg.d)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.d
# [!] 0x417ec: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4180d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41810: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x41824: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x41827: READING 0x6030 - 0x6032 (buf.a)
# [!]   <BV16 Reverse(buf.a)>
# [!] 0x4183d: WRITING 0x6000 - 0x6002 (msg.hdr.a)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.a
# [!] 0x41844: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off)>
# [!] 0x4184b: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 Reverse(off) + 0x2>
# [!]   Write to entire field off
# [!] 0x41856: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_329_64>
# [!] 0x41859: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x4186d: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_329_64>
# [!] 0x41870: READING 0x6032 - 0x6034 (buf.b)
# [!]   <BV16 Reverse(buf.b)>
# [!] 0x41886: WRITING 0x6002 - 0x6004 (msg.hdr.b)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.b
# [!] 0x4188e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_329_64>
# [!] 0x41895: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_329_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418a0: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_331_64>
# [!] 0x418a3: READING 0x6034 - 0x6036 (buf.msg.hdr.numstructs)
# [!]   <BV16 Reverse(buf.msg.hdr.numstructs)>
# [!] 0x418b7: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_331_64>
# [!] 0x418ba: READING 0x6034 - 0x6036 (buf.msg.hdr.numstructs)
# [!]   <BV16 Reverse(buf.msg.hdr.numstructs)>
# [!] 0x418d0: WRITING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.numstructs
# [!] 0x418d8: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_331_64>
# [!] 0x418df: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_331_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x418ea: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_333_64>
# [!] 0x418ed: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x41901: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_333_64>
# [!] 0x41904: READING 0x6036 - 0x6038 (buf.d)
# [!]   <BV16 Reverse(buf.d)>
# [!] 0x4191a: WRITING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.d
# [!] 0x41922: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_333_64>
# [!] 0x41929: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_333_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41934: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_335_64>
# [!] 0x41937: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x4194b: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_335_64>
# [!] 0x4194e: READING 0x6038 - 0x603a (buf.e)
# [!]   <BV16 Reverse(buf.e)>
# [!] 0x41964: WRITING 0x6008 - 0x600a (msg.hdr.e)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.e
# [!] 0x4196c: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_335_64>
# [!] 0x41973: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_335_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x4197e: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_337_64>
# [!] 0x41981: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x41995: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_337_64>
# [!] 0x41998: READING 0x603a - 0x603c (buf.f)
# [!]   <BV16 Reverse(buf.f)>
# [!] 0x419ae: WRITING 0x600a - 0x600c (msg.hdr.f)
# [!]   <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]   Write to entire field msg.hdr.f
# [!] 0x419b6: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_337_64>
# [!] 0x419bd: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_337_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ed2: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_332_16>
# [!] malloc: Alloc'd 264 bytes at 0x20010
# [+] Storing 8 bytes at 0x20008
# [!]   Alloc of 1 items
# [+] Storing 2112 bytes at 0x20010
# [!] 0x41ee6: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x20010>
# [!]   Write to entire field msg.a
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_332_16>
# [!] 0x41f2d: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_339_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_339_64>
# [!] 0x41577: READING 0x603c - 0x603d (buf.struct.string0.len)
# [!]   <BV8 buf.struct.string0.len>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_339_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_339_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x41652: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x416b2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x416b9: READING 0x603d - 0x603e (buf.struct.string0[0])
# [!]   <BV8 buf.struct.string0[0]>
# [!] 0x41740: WRITING 0x20010 - 0x20011 (msg.struct.item.0.text.0)
# [!]   <BV8 buf.struct.string0[0]>
# [!]   Write to entire field msg.struct.item.0.text.0
# [!] 0x41740: WRITING 0x20010 - 0x20011 (msg.struct.item.0.text.0)
# [!]   <BV8 buf.struct.string0[0]>
# [!]   Write to entire field msg.struct.item.0.text.0
# [!] 0x41740: WRITING 0x20010 - 0x20011 (msg.struct.item.0.text.0)
# [!]   <BV8 buf.struct.string0[0]>
# [!]   Write to entire field msg.struct.item.0.text.0
# [!] 0x416b2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x416b9: READING 0x603e - 0x603f (buf.struct.string0[1])
# [!]   <BV8 buf.struct.string0[1]>
# [!] 0x416b2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x416b9: READING 0x603e - 0x603f (buf.struct.string0[1])
# [!]   <BV8 buf.struct.string0[1]>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x416b2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x416b9: READING 0x603e - 0x603f (buf.struct.string0[1])
# [!]   <BV8 buf.struct.string0[1]>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41740: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 buf.struct.string0[1]>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x41740: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 buf.struct.string0[1]>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x41740: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 buf.struct.string0[1]>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x41740: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 buf.struct.string0[1]>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x41740: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 buf.struct.string0[1]>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x41740: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 buf.struct.string0[1]>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x41740: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 buf.struct.string0[1]>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x41740: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 buf.struct.string0[1]>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_341_64>
# [!]   Write to entire field off
# [!] 0x41740: WRITING 0x20011 - 0x20012 (msg.struct.item.0.text.1)
# [!]   <BV8 buf.struct.string0[1]>
# [!]   Write to entire field msg.struct.item.0.text.1
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_341_64>
# [!]   Write to entire field off
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_341_64>
# [!]   Write to entire field off
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_341_64>
# [!]   Write to entire field off
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_341_64>
# [!]   Write to entire field off
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_341_64>
# [!]   Write to entire field off
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_356_64>
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_341_64>
# [!]   Write to entire field off
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_341_64>
# [!]   Write to entire field off
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_358_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_359_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_356_64>
# [!] 0x41774: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_341_64>
# [!] 0x41577: READING 0x603f - 0x6040 (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x41777: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 (0#32 .. (0#24 .. buf.struct.string0.len)) + off_341_64>
# [!]   Write to entire field off
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_360_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_361_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_362_64>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_356_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_358_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_359_64>
# [!] 0x41577: READING 0x603f - 0x6040 (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x41577: READING 0x603f - 0x6040 (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_356_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421b8: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_363_64>
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_364_64>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_358_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_360_64>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_359_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_361_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_362_64>
# [!] 0x41577: READING 0x603f - 0x6040 (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x41577: READING 0x603f - 0x6040 (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x41577: READING 0x603f - 0x6040 (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x421c7: READING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 msg.a_340_64>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_358_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_359_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41553: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_366_64>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_360_64>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_361_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_363_64>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_362_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_364_64>
# [!] 0x417ae: WRITING 0x20012 - 0x20013 (msg.struct.item.0.text.2)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.2
# [!] 0x41577: READING 0x603f - 0x6040 (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x41577: READING 0x603f - 0x6040 (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_360_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_361_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_362_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x421d4: WRITING 0x6010 - 0x6018 (msg.a)
# [!]   <BV64 0x0>
# [!]   Write to entire field msg.a
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_363_64>
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_364_64>
# [!] 0x41574: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_366_64>
# [!] 0x417ae: WRITING 0x20012 - 0x20013 (msg.struct.item.0.text.2)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.2
# [!] 0x417ae: WRITING 0x20012 - 0x20013 (msg.struct.item.0.text.2)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.2
# [!] 0x41577: READING 0x603f - 0x6040 (buf.struct.string1.len)
# [!]   <BV8 buf.struct.string1.len>
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_363_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_364_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x41581: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_366_64>
# [!] 0x417ae: WRITING 0x20012 - 0x20013 (msg.struct.item.0.text.2)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.2
# [!] 0x417ae: WRITING 0x20012 - 0x20013 (msg.struct.item.0.text.2)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.2
# [!] 0x417ae: WRITING 0x20012 - 0x20013 (msg.struct.item.0.text.2)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.2
# [!] 0x41588: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_366_64 + 0x1>
# [!]   Write to entire field off
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_369_64>
# [!] 0x417ae: WRITING 0x20012 - 0x20013 (msg.struct.item.0.text.2)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.2
# [!] 0x417ae: WRITING 0x20012 - 0x20013 (msg.struct.item.0.text.2)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.2
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_373_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_374_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_369_64>
# [!] 0x41a44: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x417ae: WRITING 0x20012 - 0x20013 (msg.struct.item.0.text.2)
# [!]   <BV8 0>
# [!]   Write to entire field msg.struct.item.0.text.2
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_378_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_379_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_380_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_373_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_374_64>
# [!] 0x41a44: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a44: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_369_64>
# [!] 0x41a5c: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_384_64>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_385_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_378_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_379_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_380_64>
# [!] 0x41a44: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a44: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a44: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_373_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_374_64>
# [!] 0x41a5c: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a5c: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a20: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_389_64>
# [!] 0x41a6e: WRITING 0x20110 - 0x20114 (msg.struct.item.0.a)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.a
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_384_64>
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_385_64>
# [!] 0x41a44: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a44: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_369_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_378_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_379_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_380_64>
# [!] 0x41a5c: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a5c: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a5c: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_369_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41a6e: WRITING 0x20110 - 0x20114 (msg.struct.item.0.a)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.a
# [!] 0x41a6e: WRITING 0x20110 - 0x20114 (msg.struct.item.0.a)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.a
# [!] 0x41a41: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_389_64>
# [!] 0x41a44: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_373_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_374_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_384_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_385_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_394_64>
# [!] 0x41a5c: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a5c: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a8d: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_373_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41a6e: WRITING 0x20110 - 0x20114 (msg.struct.item.0.a)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.a
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_374_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41a6e: WRITING 0x20110 - 0x20114 (msg.struct.item.0.a)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.a
# [!] 0x41a6e: WRITING 0x20110 - 0x20114 (msg.struct.item.0.a)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.a
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_378_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_379_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_380_64>
# [!] 0x41a59: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_389_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_397_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_399_64>
# [!] 0x41a5c: READING 0x6040 - 0x6042 (buf.struct.a)
# [!]   <BV16 Reverse(buf.struct.a)>
# [!] 0x41a8d: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_378_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41a8d: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_379_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41a6e: WRITING 0x20110 - 0x20114 (msg.struct.item.0.a)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.a
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_380_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41a6e: WRITING 0x20110 - 0x20114 (msg.struct.item.0.a)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.a
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_394_64>
# [!] 0x41aa5: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_384_64>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_385_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_402_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_403_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_405_64>
# [!] 0x41a8d: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41a8d: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_384_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41a8d: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_385_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41a6e: WRITING 0x20110 - 0x20114 (msg.struct.item.0.a)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.a
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_397_64>
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_399_64>
# [!] 0x41aa5: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41aa5: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41a78: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_389_64>
# [!] 0x41ab7: WRITING 0x20114 - 0x20118 (msg.struct.item.0.b)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.b
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_407_64>
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x41a8d: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41a8d: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41a7f: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_389_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_394_64>
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_402_64>
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_403_64>
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_405_64>
# [!] 0x41aa5: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41aa5: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41aa5: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_394_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ab7: WRITING 0x20114 - 0x20118 (msg.struct.item.0.b)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.b
# [!] 0x41ab7: WRITING 0x20114 - 0x20118 (msg.struct.item.0.b)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.b
# [!] 0x41a8a: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_411_64>
# [!] 0x41a8d: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_397_64>
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_399_64>
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_407_64>
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x41aa5: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41aa5: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_397_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ab7: WRITING 0x20114 - 0x20118 (msg.struct.item.0.b)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.b
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_399_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ab7: WRITING 0x20114 - 0x20118 (msg.struct.item.0.b)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.b
# [!] 0x41ab7: WRITING 0x20114 - 0x20118 (msg.struct.item.0.b)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.b
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_402_64>
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_403_64>
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_405_64>
# [!] 0x41aa2: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_411_64>
# [!] 0x41aa5: READING 0x6042 - 0x6044 (buf.struct.b)
# [!]   <BV16 Reverse(buf.struct.b)>
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_402_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_403_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ab7: WRITING 0x20114 - 0x20118 (msg.struct.item.0.b)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.b
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_405_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ab7: WRITING 0x20114 - 0x20118 (msg.struct.item.0.b)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.b
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_407_64>
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64>
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_407_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_408_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41ab7: WRITING 0x20114 - 0x20118 (msg.struct.item.0.b)
# [!]   <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>
# [!]   Write to entire field msg.struct.item.0.b
# [!] 0x41ac1: READING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_411_64>
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_332_16>
# [!] 0x41ac8: WRITING 0x6230 - 0x6238 (off)
# [!]   <BV64 off_411_64 + 0x2>
# [!]   Write to entire field off
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_332_16>
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_332_16>
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_334_16>
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_332_16>
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_332_16>
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_332_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_334_16
# [*] Concretize them to continue analysis
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_334_16>
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_334_16>
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_332_16>
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_332_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_334_16
# [*] Concretize them to continue analysis
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_334_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_334_16
# [*] Concretize them to continue analysis
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_334_16>
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_334_16>
# [!] 0x41f10: READING 0x6004 - 0x6006 (msg.hdr.numstructs)
# [!]   <BV16 msg.hdr.numstructs_332_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_334_16
# [*] Concretize them to continue analysis
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_334_16
# [*] Concretize them to continue analysis
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_334_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_334_16
# [*] Concretize them to continue analysis
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_334_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_334_16
# [*] Concretize them to continue analysis
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_334_16
# [*] Concretize them to continue analysis
# [!] 0x41f80: READING 0x6006 - 0x6008 (msg.hdr.d)
# [!]   <BV16 msg.hdr.d_334_16>
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_334_16
# [*] Concretize them to continue analysis
# [!] <SimulationManager with 151 unsat, 21 deadended>
# [!] []
# [!] State at <BV64 0x1010101>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_332_16))>
# [!]     0x4155a: <Bool cap - off_339_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string0.len != 0>
# [!]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_341_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) != 0>
# [!]     0x4172b: <Bool ((0#7 .. (if SignExt(24, buf.struct.string0[0]) == 0x2d then 1 else 0)) & 1) == 0>
# [!]     0x421bd: <Bool msg.a_340_64 != 0x0>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_328_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_341_64 = <BV64 off_339_64 + 0x1>
# [!]     0x6010 - 0x6018: msg.a_345_64 = <BV64 0x0>
# [!]     0x6018 - 0x6020: msg.b_324_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_325_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_326_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_330_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_332_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# ...
# [!]     0x416a4: <Bool 0x2 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x4155a: <Bool cap - off_363_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string1.len == 0>
# [!]     0x41a27: <Bool cap - off_384_64 >= 0x4>
# [!]     0x41f17: <Bool 0x1 >= (0#32 .. (0#16 .. msg.hdr.numstructs_332_16))>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_328_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_425_64 = <BV64 off_407_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_340_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_324_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_325_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_326_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_330_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_332_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_334_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_336_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_338_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.string0.len = <BV8 buf.struct.string0.len>
# [!]     0x603d - 0x603e: buf.struct.string0[0] = <BV8 buf.struct.string0[0]>
# [!]     0x603e - 0x603f: buf.struct.string0[1] = <BV8 buf.struct.string0[1]>
# [!]     0x603f - 0x6040: buf.struct.string1.len = <BV8 buf.struct.string1.len>
# [!]     0x6040 - 0x6042: buf.struct.a = <BV16 buf.struct.a>
# [!]     0x6042 - 0x6044: buf.struct.b = <BV16 buf.struct.b>
# [!]     0x6044 - 0x6230: buf = <BV3936 buf>
# [!]     0x20010 - 0x20011: msg.struct.item.0.text.0_343_8 = <BV8 buf.struct.string0[0]>
# [!]     0x20011 - 0x20012: msg.struct.item.0.text.1_354_8 = <BV8 buf.struct.string0[1]>
# [!]     0x20012 - 0x20013: msg.struct.item.0.text.2_390_8 = <BV8 0>
# [!]     0x20013 - 0x20110: msg.struct.item.0.text = <BV2024 msg.struct.item.0.text>
# [!]     0x20110 - 0x20114: msg.struct.item.0.a_404_32 = <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]     0x20114 - 0x20118: msg.struct.item.0.b_422_32 = <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>
# [!] State at <BV64 0x10000>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_332_16))>
# [!]     0x4155a: <Bool cap - off_339_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string0.len != 0>
# [!]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_341_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) == 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.string0[0]) - 0x7a[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x7a[31:31]) | (if SignExt(24, buf.struct.string0[0]) == 0x7a then 1 else 0)) & 1) | (0#24 .. (0#7 .. SignExt(24, buf.struct.string0[0]) - 0x39[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x39[31:31]) | (if SignExt(24, buf.struct.string0[0]) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.string0[0]) == 0x2d then 1 else 0)) & 1)) != 0x0>
# [!]     0x416a4: <Bool 0x1 < (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.string0[1]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[1])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[1])[31:31] ^ SignExt(24, buf.struct.string0[1]) - 0x61[31:31])) != 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.string0[1]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[1])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[1])[31:31] ^ SignExt(24, buf.struct.string0[1]) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.string0[1]) - 0x39[31:31] ^ (SignExt(24, buf.struct.string0[1])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[1])[31:31] ^ SignExt(24, buf.struct.string0[1]) - 0x39[31:31]) | (if SignExt(24, buf.struct.string0[1]) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.string0[1]) == 0x2d then 1 else 0)) & 1)) != 0x0>
# [!]     0x416a4: <Bool 0x2 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x4155a: <Bool cap - off_364_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string1.len == 0>
# [!]     0x41a27: <Bool cap - off_385_64 >= 0x4>
# [!]     0x41f17: <Bool 0x1 >= (0#32 .. (0#16 .. msg.hdr.numstructs_332_16))>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_328_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_426_64 = <BV64 off_408_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_340_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_324_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_325_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_326_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_330_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_332_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_334_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_336_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_338_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.string0.len = <BV8 buf.struct.string0.len>
# [!]     0x603d - 0x603e: buf.struct.string0[0] = <BV8 buf.struct.string0[0]>
# [!]     0x603e - 0x603f: buf.struct.string0[1] = <BV8 buf.struct.string0[1]>
# [!]     0x603f - 0x6040: buf.struct.string1.len = <BV8 buf.struct.string1.len>
# [!]     0x6040 - 0x6042: buf.struct.a = <BV16 buf.struct.a>
# [!]     0x6042 - 0x6044: buf.struct.b = <BV16 buf.struct.b>
# [!]     0x6044 - 0x6230: buf = <BV3936 buf>
# [!]     0x20010 - 0x20011: msg.struct.item.0.text.0_344_8 = <BV8 buf.struct.string0[0]>
# [!]     0x20011 - 0x20012: msg.struct.item.0.text.1_355_8 = <BV8 buf.struct.string0[1]>
# [!]     0x20012 - 0x20013: msg.struct.item.0.text.2_391_8 = <BV8 0>
# [!]     0x20013 - 0x20110: msg.struct.item.0.text = <BV2024 msg.struct.item.0.text>
# [!]     0x20110 - 0x20114: msg.struct.item.0.a_406_32 = <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]     0x20114 - 0x20118: msg.struct.item.0.b_424_32 = <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>
# [!] State at <BV64 0x10000>:
# [!]   Guards:
# [!]     0x417f3: <Bool cap - Reverse(off) >= 0xc>
# [!]     0x41f17: <Bool 0x0 < (0#32 .. (0#16 .. msg.hdr.numstructs_332_16))>
# [!]     0x4155a: <Bool cap - off_339_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string0.len != 0>
# [!]     0x415ab: <Bool (buf.struct.string0.len & 192) != 192>
# [!]     0x4161c: <Bool (buf.struct.string0.len & 192) == 0>
# [!]     0x41638: <Bool ((if (0#32 .. (0#24 .. buf.struct.string0.len)) < 0xff then 1 else 0) | (if buf.struct.string0.len == 255 then 1 else 0)) != 0>
# [!]     0x4165c: <Bool cap - off_341_64 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416a4: <Bool 0x0 < (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.string0[0]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x61[31:31])) == 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.string0[0]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.string0[0]) - 0x7a[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x7a[31:31]) | (if SignExt(24, buf.struct.string0[0]) == 0x7a then 1 else 0)) & 1) | (0#24 .. (0#7 .. SignExt(24, buf.struct.string0[0]) - 0x39[31:31] ^ (SignExt(24, buf.struct.string0[0])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[0])[31:31] ^ SignExt(24, buf.struct.string0[0]) - 0x39[31:31]) | (if SignExt(24, buf.struct.string0[0]) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.string0[0]) == 0x2d then 1 else 0)) & 1)) != 0x0>
# [!]     0x416a4: <Bool 0x1 < (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x416cb: <Bool (SignExt(24, buf.struct.string0[1]) - 0x61[31:31] ^ (SignExt(24, buf.struct.string0[1])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[1])[31:31] ^ SignExt(24, buf.struct.string0[1]) - 0x61[31:31])) == 0>
# [!]     0x416f5: <Bool (SignExt(24, buf.struct.string0[1]) - 0x30[31:31] ^ (SignExt(24, buf.struct.string0[1])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[1])[31:31] ^ SignExt(24, buf.struct.string0[1]) - 0x30[31:31])) == 0>
# [!]     0x4172b: <Bool ((0#24 .. (0#7 .. SignExt(24, buf.struct.string0[1]) - 0x7a[31:31] ^ (SignExt(24, buf.struct.string0[1])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[1])[31:31] ^ SignExt(24, buf.struct.string0[1]) - 0x7a[31:31]) | (if SignExt(24, buf.struct.string0[1]) == 0x7a then 1 else 0)) & 1) | (0#24 .. (0#7 .. SignExt(24, buf.struct.string0[1]) - 0x39[31:31] ^ (SignExt(24, buf.struct.string0[1])[31:31] ^ 0) & (SignExt(24, buf.struct.string0[1])[31:31] ^ SignExt(24, buf.struct.string0[1]) - 0x39[31:31]) | (if SignExt(24, buf.struct.string0[1]) == 0x39 then 1 else 0)) & 1) | (0#24 .. (0#7 .. (if SignExt(24, buf.struct.string0[1]) == 0x2d then 1 else 0)) & 1)) != 0x0>
# [!]     0x416a4: <Bool 0x2 >= (0#32 .. (0#24 .. buf.struct.string0.len))>
# [!]     0x4155a: <Bool cap - off_366_64 >= 0x1>
# [!]     0x41592: <Bool buf.struct.string1.len == 0>
# [!]     0x41a27: <Bool cap - off_389_64 >= 0x4>
# [!]     0x41f17: <Bool 0x1 >= (0#32 .. (0#16 .. msg.hdr.numstructs_332_16))>
# [!]   Fields:
# [!]     0x6000 - 0x6002: msg.hdr.a_328_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.a)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.a)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6030 - 0x6032: buf.a = <BV16 buf.a>
# [!]     0x6230 - 0x6238: off_428_64 = <BV64 off_411_64 + 0x2>
# [!]     0x6010 - 0x6018: msg.a_340_64 = <BV64 0x20010>
# [!]     0x6018 - 0x6020: msg.b_324_64 = <BV64 0x0>
# [!]     0x6020 - 0x6028: msg.c_325_64 = <BV64 0x0>
# [!]     0x6028 - 0x6030: msg.d_326_64 = <BV64 0x0>
# [!]     0x6032 - 0x6034: buf.b = <BV16 buf.b>
# [!]     0x6002 - 0x6004: msg.hdr.b_330_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.b)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.b)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6004 - 0x6006: msg.hdr.numstructs_332_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.msg.hdr.numstructs)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6006 - 0x6008: msg.hdr.d_334_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.d)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.d)) & 0xff00) >> 0x8[15:0]>
# [!]     0x6008 - 0x600a: msg.hdr.e_336_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.e)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.e)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600a - 0x600c: msg.hdr.f_338_16 = <BV16 (0#32 .. (0#16 .. Reverse(buf.f)) & 0xff) << 0x8[15:0] | SignExt(32, (0#16 .. Reverse(buf.f)) & 0xff00) >> 0x8[15:0]>
# [!]     0x600c - 0x6010: msg.hdr.unk = <BV32 msg.hdr.unk>
# [!]     0x6034 - 0x6036: buf.msg.hdr.numstructs = <BV16 buf.msg.hdr.numstructs>
# [!]     0x6036 - 0x6038: buf.d = <BV16 buf.d>
# [!]     0x6038 - 0x603a: buf.e = <BV16 buf.e>
# [!]     0x603a - 0x603c: buf.f = <BV16 buf.f>
# [!]     0x603c - 0x603d: buf.struct.string0.len = <BV8 buf.struct.string0.len>
# [!]     0x603d - 0x603e: buf.struct.string0[0] = <BV8 buf.struct.string0[0]>
# [!]     0x603e - 0x603f: buf.struct.string0[1] = <BV8 buf.struct.string0[1]>
# [!]     0x603f - 0x6040: buf.struct.string1.len = <BV8 buf.struct.string1.len>
# [!]     0x6040 - 0x6042: buf.struct.a = <BV16 buf.struct.a>
# [!]     0x6042 - 0x6044: buf.struct.b = <BV16 buf.struct.b>
# [!]     0x6044 - 0x6230: buf = <BV3936 buf>
# [!]     0x20010 - 0x20011: msg.struct.item.0.text.0_344_8 = <BV8 buf.struct.string0[0]>
# [!]     0x20011 - 0x20012: msg.struct.item.0.text.1_357_8 = <BV8 buf.struct.string0[1]>
# [!]     0x20012 - 0x20013: msg.struct.item.0.text.2_392_8 = <BV8 0>
# [!]     0x20013 - 0x20110: msg.struct.item.0.text = <BV2024 msg.struct.item.0.text>
# [!]     0x20110 - 0x20114: msg.struct.item.0.a_409_32 = <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.a)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.a)) & 0xff00) >> 0x8[31:0]>
# [!]     0x20114 - 0x20118: msg.struct.item.0.b_427_32 = <BV32 (0#32 .. (0#16 .. Reverse(buf.struct.b)) & 0xff) << 0x8[31:0] | SignExt(32, (0#16 .. Reverse(buf.struct.b)) & 0xff00) >> 0x8[31:0]>

# %% [markdown]
# _All this work is captured in `dns_6.py`_

# %% [markdown]
# # End of Line
# This is the end of the example, we've successfully parsed out embedded structs being used for DNS. If we line up answers we see running the program with the data, we can determine more of what the fields are that we've been manipulating. After you've done the above excercises, you may want to try labeling the fields yourself. Below, we include the answer key for the fields we've used so far. Some structs remain unlabeled as an excercise for the reader to define the next part of the struct.

# %%
fields = [(1, f"text.{i}") for i in range(0, 3)]
fields.append((253, "text"))
fields.append((4, "qtype"))
fields.append((4, "qclass"))

# DNS message struct
gdata[0] = smallworld.state.SymbolicValue(2, None, None, "mem.dns.hdr.tid")
gdata[2] = smallworld.state.SymbolicValue(2, None, None, "mem.dns.hdr.flags")
gdata[4] = smallworld.state.SymbolicValue(2, None, None, "mem.dns.hdr.n_qs")
gdata[6] = smallworld.state.SymbolicValue(2, None, None, "mem.dns.hdr.d")
gdata[8] = smallworld.state.SymbolicValue(2, None, None, "mem.dns.hdr.e")
gdata[10] = smallworld.state.SymbolicValue(2, None, None, "mem.dns.hdr.f")
# NOTE: 4 bytes of padding here; never referenced
gdata[16] = smallworld.state.SymbolicValue(8, None, None, "msg.a")
gdata[24] = smallworld.state.SymbolicValue(8, None, None, "msg.b")
gdata[32] = smallworld.state.SymbolicValue(8, None, None, "msg.c")
gdata[40] = smallworld.state.SymbolicValue(8, None, None, "msg.d")
# Input buffer
gdata[48] = smallworld.state.SymbolicValue(2, None, None, "buf.dns.hdr.tid")
gdata[50] = smallworld.state.SymbolicValue(2, None, None, "buf.dns.hdr.flags")
gdata[52] = smallworld.state.BytesValue(b"\x00\x01", "buf.dns.hdr.n_qs")
gdata[54] = smallworld.state.SymbolicValue(2, None, None, "buf.dns.hdr.d")
gdata[56] = smallworld.state.SymbolicValue(2, None, None, "buf.dns.hdr.e")
gdata[58] = smallworld.state.SymbolicValue(2, None, None, "buf.dns.hdr.f")
# This is a sequence of zero or more run-length-encoded strings.
# Strings can be of length 0 - 63,
# and the total number of characters can't exceed 25
gdata[60] = smallworld.state.IntegerValue(2, 1, "buf.dns.q1.qname.domain0.len")
gdata[61] = smallworld.state.SymbolicValue(
    1, None, None, "buf.dns.q1.qname.domain0.char[0]"
)
gdata[62] = smallworld.state.SymbolicValue(
    1, None, None, "buf.dns.q1.qname.domain0.char[1]"
)
gdata[63] = smallworld.state.IntegerValue(0, 1, "buf.dns.q1.qname.domain1.len")
gdata[64] = smallworld.state.SymbolicValue(2, None, None, "buf.dns.q1.qtype")
gdata[66] = smallworld.state.SymbolicValue(2, None, None, "buf.dns.q1.qclass")
gdata[68] = smallworld.state.SymbolicValue(492, None, None, "buf")
# Offset into buffer
gdata[560] = smallworld.state.IntegerValue(0, 8, "off", False)

# %% [markdown]
# # What's Next
# The remainder of the DNS protocol remains as an excercise to the reader, there remains an entirely new struct definition. We've worked through one together, the DNS Question struct, now you can work through one yourself! If you get stuck, the new struct is fleshed out in `dns_7.py` if you want to check your answers. You can also see all the struct definitions in `dns.h`.
#
# If you're ready to get started, there's an error above that will serve as your next clue:
# ```
# [*] Capacity did not collapse to one value
# [*] The following fields are lengths:
# [*]    msg.hdr.d_334_16
# [*] Concretize them to continue analysis
# ```
